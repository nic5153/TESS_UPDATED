# %%
import os
import requests

def download_tarball(url, save_path):
    response = requests.get(url)
    with open(save_path, 'wb') as f:
        f.write(response.content)

def main():
    # Base URL where the tarballs are located
    base_url = "https://tess.mit.edu/public/tesstransients/pages/"
    
    # Range of tarball numbers
    start_num = 1
    end_num = 66
    
    # Local directory where you want to save the tarballs
    local_directory = r"C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs"
    
    # Create the directory if it does not exist
    if not os.path.exists(local_directory):
        os.makedirs(local_directory)
    
    # Download each tarball file
    for i in range(start_num, end_num + 1):
        # Pad the number with leading zeros if necessary (e.g., s01, s02, ..., s66)
        tarball_num = str(i).zfill(2)
        # Construct the relative URL for the current tarball
        relative_url = f"../lc_bulk/s{tarball_num}.tgz"
        # Construct the full URL by joining the base URL and the relative URL
        full_url = base_url + relative_url
        # Extract the filename from the relative URL
        filename = os.path.basename(relative_url)
        # Construct the local save path
        local_save_path = os.path.join(local_directory, filename)
        # Download the tarball
        print(f"Downloading {filename} from {full_url}...")
        download_tarball(full_url, local_save_path)
        print(f"Downloaded {filename} to {local_save_path}")

if __name__ == "__main__":
    main()
# Out:
# Downloading s01.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s01.tgz...
# Downloaded s01.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s01.tgz
# Downloading s02.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s02.tgz...
# Downloaded s02.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s02.tgz
# Downloading s03.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s03.tgz...
# Downloaded s03.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s03.tgz
# Downloading s04.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s04.tgz...
# Downloaded s04.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s04.tgz
# Downloading s05.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s05.tgz...
# Downloaded s05.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s05.tgz
# Downloading s06.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s06.tgz...
# Downloaded s06.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s06.tgz
# Downloading s07.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s07.tgz...
# Downloaded s07.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s07.tgz
# Downloading s08.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s08.tgz...
# Downloaded s08.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s08.tgz
# Downloading s09.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s09.tgz...
# Downloaded s09.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s09.tgz
# Downloading s10.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s10.tgz...
# Downloaded s10.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s10.tgz
# Downloading s11.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s11.tgz...
# Downloaded s11.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s11.tgz
# Downloading s12.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s12.tgz...
# Downloaded s12.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s12.tgz
# Downloading s13.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s13.tgz...
# Downloaded s13.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s13.tgz
# Downloading s14.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s14.tgz...
# Downloaded s14.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s14.tgz
# Downloading s15.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s15.tgz...
# Downloaded s15.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s15.tgz
# Downloading s16.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s16.tgz...
# Downloaded s16.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s16.tgz
# Downloading s17.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s17.tgz...
# Downloaded s17.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s17.tgz
# Downloading s18.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s18.tgz...
# Downloaded s18.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s18.tgz
# Downloading s19.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s19.tgz...
# Downloaded s19.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s19.tgz
# Downloading s20.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s20.tgz...
# Downloaded s20.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s20.tgz
# Downloading s21.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s21.tgz...
# Downloaded s21.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s21.tgz
# Downloading s22.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s22.tgz...
# Downloaded s22.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s22.tgz
# Downloading s23.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s23.tgz...
# Downloaded s23.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s23.tgz
# Downloading s24.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s24.tgz...
# Downloaded s24.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s24.tgz
# Downloading s25.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s25.tgz...
# Downloaded s25.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s25.tgz
# Downloading s26.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s26.tgz...
# Downloaded s26.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s26.tgz
# Downloading s27.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s27.tgz...
# Downloaded s27.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s27.tgz
# Downloading s28.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s28.tgz...
# Downloaded s28.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s28.tgz
# Downloading s29.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s29.tgz...
# Downloaded s29.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s29.tgz
# Downloading s30.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s30.tgz...
# Downloaded s30.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s30.tgz
# Downloading s31.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s31.tgz...
# Downloaded s31.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s31.tgz
# Downloading s32.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s32.tgz...
# Downloaded s32.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s32.tgz
# Downloading s33.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s33.tgz...
# Downloaded s33.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s33.tgz
# Downloading s34.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s34.tgz...
# Downloaded s34.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s34.tgz
# Downloading s35.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s35.tgz...
# Downloaded s35.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s35.tgz
# Downloading s36.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s36.tgz...
# Downloaded s36.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s36.tgz
# Downloading s37.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s37.tgz...
# Downloaded s37.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s37.tgz
# Downloading s38.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s38.tgz...
# Downloaded s38.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s38.tgz
# Downloading s39.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s39.tgz...
# Downloaded s39.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s39.tgz
# Downloading s40.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s40.tgz...
# Downloaded s40.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s40.tgz
# Downloading s41.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s41.tgz...
# Downloaded s41.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s41.tgz
# Downloading s42.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s42.tgz...
# Downloaded s42.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s42.tgz
# Downloading s43.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s43.tgz...
# Downloaded s43.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s43.tgz
# Downloading s44.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s44.tgz...
# Downloaded s44.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s44.tgz
# Downloading s45.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s45.tgz...
# Downloaded s45.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s45.tgz
# Downloading s46.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s46.tgz...
# Downloaded s46.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s46.tgz
# Downloading s47.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s47.tgz...
# Downloaded s47.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s47.tgz
# Downloading s48.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s48.tgz...
# Downloaded s48.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s48.tgz
# Downloading s49.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s49.tgz...
# Downloaded s49.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s49.tgz
# Downloading s50.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s50.tgz...
# Downloaded s50.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s50.tgz
# Downloading s51.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s51.tgz...
# Downloaded s51.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s51.tgz
# Downloading s52.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s52.tgz...
# Downloaded s52.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s52.tgz
# Downloading s53.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s53.tgz...
# Downloaded s53.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s53.tgz
# Downloading s54.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s54.tgz...
# Downloaded s54.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s54.tgz
# Downloading s55.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s55.tgz...
# Downloaded s55.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s55.tgz
# Downloading s56.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s56.tgz...
# Downloaded s56.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s56.tgz
# Downloading s57.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s57.tgz...
# Downloaded s57.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s57.tgz
# Downloading s58.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s58.tgz...
# Downloaded s58.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s58.tgz
# Downloading s59.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s59.tgz...
# Downloaded s59.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s59.tgz
# Downloading s60.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s60.tgz...
# Downloaded s60.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s60.tgz
# Downloading s61.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s61.tgz...
# Downloaded s61.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s61.tgz
# Downloading s62.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s62.tgz...
# Downloaded s62.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s62.tgz
# Downloading s63.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s63.tgz...
# Downloaded s63.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s63.tgz
# Downloading s64.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s64.tgz...
# Downloaded s64.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s64.tgz
# Downloading s65.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s65.tgz...
# Downloaded s65.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s65.tgz
# Downloading s66.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s66.tgz...
# Downloaded s66.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s66.tgz

# %%
import os
import tarfile

def extract_tarball(tgz_file, extraction_dir, delete_png=False, add_txt_extension=False):
    try:
        with tarfile.open(tgz_file, 'r:gz') as tar:
            tar.extractall(path=extraction_dir)
            if delete_png:
                # Delete .png files
                for member in tar.getmembers():
                    if member.name.endswith('.png'):
                        os.remove(os.path.join(extraction_dir, member.name))
            if add_txt_extension:
                # Rename files and add .txt extension
                for member in tar.getmembers():
                    if not member.name.endswith('.png'):
                        new_name = os.path.splitext(member.name)[0] + '.txt'
                        os.rename(os.path.join(extraction_dir, member.name), os.path.join(extraction_dir, new_name))
        print(f"Extracted {os.path.basename(tgz_file)} to {extraction_dir}")
    except tarfile.ReadError as e:
        print(f"Error extracting {os.path.basename(tgz_file)}:", e)

def main():
    # Local directory where the .tgz files are located
    local_directory = r"C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs"
    
    # Directory where you want to extract the .tgz files
    extraction_dir = r"C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs"
    
    # Create the extraction directory if it does not exist
    if not os.path.exists(extraction_dir):
        os.makedirs(extraction_dir)
    
    # Get a list of .tgz files in the local directory
    tgz_files = [f for f in os.listdir(local_directory) if f.endswith('.tgz')]
    
    # Extract each .tgz file
    for tgz_file in tgz_files:
        # Construct the full path of the .tgz file
        tgz_file_path = os.path.join(local_directory, tgz_file)
        # Extract the .tgz file and optionally delete .png files and add .txt extension
        extract_tarball(tgz_file_path, extraction_dir, delete_png=True, add_txt_extension=True)

if __name__ == "__main__":
    main()
# Out:
# Extracted s01.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s02.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s03.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s04.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s05.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s06.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s07.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s08.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s09.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s10.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s11.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s12.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s13.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s14.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s15.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s16.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s17.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s18.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s19.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s20.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s21.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s22.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s23.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s24.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s25.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s26.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s27.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s28.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s29.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s30.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s31.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s32.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s33.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s34.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s35.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s36.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s37.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s38.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s39.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s40.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s41.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s42.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s43.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s44.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s45.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s46.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s47.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s48.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s49.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s50.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s51.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s52.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s53.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s54.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s55.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s56.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s57.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s58.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s59.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s60.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s61.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s62.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s63.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s64.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s65.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s66.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs

# %%
import os
import tarfile
import re
import shutil

def extract_tarballs(tarball_directory, extraction_directory):
    for file_name in os.listdir(tarball_directory):
        if file_name.endswith(".tgz"):
            tarball_path = os.path.join(tarball_directory, file_name)
            with tarfile.open(tarball_path, 'r:gz') as tar:
                tar.extractall(extraction_directory)

def delete_png_files(directory):
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".png"):
                os.remove(os.path.join(root, file))

def collect_and_rename_txt_files(directory, output_directory):
    txt_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".txt"):
                txt_files.append(os.path.join(root, file))
    for txt_file in txt_files:
        # Extracting title from the file name
        title = re.findall(r'(?:20\d{2}[a-zA-Z]+)', txt_file)
        if title:
            new_name = os.path.join(output_directory, title[0] + ".txt")
            shutil.copy(txt_file, new_name)

def main():
    # Directory containing the tarballs
    tarball_directory = r"C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs"
    # Directory to extract tarballs
    extraction_directory = r"C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs"
    # Directory to collect TXT files
    txt_output_directory = r"C:\Users\nic51\Code_Repos\Tess\TXT_Files"

    # Extract tarballs
    extract_tarballs(tarball_directory, extraction_directory)

    # Delete PNG files
    print("Deleting PNG files...")
    delete_png_files(extraction_directory)
    print("PNG files deleted successfully")

    # Collect TXT files and rename them
    print("Collecting and renaming TXT files...")
    collect_and_rename_txt_files(extraction_directory, txt_output_directory)
    print("TXT files collected and renamed successfully")

if __name__ == "__main__":
    main()
# Out:
# Deleting PNG files...
# PNG files deleted successfully
# Collecting and renaming TXT files...
# TXT files collected and renamed successfully

# %%
import os
import requests

def download_tarball(url, save_path):
    response = requests.get(url)
    with open(save_path, 'wb') as f:
        f.write(response.content)

def main():
    # Base URL where the tarballs are located
    base_url = "https://tess.mit.edu/public/tesstransients/pages/"
    
    # Range of tarball numbers
    start_num = 1
    end_num = 66
    
    # Local directory where you want to save the tarballs
    local_directory = r"C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs"
    
    # Create the directory if it does not exist
    if not os.path.exists(local_directory):
        os.makedirs(local_directory)
    
    # Download each tarball file
    for i in range(start_num, end_num + 1):
        # Pad the number with leading zeros if necessary (e.g., s01, s02, ..., s66)
        tarball_num = str(i).zfill(2)
        # Construct the relative URL for the current tarball
        relative_url = f"../lc_bulk/s{tarball_num}.tgz"
        # Construct the full URL by joining the base URL and the relative URL
        full_url = base_url + relative_url
        # Extract the filename from the relative URL
        filename = os.path.basename(relative_url)
        # Construct the local save path
        local_save_path = os.path.join(local_directory, filename)
        # Download the tarball
        print(f"Downloading {filename} from {full_url}...")
        download_tarball(full_url, local_save_path)
        print(f"Downloaded {filename} to {local_save_path}")

if __name__ == "__main__":
    main()
# Out:
# Downloading s01.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s01.tgz...
# Downloaded s01.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s01.tgz
# Downloading s02.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s02.tgz...
# Downloaded s02.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s02.tgz
# Downloading s03.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s03.tgz...
# Downloaded s03.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s03.tgz
# Downloading s04.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s04.tgz...
# Downloaded s04.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s04.tgz
# Downloading s05.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s05.tgz...
# Downloaded s05.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s05.tgz
# Downloading s06.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s06.tgz...
# Downloaded s06.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s06.tgz
# Downloading s07.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s07.tgz...
# Downloaded s07.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s07.tgz
# Downloading s08.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s08.tgz...
# Downloaded s08.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s08.tgz
# Downloading s09.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s09.tgz...
# Downloaded s09.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s09.tgz
# Downloading s10.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s10.tgz...
# Downloaded s10.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s10.tgz
# Downloading s11.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s11.tgz...
# Downloaded s11.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s11.tgz
# Downloading s12.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s12.tgz...
# Downloaded s12.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s12.tgz
# Downloading s13.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s13.tgz...
# Downloaded s13.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s13.tgz
# Downloading s14.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s14.tgz...
# Downloaded s14.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s14.tgz
# Downloading s15.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s15.tgz...
# Downloaded s15.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s15.tgz
# Downloading s16.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s16.tgz...
# Downloaded s16.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s16.tgz
# Downloading s17.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s17.tgz...
# Downloaded s17.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s17.tgz
# Downloading s18.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s18.tgz...
# Downloaded s18.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s18.tgz
# Downloading s19.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s19.tgz...
# Downloaded s19.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s19.tgz
# Downloading s20.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s20.tgz...
# Downloaded s20.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s20.tgz
# Downloading s21.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s21.tgz...
# Downloaded s21.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s21.tgz
# Downloading s22.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s22.tgz...
# Downloaded s22.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s22.tgz
# Downloading s23.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s23.tgz...
# Downloaded s23.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s23.tgz
# Downloading s24.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s24.tgz...
# Downloaded s24.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s24.tgz
# Downloading s25.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s25.tgz...
# Downloaded s25.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s25.tgz
# Downloading s26.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s26.tgz...
# Downloaded s26.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s26.tgz
# Downloading s27.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s27.tgz...
# Downloaded s27.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s27.tgz
# Downloading s28.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s28.tgz...
# Downloaded s28.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s28.tgz
# Downloading s29.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s29.tgz...
# Downloaded s29.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s29.tgz
# Downloading s30.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s30.tgz...
# Downloaded s30.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s30.tgz
# Downloading s31.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s31.tgz...
# Downloaded s31.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s31.tgz
# Downloading s32.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s32.tgz...
# Downloaded s32.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s32.tgz
# Downloading s33.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s33.tgz...
# Downloaded s33.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s33.tgz
# Downloading s34.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s34.tgz...
# Downloaded s34.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s34.tgz
# Downloading s35.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s35.tgz...
# Downloaded s35.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s35.tgz
# Downloading s36.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s36.tgz...
# Downloaded s36.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s36.tgz
# Downloading s37.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s37.tgz...
# Downloaded s37.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s37.tgz
# Downloading s38.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s38.tgz...
# Downloaded s38.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s38.tgz
# Downloading s39.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s39.tgz...
# Downloaded s39.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s39.tgz
# Downloading s40.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s40.tgz...
# Downloaded s40.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s40.tgz
# Downloading s41.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s41.tgz...
# Downloaded s41.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s41.tgz
# Downloading s42.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s42.tgz...
# Downloaded s42.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s42.tgz
# Downloading s43.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s43.tgz...
# Downloaded s43.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s43.tgz
# Downloading s44.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s44.tgz...
# Downloaded s44.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s44.tgz
# Downloading s45.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s45.tgz...
# Downloaded s45.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s45.tgz
# Downloading s46.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s46.tgz...
# Downloaded s46.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s46.tgz
# Downloading s47.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s47.tgz...
# Downloaded s47.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s47.tgz
# Downloading s48.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s48.tgz...
# Downloaded s48.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s48.tgz
# Downloading s49.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s49.tgz...
# Downloaded s49.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s49.tgz
# Downloading s50.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s50.tgz...
# Downloaded s50.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s50.tgz
# Downloading s51.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s51.tgz...
# Downloaded s51.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s51.tgz
# Downloading s52.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s52.tgz...
# Downloaded s52.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s52.tgz
# Downloading s53.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s53.tgz...
# Downloaded s53.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s53.tgz
# Downloading s54.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s54.tgz...
# Downloaded s54.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s54.tgz
# Downloading s55.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s55.tgz...
# Downloaded s55.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s55.tgz
# Downloading s56.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s56.tgz...
# Downloaded s56.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s56.tgz
# Downloading s57.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s57.tgz...
# Downloaded s57.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s57.tgz
# Downloading s58.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s58.tgz...
# Downloaded s58.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s58.tgz
# Downloading s59.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s59.tgz...
# Downloaded s59.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s59.tgz
# Downloading s60.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s60.tgz...
# Downloaded s60.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s60.tgz
# Downloading s61.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s61.tgz...
# Downloaded s61.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s61.tgz
# Downloading s62.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s62.tgz...
# Downloaded s62.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s62.tgz
# Downloading s63.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s63.tgz...
# Downloaded s63.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s63.tgz
# Downloading s64.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s64.tgz...
# Downloaded s64.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s64.tgz
# Downloading s65.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s65.tgz...
# Downloaded s65.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s65.tgz
# Downloading s66.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s66.tgz...
# Downloaded s66.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s66.tgz

# %%
import os
import shutil

def collect_and_move_txt_files(extraction_directory, txt_output_directory):
    # Create the output directory if it doesn't exist
    os.makedirs(txt_output_directory, exist_ok=True)

    # Traverse each sector folder within the extraction directory
    for sector_folder in os.listdir(extraction_directory):
        sector_path = os.path.join(extraction_directory, sector_folder)
        if os.path.isdir(sector_path):
            # Traverse each file within the sector folder
            for root, _, files in os.walk(sector_path):
                for file in files:
                    if file.endswith(".txt"):
                        # Move the TXT file to the output directory
                        source_path = os.path.join(root, file)
                        destination_path = os.path.join(txt_output_directory, file)
                        shutil.move(source_path, destination_path)

def main():
    # Directory containing the extracted files from tarballs
    extraction_directory = r"C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs"
    # Directory to collect TXT files
    txt_output_directory = r"C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\TXT_Files"

    # Collect and move TXT files
    print("Collecting and moving TXT files...")
    collect_and_move_txt_files(extraction_directory, txt_output_directory)
    print("TXT files collected and moved successfully")

if __name__ == "__main__":
    main()
# Out:
# Collecting and moving TXT files...
# TXT files collected and moved successfully

# %%
import os
import tarfile

def extract_tarball(tgz_file, extraction_dir, delete_png=False, add_txt_extension=False):
    try:
        with tarfile.open(tgz_file, 'r:gz') as tar:
            tar.extractall(path=extraction_dir)
            if delete_png:
                # Delete .png files
                for member in tar.getmembers():
                    if member.name.endswith('.png'):
                        os.remove(os.path.join(extraction_dir, member.name))
            if add_txt_extension:
                # Rename files and add .txt extension
                for member in tar.getmembers():
                    if not member.name.endswith('.png'):
                        new_name = os.path.splitext(member.name)[0] + '.txt'
                        os.rename(os.path.join(extraction_dir, member.name), os.path.join(extraction_dir, new_name))
        print(f"Extracted {os.path.basename(tgz_file)} to {extraction_dir}")
    except tarfile.ReadError as e:
        print(f"Error extracting {os.path.basename(tgz_file)}:", e)

def main():
    # Local directory where the .tgz files are located
    local_directory = r"C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs"
    
    # Directory where you want to extract the .tgz files
    extraction_dir = r"C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs"
    
    # Create the extraction directory if it does not exist
    if not os.path.exists(extraction_dir):
        os.makedirs(extraction_dir)
    
    # Get a list of .tgz files in the local directory
    tgz_files = [f for f in os.listdir(local_directory) if f.endswith('.tgz')]
    
    # Extract each .tgz file
    for tgz_file in tgz_files:
        # Construct the full path of the .tgz file
        tgz_file_path = os.path.join(local_directory, tgz_file)
        # Extract the .tgz file and optionally delete .png files and add .txt extension
        extract_tarball(tgz_file_path, extraction_dir, delete_png=True, add_txt_extension=True)

if __name__ == "__main__":
    main()
# Out:
# Extracted s01.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s02.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s03.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s04.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s05.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s06.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s07.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s08.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s09.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s10.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s11.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s12.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s13.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s14.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s15.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s16.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s17.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s18.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s19.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s20.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s21.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s22.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s23.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s24.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s25.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s26.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s27.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s28.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s29.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s30.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s31.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s32.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s33.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s34.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s35.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s36.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s37.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s38.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s39.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s40.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s41.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s42.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s43.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s44.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s45.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s46.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s47.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s48.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s49.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s50.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s51.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s52.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s53.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s54.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s55.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s56.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s57.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s58.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s59.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s60.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s61.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s62.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s63.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s64.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s65.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s66.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs

# %%
import os

def remove_suffixes(txt_files_directory):
    # Traverse each file in the directory
    for file_name in os.listdir(txt_files_directory):
        file_path = os.path.join(txt_files_directory, file_name)
        # Check if the file ends with "_cleaned.txt"
        if file_name.endswith("_cleaned.txt"):
            # Remove the "_cleaned" suffix from the file name
            new_file_name = file_name.replace("_cleaned.txt", ".txt")
            os.rename(file_path, os.path.join(txt_files_directory, new_file_name))
            print(f"Renamed {file_name} to {new_file_name}")
        # Check if the file starts with "lc"
        elif file_name.startswith("lc_"):
            # Remove the "lc" prefix from the file name
            new_file_name = file_name.replace("lc", "")
            os.rename(file_path, os.path.join(txt_files_directory, new_file_name))
            print(f"Renamed {file_name} to {new_file_name}")

def main():
    # Directory containing the TXT files
    txt_files_directory = r"C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\TXT_Files"

    # Remove "_cleaned" and "lc" from file names
    print("Removing '_cleaned' and 'lc_' from file names...")
    remove_suffixes(txt_files_directory)
    print("Suffixes removed successfully")

if __name__ == "__main__":
    main()
# Out:
# Removing '_cleaned' and 'lc_' from file names...
# Renamed lc_2018eel_cleaned.txt to lc_2018eel.txt
# Renamed lc_2018emt_cleaned.txt to lc_2018emt.txt
# Renamed lc_2018eny_cleaned.txt to lc_2018eny.txt
# Renamed lc_2018eoa_cleaned.txt to lc_2018eoa.txt
# Renamed lc_2018eoc_cleaned.txt to lc_2018eoc.txt
# Renamed lc_2018eod_cleaned.txt to lc_2018eod.txt
# Renamed lc_2018eph_cleaned.txt to lc_2018eph.txt
# Renamed lc_2018eqo_cleaned.txt to lc_2018eqo.txt
# Renamed lc_2018esp_cleaned.txt to lc_2018esp.txt
# Renamed lc_2018esw_cleaned.txt to lc_2018esw.txt
# Renamed lc_2018evo_cleaned.txt to lc_2018evo.txt
# Renamed lc_2018exc_cleaned.txt to lc_2018exc.txt
# Renamed lc_2018fbm_cleaned.txt to lc_2018fbm.txt
# Renamed lc_2018fdw_cleaned.txt to lc_2018fdw.txt
# Renamed lc_2018fdx_cleaned.txt to lc_2018fdx.txt
# Renamed lc_2018fgb_cleaned.txt to lc_2018fgb.txt
# Renamed lc_2018fhs_cleaned.txt to lc_2018fhs.txt
# Renamed lc_2018fhw_cleaned.txt to lc_2018fhw.txt
# Renamed lc_2018fhw_detrended_cleaned.txt to lc_2018fhw_detrended.txt
# Renamed lc_2018flj_cleaned.txt to lc_2018flj.txt
# Renamed lc_2018fll_cleaned.txt to lc_2018fll.txt
# Renamed lc_2018flq_cleaned.txt to lc_2018flq.txt
# Renamed lc_2018flr_cleaned.txt to lc_2018flr.txt
# Renamed lc_2018flt_cleaned.txt to lc_2018flt.txt
# Renamed lc_2018flz_cleaned.txt to lc_2018flz.txt
# Renamed lc_2018fmg_cleaned.txt to lc_2018fmg.txt
# Renamed lc_2018fmm_cleaned.txt to lc_2018fmm.txt
# Renamed lc_2018fmn_cleaned.txt to lc_2018fmn.txt
# Renamed lc_2018fns_cleaned.txt to lc_2018fns.txt
# Renamed lc_2018fqn_cleaned.txt to lc_2018fqn.txt
# Renamed lc_2018ftf_cleaned.txt to lc_2018ftf.txt
# Renamed lc_2018fub_cleaned.txt to lc_2018fub.txt
# Renamed lc_2018fvi_cleaned.txt to lc_2018fvi.txt
# Renamed lc_2018fvi_detrended_cleaned.txt to lc_2018fvi_detrended.txt
# Renamed lc_2018fwd_cleaned.txt to lc_2018fwd.txt
# Renamed lc_2018fwi_cleaned.txt to lc_2018fwi.txt
# Renamed lc_2018fwk_cleaned.txt to lc_2018fwk.txt
# Renamed lc_2018fwm_cleaned.txt to lc_2018fwm.txt
# Renamed lc_2018fwr_cleaned.txt to lc_2018fwr.txt
# Renamed lc_2018fxj_cleaned.txt to lc_2018fxj.txt
# Renamed lc_2018fxl_cleaned.txt to lc_2018fxl.txt
# Renamed lc_2018fzi_cleaned.txt to lc_2018fzi.txt
# Renamed lc_2018gey_cleaned.txt to lc_2018gey.txt
# Renamed lc_2018gfj_cleaned.txt to lc_2018gfj.txt
# Renamed lc_2018gfk_cleaned.txt to lc_2018gfk.txt
# Renamed lc_2018gku_cleaned.txt to lc_2018gku.txt
# Renamed lc_2018glp_cleaned.txt to lc_2018glp.txt
# Renamed lc_2018glq_cleaned.txt to lc_2018glq.txt
# Renamed lc_2018glv_cleaned.txt to lc_2018glv.txt
# Renamed lc_2018glw_cleaned.txt to lc_2018glw.txt
# Renamed lc_2018goa_cleaned.txt to lc_2018goa.txt
# Renamed lc_2018gqc_cleaned.txt to lc_2018gqc.txt
# Renamed lc_2018grv_cleaned.txt to lc_2018grv.txt
# Renamed lc_2018gsg_cleaned.txt to lc_2018gsg.txt
# Renamed lc_2018gty_cleaned.txt to lc_2018gty.txt
# Renamed lc_2018gum_cleaned.txt to lc_2018gum.txt
# Renamed lc_2018gxi_cleaned.txt to lc_2018gxi.txt
# Renamed lc_2018hac_cleaned.txt to lc_2018hac.txt
# Renamed lc_2018har_cleaned.txt to lc_2018har.txt
# Renamed lc_2018has_cleaned.txt to lc_2018has.txt
# Renamed lc_2018hbw_cleaned.txt to lc_2018hbw.txt
# Renamed lc_2018hdl_cleaned.txt to lc_2018hdl.txt
# Renamed lc_2018hdo_cleaned.txt to lc_2018hdo.txt
# Renamed lc_2018hdq_cleaned.txt to lc_2018hdq.txt
# Renamed lc_2018hgc_cleaned.txt to lc_2018hgc.txt
# Renamed lc_2018hgi_cleaned.txt to lc_2018hgi.txt
# Renamed lc_2018hgl_cleaned.txt to lc_2018hgl.txt
# Renamed lc_2018hib_cleaned.txt to lc_2018hib.txt
# Renamed lc_2018hib_detrended_cleaned.txt to lc_2018hib_detrended.txt
# Renamed lc_2018hjo_cleaned.txt to lc_2018hjo.txt
# Renamed lc_2018hjr_cleaned.txt to lc_2018hjr.txt
# Renamed lc_2018hka_cleaned.txt to lc_2018hka.txt
# Renamed lc_2018hkb_cleaned.txt to lc_2018hkb.txt
# Renamed lc_2018hkh_cleaned.txt to lc_2018hkh.txt
# Renamed lc_2018hks_cleaned.txt to lc_2018hks.txt
# Renamed lc_2018hkx_cleaned.txt to lc_2018hkx.txt
# Renamed lc_2018hlp_cleaned.txt to lc_2018hlp.txt
# Renamed lc_2018hmo_cleaned.txt to lc_2018hmo.txt
# Renamed lc_2018hnc_cleaned.txt to lc_2018hnc.txt
# Renamed lc_2018hnq_cleaned.txt to lc_2018hnq.txt
# Renamed lc_2018hoc_cleaned.txt to lc_2018hoc.txt
# Renamed lc_2018hpd_cleaned.txt to lc_2018hpd.txt
# Renamed lc_2018hpj_cleaned.txt to lc_2018hpj.txt
# Renamed lc_2018hps_cleaned.txt to lc_2018hps.txt
# Renamed lc_2018hpu_cleaned.txt to lc_2018hpu.txt
# Renamed lc_2018hql_cleaned.txt to lc_2018hql.txt
# Renamed lc_2018hrs_cleaned.txt to lc_2018hrs.txt
# Renamed lc_2018hsf_cleaned.txt to lc_2018hsf.txt
# Renamed lc_2018hsq_cleaned.txt to lc_2018hsq.txt
# Renamed lc_2018hss_cleaned.txt to lc_2018hss.txt
# Renamed lc_2018hss_detrended_cleaned.txt to lc_2018hss_detrended.txt
# Renamed lc_2018hsz_cleaned.txt to lc_2018hsz.txt
# Renamed lc_2018hte_cleaned.txt to lc_2018hte.txt
# Renamed lc_2018huc_cleaned.txt to lc_2018huc.txt
# Renamed lc_2018hue_cleaned.txt to lc_2018hue.txt
# Renamed lc_2018hum_cleaned.txt to lc_2018hum.txt
# Renamed lc_2018hxq_cleaned.txt to lc_2018hxq.txt
# Renamed lc_2018hyq_cleaned.txt to lc_2018hyq.txt
# Renamed lc_2018hyx_cleaned.txt to lc_2018hyx.txt
# Renamed lc_2018hyy_cleaned.txt to lc_2018hyy.txt
# Renamed lc_2018hzh_cleaned.txt to lc_2018hzh.txt
# Renamed lc_2018ien_cleaned.txt to lc_2018ien.txt
# Renamed lc_2018ieu_cleaned.txt to lc_2018ieu.txt
# Renamed lc_2018iez_cleaned.txt to lc_2018iez.txt
# Renamed lc_2018ifa_cleaned.txt to lc_2018ifa.txt
# Renamed lc_2018ifh_cleaned.txt to lc_2018ifh.txt
# Renamed lc_2018ifm_cleaned.txt to lc_2018ifm.txt
# Renamed lc_2018ift_cleaned.txt to lc_2018ift.txt
# Renamed lc_2018ihp_cleaned.txt to lc_2018ihp.txt
# Renamed lc_2018ihq_cleaned.txt to lc_2018ihq.txt
# Renamed lc_2018iht_cleaned.txt to lc_2018iht.txt
# Renamed lc_2018iin_cleaned.txt to lc_2018iin.txt
# Renamed lc_2018ijn_cleaned.txt to lc_2018ijn.txt
# Renamed lc_2018ime_cleaned.txt to lc_2018ime.txt
# Renamed lc_2018ioa_cleaned.txt to lc_2018ioa.txt
# Renamed lc_2018iti_cleaned.txt to lc_2018iti.txt
# Renamed lc_2018itr_cleaned.txt to lc_2018itr.txt
# Renamed lc_2018iuj_cleaned.txt to lc_2018iuj.txt
# Renamed lc_2018iwg_cleaned.txt to lc_2018iwg.txt
# Renamed lc_2018iwl_cleaned.txt to lc_2018iwl.txt
# Renamed lc_2018iyh_cleaned.txt to lc_2018iyh.txt
# Renamed lc_2018iyx_cleaned.txt to lc_2018iyx.txt
# Renamed lc_2018izg_cleaned.txt to lc_2018izg.txt
# Renamed lc_2018izr_cleaned.txt to lc_2018izr.txt
# Renamed lc_2018izt_cleaned.txt to lc_2018izt.txt
# Renamed lc_2018jad_cleaned.txt to lc_2018jad.txt
# Renamed lc_2018jbn_cleaned.txt to lc_2018jbn.txt
# Renamed lc_2018jco_cleaned.txt to lc_2018jco.txt
# Renamed lc_2018jdc_cleaned.txt to lc_2018jdc.txt
# Renamed lc_2018jeb_cleaned.txt to lc_2018jeb.txt
# Renamed lc_2018jej_cleaned.txt to lc_2018jej.txt
# Renamed lc_2018jfk_cleaned.txt to lc_2018jfk.txt
# Renamed lc_2018jgq_cleaned.txt to lc_2018jgq.txt
# Renamed lc_2018jhc_cleaned.txt to lc_2018jhc.txt
# Renamed lc_2018jhq_cleaned.txt to lc_2018jhq.txt
# Renamed lc_2018jih_cleaned.txt to lc_2018jih.txt
# Renamed lc_2018jjc_cleaned.txt to lc_2018jjc.txt
# Renamed lc_2018jjd_cleaned.txt to lc_2018jjd.txt
# Renamed lc_2018jjh_cleaned.txt to lc_2018jjh.txt
# Renamed lc_2018jjs_cleaned.txt to lc_2018jjs.txt
# Renamed lc_2018jju_cleaned.txt to lc_2018jju.txt
# Renamed lc_2018jkg_cleaned.txt to lc_2018jkg.txt
# Renamed lc_2018jms_cleaned.txt to lc_2018jms.txt
# Renamed lc_2018jmt_cleaned.txt to lc_2018jmt.txt
# Renamed lc_2018jnd_cleaned.txt to lc_2018jnd.txt
# Renamed lc_2018jpy_cleaned.txt to lc_2018jpy.txt
# Renamed lc_2018jri_cleaned.txt to lc_2018jri.txt
# Renamed lc_2018jro_cleaned.txt to lc_2018jro.txt
# Renamed lc_2018jsl_cleaned.txt to lc_2018jsl.txt
# Renamed lc_2018jtu_cleaned.txt to lc_2018jtu.txt
# Renamed lc_2018jtv_cleaned.txt to lc_2018jtv.txt
# Renamed lc_2018jwd_cleaned.txt to lc_2018jwd.txt
# Renamed lc_2018jwg_cleaned.txt to lc_2018jwg.txt
# Renamed lc_2018jwh_cleaned.txt to lc_2018jwh.txt
# Renamed lc_2018jwi_cleaned.txt to lc_2018jwi.txt
# Renamed lc_2018jwj_cleaned.txt to lc_2018jwj.txt
# Renamed lc_2018kah_cleaned.txt to lc_2018kah.txt
# Renamed lc_2018kao_cleaned.txt to lc_2018kao.txt
# Renamed lc_2018kbi_cleaned.txt to lc_2018kbi.txt
# Renamed lc_2018kbq_cleaned.txt to lc_2018kbq.txt
# Renamed lc_2018kcu_cleaned.txt to lc_2018kcu.txt
# Renamed lc_2018kfv_cleaned.txt to lc_2018kfv.txt
# Renamed lc_2018kfv_detrended_cleaned.txt to lc_2018kfv_detrended.txt
# Renamed lc_2018kgg_cleaned.txt to lc_2018kgg.txt
# Renamed lc_2018kib_cleaned.txt to lc_2018kib.txt
# Renamed lc_2018kif_cleaned.txt to lc_2018kif.txt
# Renamed lc_2018kig_cleaned.txt to lc_2018kig.txt
# Renamed lc_2018kih_cleaned.txt to lc_2018kih.txt
# Renamed lc_2018kjp_cleaned.txt to lc_2018kjp.txt
# Renamed lc_2018knl_cleaned.txt to lc_2018knl.txt
# Renamed lc_2018koy_cleaned.txt to lc_2018koy.txt
# Renamed lc_2018kpc_cleaned.txt to lc_2018kpc.txt
# Renamed lc_2018kqk_cleaned.txt to lc_2018kqk.txt
# Renamed lc_2018kqz_cleaned.txt to lc_2018kqz.txt
# Renamed lc_2018krw_cleaned.txt to lc_2018krw.txt
# Renamed lc_2018ksi_cleaned.txt to lc_2018ksi.txt
# Renamed lc_2018ksr_cleaned.txt to lc_2018ksr.txt
# Renamed lc_2018kuo_cleaned.txt to lc_2018kuo.txt
# Renamed lc_2018kuv_cleaned.txt to lc_2018kuv.txt
# Renamed lc_2018kvc_cleaned.txt to lc_2018kvc.txt
# Renamed lc_2018kvr_cleaned.txt to lc_2018kvr.txt
# Renamed lc_2018kvz_cleaned.txt to lc_2018kvz.txt
# Renamed lc_2018kwm_cleaned.txt to lc_2018kwm.txt
# Renamed lc_2018kwo_cleaned.txt to lc_2018kwo.txt
# Renamed lc_2018lab_cleaned.txt to lc_2018lab.txt
# Renamed lc_2018lad_cleaned.txt to lc_2018lad.txt
# Renamed lc_2018lit_cleaned.txt to lc_2018lit.txt
# Renamed lc_2018lla_cleaned.txt to lc_2018lla.txt
# Renamed lc_2018lml_cleaned.txt to lc_2018lml.txt
# Renamed lc_2018lne_cleaned.txt to lc_2018lne.txt
# Renamed lc_2018lot_cleaned.txt to lc_2018lot.txt
# Renamed lc_2019aan_cleaned.txt to lc_2019aan.txt
# Renamed lc_2019aaq_cleaned.txt to lc_2019aaq.txt
# Renamed lc_2019aay_cleaned.txt to lc_2019aay.txt
# Renamed lc_2019aba_cleaned.txt to lc_2019aba.txt
# Renamed lc_2019abb_cleaned.txt to lc_2019abb.txt
# Renamed lc_2019abc_cleaned.txt to lc_2019abc.txt
# Renamed lc_2019aby_cleaned.txt to lc_2019aby.txt
# Renamed lc_2019ach_cleaned.txt to lc_2019ach.txt
# Renamed lc_2019aeg_cleaned.txt to lc_2019aeg.txt
# Renamed lc_2019aen_cleaned.txt to lc_2019aen.txt
# Renamed lc_2019aeu_cleaned.txt to lc_2019aeu.txt
# Renamed lc_2019agu_cleaned.txt to lc_2019agu.txt
# Renamed lc_2019ahk_cleaned.txt to lc_2019ahk.txt
# Renamed lc_2019aib_cleaned.txt to lc_2019aib.txt
# Renamed lc_2019aih_cleaned.txt to lc_2019aih.txt
# Renamed lc_2019ait_cleaned.txt to lc_2019ait.txt
# Renamed lc_2019ajf_cleaned.txt to lc_2019ajf.txt
# Renamed lc_2019ako_cleaned.txt to lc_2019ako.txt
# Renamed lc_2019alb_cleaned.txt to lc_2019alb.txt
# Renamed lc_2019alj_cleaned.txt to lc_2019alj.txt
# Renamed lc_2019all_cleaned.txt to lc_2019all.txt
# Renamed lc_2019alq_cleaned.txt to lc_2019alq.txt
# Renamed lc_2019alv_cleaned.txt to lc_2019alv.txt
# Renamed lc_2019ane_cleaned.txt to lc_2019ane.txt
# Renamed lc_2019ank_cleaned.txt to lc_2019ank.txt
# Renamed lc_2019any_cleaned.txt to lc_2019any.txt
# Renamed lc_2019aqe_cleaned.txt to lc_2019aqe.txt
# Renamed lc_2019arw_cleaned.txt to lc_2019arw.txt
# Renamed lc_2019atc_cleaned.txt to lc_2019atc.txt
# Renamed lc_2019auk_cleaned.txt to lc_2019auk.txt
# Renamed lc_2019axh_cleaned.txt to lc_2019axh.txt
# Renamed lc_2019axj_cleaned.txt to lc_2019axj.txt
# Renamed lc_2019ayy_cleaned.txt to lc_2019ayy.txt
# Renamed lc_2019azi_cleaned.txt to lc_2019azi.txt
# Renamed lc_2019bap_cleaned.txt to lc_2019bap.txt
# Renamed lc_2019bca_cleaned.txt to lc_2019bca.txt
# Renamed lc_2019bcp_cleaned.txt to lc_2019bcp.txt
# Renamed lc_2019bcu_cleaned.txt to lc_2019bcu.txt
# Renamed lc_2019bea_cleaned.txt to lc_2019bea.txt
# Renamed lc_2019beb_cleaned.txt to lc_2019beb.txt
# Renamed lc_2019bes_cleaned.txt to lc_2019bes.txt
# Renamed lc_2019bet_cleaned.txt to lc_2019bet.txt
# Renamed lc_2019beu_cleaned.txt to lc_2019beu.txt
# Renamed lc_2019bfb_cleaned.txt to lc_2019bfb.txt
# Renamed lc_2019bfd_cleaned.txt to lc_2019bfd.txt
# Renamed lc_2019bfz_cleaned.txt to lc_2019bfz.txt
# Renamed lc_2019bgo_cleaned.txt to lc_2019bgo.txt
# Renamed lc_2019bgp_cleaned.txt to lc_2019bgp.txt
# Renamed lc_2019bip_cleaned.txt to lc_2019bip.txt
# Renamed lc_2019biq_cleaned.txt to lc_2019biq.txt
# Renamed lc_2019biu_cleaned.txt to lc_2019biu.txt
# Renamed lc_2019bnk_cleaned.txt to lc_2019bnk.txt
# Renamed lc_2019boo_cleaned.txt to lc_2019boo.txt
# Renamed lc_2019bop_cleaned.txt to lc_2019bop.txt
# Renamed lc_2019boq_cleaned.txt to lc_2019boq.txt
# Renamed lc_2019box_cleaned.txt to lc_2019box.txt
# Renamed lc_2019bqk_cleaned.txt to lc_2019bqk.txt
# Renamed lc_2019bql_cleaned.txt to lc_2019bql.txt
# Renamed lc_2019bsw_cleaned.txt to lc_2019bsw.txt
# Renamed lc_2019bvp_cleaned.txt to lc_2019bvp.txt
# Renamed lc_2019bwb_cleaned.txt to lc_2019bwb.txt
# Renamed lc_2019bwo_cleaned.txt to lc_2019bwo.txt
# Renamed lc_2019bwu_cleaned.txt to lc_2019bwu.txt
# Renamed lc_2019bxg_cleaned.txt to lc_2019bxg.txt
# Renamed lc_2019bxi_cleaned.txt to lc_2019bxi.txt
# Renamed lc_2019bxl_cleaned.txt to lc_2019bxl.txt
# Renamed lc_2019caa_cleaned.txt to lc_2019caa.txt
# Renamed lc_2019cdy_cleaned.txt to lc_2019cdy.txt
# Renamed lc_2019cgy_cleaned.txt to lc_2019cgy.txt
# Renamed lc_2019cix_cleaned.txt to lc_2019cix.txt
# Renamed lc_2019cjp_cleaned.txt to lc_2019cjp.txt
# Renamed lc_2019cjz_cleaned.txt to lc_2019cjz.txt
# Renamed lc_2019cj_cleaned.txt to lc_2019cj.txt
# Renamed lc_2019clt_cleaned.txt to lc_2019clt.txt
# Renamed lc_2019clu_cleaned.txt to lc_2019clu.txt
# Renamed lc_2019cmb_cleaned.txt to lc_2019cmb.txt
# Renamed lc_2019cmf_cleaned.txt to lc_2019cmf.txt
# Renamed lc_2019cml_cleaned.txt to lc_2019cml.txt
# Renamed lc_2019coc_cleaned.txt to lc_2019coc.txt
# Renamed lc_2019con_cleaned.txt to lc_2019con.txt
# Renamed lc_2019cos_cleaned.txt to lc_2019cos.txt
# Renamed lc_2019cot_cleaned.txt to lc_2019cot.txt
# Renamed lc_2019cou_cleaned.txt to lc_2019cou.txt
# Renamed lc_2019cow_cleaned.txt to lc_2019cow.txt
# Renamed lc_2019coz_cleaned.txt to lc_2019coz.txt
# Renamed lc_2019cqf_cleaned.txt to lc_2019cqf.txt
# Renamed lc_2019cqi_cleaned.txt to lc_2019cqi.txt
# Renamed lc_2019cqk_cleaned.txt to lc_2019cqk.txt
# Renamed lc_2019cql_cleaned.txt to lc_2019cql.txt
# Renamed lc_2019crw_cleaned.txt to lc_2019crw.txt
# Renamed lc_2019crx_cleaned.txt to lc_2019crx.txt
# Renamed lc_2019crz_cleaned.txt to lc_2019crz.txt
# Renamed lc_2019cwr_cleaned.txt to lc_2019cwr.txt
# Renamed lc_2019cxt_cleaned.txt to lc_2019cxt.txt
# Renamed lc_2019czn_cleaned.txt to lc_2019czn.txt
# Renamed lc_2019dbm_cleaned.txt to lc_2019dbm.txt
# Renamed lc_2019dcj_cleaned.txt to lc_2019dcj.txt
# Renamed lc_2019ddc_cleaned.txt to lc_2019ddc.txt
# Renamed lc_2019deo_cleaned.txt to lc_2019deo.txt
# Renamed lc_2019dfr_cleaned.txt to lc_2019dfr.txt
# Renamed lc_2019dhm_cleaned.txt to lc_2019dhm.txt
# Renamed lc_2019dhz_cleaned.txt to lc_2019dhz.txt
# Renamed lc_2019din_cleaned.txt to lc_2019din.txt
# Renamed lc_2019dit_cleaned.txt to lc_2019dit.txt
# Renamed lc_2019djd_cleaned.txt to lc_2019djd.txt
# Renamed lc_2019dji_cleaned.txt to lc_2019dji.txt
# Renamed lc_2019dke_cleaned.txt to lc_2019dke.txt
# Renamed lc_2019dng_cleaned.txt to lc_2019dng.txt
# Renamed lc_2019dns_cleaned.txt to lc_2019dns.txt
# Renamed lc_2019dov_cleaned.txt to lc_2019dov.txt
# Renamed lc_2019dpd_cleaned.txt to lc_2019dpd.txt
# Renamed lc_2019dpz_cleaned.txt to lc_2019dpz.txt
# Renamed lc_2019dqg_cleaned.txt to lc_2019dqg.txt
# Renamed lc_2019dsn_cleaned.txt to lc_2019dsn.txt
# Renamed lc_2019dtv_cleaned.txt to lc_2019dtv.txt
# Renamed lc_2019dut_cleaned.txt to lc_2019dut.txt
# Renamed lc_2019dwl_cleaned.txt to lc_2019dwl.txt
# Renamed lc_2019dww_cleaned.txt to lc_2019dww.txt
# Renamed lc_2019dzc_cleaned.txt to lc_2019dzc.txt
# Renamed lc_2019dzs_cleaned.txt to lc_2019dzs.txt
# Renamed lc_2019ebe_cleaned.txt to lc_2019ebe.txt
# Renamed lc_2019ebh_cleaned.txt to lc_2019ebh.txt
# Renamed lc_2019ecn_cleaned.txt to lc_2019ecn.txt
# Renamed lc_2019edh_cleaned.txt to lc_2019edh.txt
# Renamed lc_2019egw_cleaned.txt to lc_2019egw.txt
# Renamed lc_2019ehv_cleaned.txt to lc_2019ehv.txt
# Renamed lc_2019ehx_cleaned.txt to lc_2019ehx.txt
# Renamed lc_2019ehy_cleaned.txt to lc_2019ehy.txt
# Renamed lc_2019ekk_cleaned.txt to lc_2019ekk.txt
# Renamed lc_2019ekn_cleaned.txt to lc_2019ekn.txt
# Renamed lc_2019ekp_cleaned.txt to lc_2019ekp.txt
# Renamed lc_2019erz_cleaned.txt to lc_2019erz.txt
# Renamed lc_2019esa_cleaned.txt to lc_2019esa.txt
# Renamed lc_2019esl_cleaned.txt to lc_2019esl.txt
# Renamed lc_2019esm_cleaned.txt to lc_2019esm.txt
# Renamed lc_2019exu_cleaned.txt to lc_2019exu.txt
# Renamed lc_2019fcc_cleaned.txt to lc_2019fcc.txt
# Renamed lc_2019fir_cleaned.txt to lc_2019fir.txt
# Renamed lc_2019fis_cleaned.txt to lc_2019fis.txt
# Renamed lc_2019fjs_cleaned.txt to lc_2019fjs.txt
# Renamed lc_2019fp_cleaned.txt to lc_2019fp.txt
# Renamed lc_2019gac_cleaned.txt to lc_2019gac.txt
# Renamed lc_2019gak_cleaned.txt to lc_2019gak.txt
# Renamed lc_2019gb_cleaned.txt to lc_2019gb.txt
# Renamed lc_2019gdc_cleaned.txt to lc_2019gdc.txt
# Renamed lc_2019gdg_cleaned.txt to lc_2019gdg.txt
# Renamed lc_2019gdy_cleaned.txt to lc_2019gdy.txt
# Renamed lc_2019gg_cleaned.txt to lc_2019gg.txt
# Renamed lc_2019gn_cleaned.txt to lc_2019gn.txt
# Renamed lc_2019gqv_cleaned.txt to lc_2019gqv.txt
# Renamed lc_2019guh_cleaned.txt to lc_2019guh.txt
# Renamed lc_2019gvc_cleaned.txt to lc_2019gvc.txt
# Renamed lc_2019gvi_cleaned.txt to lc_2019gvi.txt
# Renamed lc_2019gvp_cleaned.txt to lc_2019gvp.txt
# Renamed lc_2019gwq_cleaned.txt to lc_2019gwq.txt
# Renamed lc_2019gws_cleaned.txt to lc_2019gws.txt
# Renamed lc_2019gyb_cleaned.txt to lc_2019gyb.txt
# Renamed lc_2019gzu_cleaned.txt to lc_2019gzu.txt
# Renamed lc_2019hcn_cleaned.txt to lc_2019hcn.txt
# Renamed lc_2019hit_cleaned.txt to lc_2019hit.txt
# Renamed lc_2019hkx_cleaned.txt to lc_2019hkx.txt
# Renamed lc_2019hlb_cleaned.txt to lc_2019hlb.txt
# Renamed lc_2019hmh_cleaned.txt to lc_2019hmh.txt
# Renamed lc_2019hnp_cleaned.txt to lc_2019hnp.txt
# Renamed lc_2019hpg_cleaned.txt to lc_2019hpg.txt
# Renamed lc_2019hrs_cleaned.txt to lc_2019hrs.txt
# Renamed lc_2019hsc_cleaned.txt to lc_2019hsc.txt
# Renamed lc_2019hsl_cleaned.txt to lc_2019hsl.txt
# Renamed lc_2019hsq_cleaned.txt to lc_2019hsq.txt
# Renamed lc_2019htm_cleaned.txt to lc_2019htm.txt
# Renamed lc_2019htv_cleaned.txt to lc_2019htv.txt
# Renamed lc_2019htx_cleaned.txt to lc_2019htx.txt
# Renamed lc_2019hvx_cleaned.txt to lc_2019hvx.txt
# Renamed lc_2019hyu_cleaned.txt to lc_2019hyu.txt
# Renamed lc_2019hzo_cleaned.txt to lc_2019hzo.txt
# Renamed lc_2019hzq_cleaned.txt to lc_2019hzq.txt
# Renamed lc_2019iac_cleaned.txt to lc_2019iac.txt
# Renamed lc_2019iar_cleaned.txt to lc_2019iar.txt
# Renamed lc_2019ibg_cleaned.txt to lc_2019ibg.txt
# Renamed lc_2019ifd_cleaned.txt to lc_2019ifd.txt
# Renamed lc_2019ify_cleaned.txt to lc_2019ify.txt
# Renamed lc_2019ihi_cleaned.txt to lc_2019ihi.txt
# Renamed lc_2019iio_cleaned.txt to lc_2019iio.txt
# Renamed lc_2019iiv_cleaned.txt to lc_2019iiv.txt
# Renamed lc_2019iy_cleaned.txt to lc_2019iy.txt
# Renamed lc_2019jh_cleaned.txt to lc_2019jh.txt
# Renamed lc_2019jom_cleaned.txt to lc_2019jom.txt
# Renamed lc_2019jor_cleaned.txt to lc_2019jor.txt
# Renamed lc_2019jyj_cleaned.txt to lc_2019jyj.txt
# Renamed lc_2019kag_cleaned.txt to lc_2019kag.txt
# Renamed lc_2019khg_cleaned.txt to lc_2019khg.txt
# Renamed lc_2019kh_cleaned.txt to lc_2019kh.txt
# Renamed lc_2019kim_cleaned.txt to lc_2019kim.txt
# Renamed lc_2019kli_cleaned.txt to lc_2019kli.txt
# Renamed lc_2019kll_cleaned.txt to lc_2019kll.txt
# Renamed lc_2019kqd_cleaned.txt to lc_2019kqd.txt
# Renamed lc_2019kqq_cleaned.txt to lc_2019kqq.txt
# Renamed lc_2019krd_cleaned.txt to lc_2019krd.txt
# Renamed lc_2019krj_cleaned.txt to lc_2019krj.txt
# Renamed lc_2019kt_cleaned.txt to lc_2019kt.txt
# Renamed lc_2019kvh_cleaned.txt to lc_2019kvh.txt
# Renamed lc_2019kwc_cleaned.txt to lc_2019kwc.txt
# Renamed lc_2019lbm_cleaned.txt to lc_2019lbm.txt
# Renamed lc_2019llb_cleaned.txt to lc_2019llb.txt
# Renamed lc_2019lld_cleaned.txt to lc_2019lld.txt
# Renamed lc_2019llg_cleaned.txt to lc_2019llg.txt
# Renamed lc_2019lli_cleaned.txt to lc_2019lli.txt
# Renamed lc_2019lls_cleaned.txt to lc_2019lls.txt
# Renamed lc_2019lmf_cleaned.txt to lc_2019lmf.txt
# Renamed lc_2019lmi_cleaned.txt to lc_2019lmi.txt
# Renamed lc_2019lo_cleaned.txt to lc_2019lo.txt
# Renamed lc_2019lpf_cleaned.txt to lc_2019lpf.txt
# Renamed lc_2019lph_cleaned.txt to lc_2019lph.txt
# Renamed lc_2019lpk_cleaned.txt to lc_2019lpk.txt
# Renamed lc_2019lpr_cleaned.txt to lc_2019lpr.txt
# Renamed lc_2019lpw_cleaned.txt to lc_2019lpw.txt
# Renamed lc_2019lqc_cleaned.txt to lc_2019lqc.txt
# Renamed lc_2019lqg_cleaned.txt to lc_2019lqg.txt
# Renamed lc_2019lqo_cleaned.txt to lc_2019lqo.txt
# Renamed lc_2019lrq_cleaned.txt to lc_2019lrq.txt
# Renamed lc_2019lrs_cleaned.txt to lc_2019lrs.txt
# Renamed lc_2019lru_cleaned.txt to lc_2019lru.txt
# Renamed lc_2019lrx_cleaned.txt to lc_2019lrx.txt
# Renamed lc_2019lsf_cleaned.txt to lc_2019lsf.txt
# Renamed lc_2019lso_cleaned.txt to lc_2019lso.txt
# Renamed lc_2019lst_cleaned.txt to lc_2019lst.txt
# Renamed lc_2019luq_cleaned.txt to lc_2019luq.txt
# Renamed lc_2019lus_cleaned.txt to lc_2019lus.txt
# Renamed lc_2019lut_cleaned.txt to lc_2019lut.txt
# Renamed lc_2019lyd_cleaned.txt to lc_2019lyd.txt
# Renamed lc_2019lym_cleaned.txt to lc_2019lym.txt
# Renamed lc_2019mah_cleaned.txt to lc_2019mah.txt
# Renamed lc_2019maz_cleaned.txt to lc_2019maz.txt
# Renamed lc_2019mba_cleaned.txt to lc_2019mba.txt
# Renamed lc_2019mbi_cleaned.txt to lc_2019mbi.txt
# Renamed lc_2019mdc_cleaned.txt to lc_2019mdc.txt
# Renamed lc_2019mdp_cleaned.txt to lc_2019mdp.txt
# Renamed lc_2019mdq_cleaned.txt to lc_2019mdq.txt
# Renamed lc_2019mdr_cleaned.txt to lc_2019mdr.txt
# Renamed lc_2019mds_cleaned.txt to lc_2019mds.txt
# Renamed lc_2019mdw_cleaned.txt to lc_2019mdw.txt
# Renamed lc_2019meb_cleaned.txt to lc_2019meb.txt
# Renamed lc_2019mec_cleaned.txt to lc_2019mec.txt
# Renamed lc_2019med_cleaned.txt to lc_2019med.txt
# Renamed lc_2019mee_cleaned.txt to lc_2019mee.txt
# Renamed lc_2019mef_cleaned.txt to lc_2019mef.txt
# Renamed lc_2019meg_cleaned.txt to lc_2019meg.txt
# Renamed lc_2019men_cleaned.txt to lc_2019men.txt
# Renamed lc_2019mgr_cleaned.txt to lc_2019mgr.txt
# Renamed lc_2019mhv_cleaned.txt to lc_2019mhv.txt
# Renamed lc_2019mim_cleaned.txt to lc_2019mim.txt
# Renamed lc_2019mkg_cleaned.txt to lc_2019mkg.txt
# Renamed lc_2019mkl_cleaned.txt to lc_2019mkl.txt
# Renamed lc_2019mku_cleaned.txt to lc_2019mku.txt
# Renamed lc_2019mos_cleaned.txt to lc_2019mos.txt
# Renamed lc_2019mpq_cleaned.txt to lc_2019mpq.txt
# Renamed lc_2019mpt_cleaned.txt to lc_2019mpt.txt
# Renamed lc_2019mqc_cleaned.txt to lc_2019mqc.txt
# Renamed lc_2019mqg_cleaned.txt to lc_2019mqg.txt
# Renamed lc_2019mqz_cleaned.txt to lc_2019mqz.txt
# Renamed lc_2019mrd_cleaned.txt to lc_2019mrd.txt
# Renamed lc_2019mrf_cleaned.txt to lc_2019mrf.txt
# Renamed lc_2019mrg_cleaned.txt to lc_2019mrg.txt
# Renamed lc_2019msr_cleaned.txt to lc_2019msr.txt
# Renamed lc_2019mtm_cleaned.txt to lc_2019mtm.txt
# Renamed lc_2019mts_cleaned.txt to lc_2019mts.txt
# Renamed lc_2019mtt_cleaned.txt to lc_2019mtt.txt
# Renamed lc_2019mtz_cleaned.txt to lc_2019mtz.txt
# Renamed lc_2019mue_cleaned.txt to lc_2019mue.txt
# Renamed lc_2019mue_detrended-detrended_cleaned.txt to lc_2019mue_detrended-detrended.txt
# Renamed lc_2019mue_detrended_cleaned.txt to lc_2019mue_detrended.txt
# Renamed lc_2019muf_cleaned.txt to lc_2019muf.txt
# Renamed lc_2019muu_cleaned.txt to lc_2019muu.txt
# Renamed lc_2019muz_cleaned.txt to lc_2019muz.txt
# Renamed lc_2019mvj_cleaned.txt to lc_2019mvj.txt
# Renamed lc_2019mzo_cleaned.txt to lc_2019mzo.txt
# Renamed lc_2019mzy_cleaned.txt to lc_2019mzy.txt
# Renamed lc_2019ncd_cleaned.txt to lc_2019ncd.txt
# Renamed lc_2019ndl_cleaned.txt to lc_2019ndl.txt
# Renamed lc_2019nfq_cleaned.txt to lc_2019nfq.txt
# Renamed lc_2019nfv_cleaned.txt to lc_2019nfv.txt
# Renamed lc_2019nil_cleaned.txt to lc_2019nil.txt
# Renamed lc_2019njg_cleaned.txt to lc_2019njg.txt
# Renamed lc_2019njr_cleaned.txt to lc_2019njr.txt
# Renamed lc_2019njy_cleaned.txt to lc_2019njy.txt
# Renamed lc_2019nkq_cleaned.txt to lc_2019nkq.txt
# Renamed lc_2019nkr_cleaned.txt to lc_2019nkr.txt
# Renamed lc_2019nlc_cleaned.txt to lc_2019nlc.txt
# Renamed lc_2019nld_cleaned.txt to lc_2019nld.txt
# Renamed lc_2019nms_cleaned.txt to lc_2019nms.txt
# Renamed lc_2019nng_cleaned.txt to lc_2019nng.txt
# Renamed lc_2019nnr_cleaned.txt to lc_2019nnr.txt
# Renamed lc_2019noc_cleaned.txt to lc_2019noc.txt
# Renamed lc_2019nof_cleaned.txt to lc_2019nof.txt
# Renamed lc_2019nql_cleaned.txt to lc_2019nql.txt
# Renamed lc_2019nqn_cleaned.txt to lc_2019nqn.txt
# Renamed lc_2019nty_cleaned.txt to lc_2019nty.txt
# Renamed lc_2019ntz_cleaned.txt to lc_2019ntz.txt
# Renamed lc_2019nud_cleaned.txt to lc_2019nud.txt
# Renamed lc_2019nvj_cleaned.txt to lc_2019nvj.txt
# Renamed lc_2019nvk_cleaned.txt to lc_2019nvk.txt
# Renamed lc_2019nvl_cleaned.txt to lc_2019nvl.txt
# Renamed lc_2019nvm_cleaned.txt to lc_2019nvm.txt
# Renamed lc_2019nvw_cleaned.txt to lc_2019nvw.txt
# Renamed lc_2019nwu_cleaned.txt to lc_2019nwu.txt
# Renamed lc_2019nxp_cleaned.txt to lc_2019nxp.txt
# Renamed lc_2019nyf_cleaned.txt to lc_2019nyf.txt
# Renamed lc_2019nyo_cleaned.txt to lc_2019nyo.txt
# Renamed lc_2019nzp_cleaned.txt to lc_2019nzp.txt
# Renamed lc_2019nzq_cleaned.txt to lc_2019nzq.txt
# Renamed lc_2019oba_cleaned.txt to lc_2019oba.txt
# Renamed lc_2019obp_cleaned.txt to lc_2019obp.txt
# Renamed lc_2019oda_cleaned.txt to lc_2019oda.txt
# Renamed lc_2019ofn_cleaned.txt to lc_2019ofn.txt
# Renamed lc_2019oft_cleaned.txt to lc_2019oft.txt
# Renamed lc_2019ohj_cleaned.txt to lc_2019ohj.txt
# Renamed lc_2019omq_cleaned.txt to lc_2019omq.txt
# Renamed lc_2019onn_cleaned.txt to lc_2019onn.txt
# Renamed lc_2019ooj_cleaned.txt to lc_2019ooj.txt
# Renamed lc_2019ook_cleaned.txt to lc_2019ook.txt
# Renamed lc_2019opq_cleaned.txt to lc_2019opq.txt
# Renamed lc_2019opz_cleaned.txt to lc_2019opz.txt
# Renamed lc_2019oqb_cleaned.txt to lc_2019oqb.txt
# Renamed lc_2019oqc_cleaned.txt to lc_2019oqc.txt
# Renamed lc_2019ord_cleaned.txt to lc_2019ord.txt
# Renamed lc_2019osp_cleaned.txt to lc_2019osp.txt
# Renamed lc_2019osx_cleaned.txt to lc_2019osx.txt
# Renamed lc_2019osz_cleaned.txt to lc_2019osz.txt
# Renamed lc_2019oug_cleaned.txt to lc_2019oug.txt
# Renamed lc_2019ouk_cleaned.txt to lc_2019ouk.txt
# Renamed lc_2019ouw_cleaned.txt to lc_2019ouw.txt
# Renamed lc_2019ows_cleaned.txt to lc_2019ows.txt
# Renamed lc_2019owy_cleaned.txt to lc_2019owy.txt
# Renamed lc_2019oxg_cleaned.txt to lc_2019oxg.txt
# Renamed lc_2019oxo_cleaned.txt to lc_2019oxo.txt
# Renamed lc_2019oye_cleaned.txt to lc_2019oye.txt
# Renamed lc_2019oyk_cleaned.txt to lc_2019oyk.txt
# Renamed lc_2019ozf_cleaned.txt to lc_2019ozf.txt
# Renamed lc_2019ozg_cleaned.txt to lc_2019ozg.txt
# Renamed lc_2019pac_cleaned.txt to lc_2019pac.txt
# Renamed lc_2019pai_cleaned.txt to lc_2019pai.txt
# Renamed lc_2019pat_cleaned.txt to lc_2019pat.txt
# Renamed lc_2019pau_cleaned.txt to lc_2019pau.txt
# Renamed lc_2019pco_cleaned.txt to lc_2019pco.txt
# Renamed lc_2019pcy_cleaned.txt to lc_2019pcy.txt
# Renamed lc_2019pdx_cleaned.txt to lc_2019pdx.txt
# Renamed lc_2019pfb_cleaned.txt to lc_2019pfb.txt
# Renamed lc_2019pgi_cleaned.txt to lc_2019pgi.txt
# Renamed lc_2019pgp_cleaned.txt to lc_2019pgp.txt
# Renamed lc_2019pgu_cleaned.txt to lc_2019pgu.txt
# Renamed lc_2019pho_cleaned.txt to lc_2019pho.txt
# Renamed lc_2019php_cleaned.txt to lc_2019php.txt
# Renamed lc_2019pjk_cleaned.txt to lc_2019pjk.txt
# Renamed lc_2019pjm_cleaned.txt to lc_2019pjm.txt
# Renamed lc_2019pju_cleaned.txt to lc_2019pju.txt
# Renamed lc_2019pkz_cleaned.txt to lc_2019pkz.txt
# Renamed lc_2019pla_cleaned.txt to lc_2019pla.txt
# Renamed lc_2019pmr_cleaned.txt to lc_2019pmr.txt
# Renamed lc_2019pmt_cleaned.txt to lc_2019pmt.txt
# Renamed lc_2019pm_cleaned.txt to lc_2019pm.txt
# Renamed lc_2019pnp_cleaned.txt to lc_2019pnp.txt
# Renamed lc_2019pnw_cleaned.txt to lc_2019pnw.txt
# Renamed lc_2019pnw_detrended_cleaned.txt to lc_2019pnw_detrended.txt
# Renamed lc_2019pny_cleaned.txt to lc_2019pny.txt
# Renamed lc_2019poz_cleaned.txt to lc_2019poz.txt
# Renamed lc_2019pqm_cleaned.txt to lc_2019pqm.txt
# Renamed lc_2019pqv_cleaned.txt to lc_2019pqv.txt
# Renamed lc_2019prm_cleaned.txt to lc_2019prm.txt
# Renamed lc_2019prs_cleaned.txt to lc_2019prs.txt
# Renamed lc_2019prw_cleaned.txt to lc_2019prw.txt
# Renamed lc_2019prw_detrended_cleaned.txt to lc_2019prw_detrended.txt
# Renamed lc_2019prx_cleaned.txt to lc_2019prx.txt
# Renamed lc_2019ptf_cleaned.txt to lc_2019ptf.txt
# Renamed lc_2019ptg_cleaned.txt to lc_2019ptg.txt
# Renamed lc_2019ptv_cleaned.txt to lc_2019ptv.txt
# Renamed lc_2019ptv_detrended_cleaned.txt to lc_2019ptv_detrended.txt
# Renamed lc_2019pv_cleaned.txt to lc_2019pv.txt
# Renamed lc_2019pwa_cleaned.txt to lc_2019pwa.txt
# Renamed lc_2019pwd_cleaned.txt to lc_2019pwd.txt
# Renamed lc_2019pwq_cleaned.txt to lc_2019pwq.txt
# Renamed lc_2019pwr_cleaned.txt to lc_2019pwr.txt
# Renamed lc_2019pxv_cleaned.txt to lc_2019pxv.txt
# Renamed lc_2019pxx_cleaned.txt to lc_2019pxx.txt
# Renamed lc_2019pzj_cleaned.txt to lc_2019pzj.txt
# Renamed lc_2019pzn_cleaned.txt to lc_2019pzn.txt
# Renamed lc_2019pzq_cleaned.txt to lc_2019pzq.txt
# Renamed lc_2019pzt_cleaned.txt to lc_2019pzt.txt
# Renamed lc_2019qbs_cleaned.txt to lc_2019qbs.txt
# Renamed lc_2019qck_cleaned.txt to lc_2019qck.txt
# Renamed lc_2019qcu_cleaned.txt to lc_2019qcu.txt
# Renamed lc_2019qcw_cleaned.txt to lc_2019qcw.txt
# Renamed lc_2019qdh_cleaned.txt to lc_2019qdh.txt
# Renamed lc_2019qdi_cleaned.txt to lc_2019qdi.txt
# Renamed lc_2019qdm_cleaned.txt to lc_2019qdm.txt
# Renamed lc_2019qew_cleaned.txt to lc_2019qew.txt
# Renamed lc_2019qey_cleaned.txt to lc_2019qey.txt
# Renamed lc_2019qgh_cleaned.txt to lc_2019qgh.txt
# Renamed lc_2019qgj_cleaned.txt to lc_2019qgj.txt
# Renamed lc_2019qgx_cleaned.txt to lc_2019qgx.txt
# Renamed lc_2019qhg_cleaned.txt to lc_2019qhg.txt
# Renamed lc_2019qhh_cleaned.txt to lc_2019qhh.txt
# Renamed lc_2019qib_cleaned.txt to lc_2019qib.txt
# Renamed lc_2019qjh_cleaned.txt to lc_2019qjh.txt
# Renamed lc_2019qmm_cleaned.txt to lc_2019qmm.txt
# Renamed lc_2019qmm_detrended_cleaned.txt to lc_2019qmm_detrended.txt
# Renamed lc_2019qmt_cleaned.txt to lc_2019qmt.txt
# Renamed lc_2019qoj_cleaned.txt to lc_2019qoj.txt
# Renamed lc_2019qpc_cleaned.txt to lc_2019qpc.txt
# Renamed lc_2019qpx_cleaned.txt to lc_2019qpx.txt
# Renamed lc_2019qqk_cleaned.txt to lc_2019qqk.txt
# Renamed lc_2019qql_cleaned.txt to lc_2019qql.txt
# Renamed lc_2019qqr_cleaned.txt to lc_2019qqr.txt
# Renamed lc_2019qqs_cleaned.txt to lc_2019qqs.txt
# Renamed lc_2019qrh_cleaned.txt to lc_2019qrh.txt
# Renamed lc_2019qsc_cleaned.txt to lc_2019qsc.txt
# Renamed lc_2019qsc_detrended_cleaned.txt to lc_2019qsc_detrended.txt
# Renamed lc_2019qtw_cleaned.txt to lc_2019qtw.txt
# Renamed lc_2019qty_cleaned.txt to lc_2019qty.txt
# Renamed lc_2019qwf_cleaned.txt to lc_2019qwf.txt
# Renamed lc_2019qwj_cleaned.txt to lc_2019qwj.txt
# Renamed lc_2019qwl_cleaned.txt to lc_2019qwl.txt
# Renamed lc_2019qxo_cleaned.txt to lc_2019qxo.txt
# Renamed lc_2019qyb_cleaned.txt to lc_2019qyb.txt
# Renamed lc_2019qyc_cleaned.txt to lc_2019qyc.txt
# Renamed lc_2019rdl_cleaned.txt to lc_2019rdl.txt
# Renamed lc_2019rdp_cleaned.txt to lc_2019rdp.txt
# Renamed lc_2019rex_cleaned.txt to lc_2019rex.txt
# Renamed lc_2019rhl_cleaned.txt to lc_2019rhl.txt
# Renamed lc_2019rhy_cleaned.txt to lc_2019rhy.txt
# Renamed lc_2019rid_cleaned.txt to lc_2019rid.txt
# Renamed lc_2019ris_cleaned.txt to lc_2019ris.txt
# Renamed lc_2019rj_cleaned.txt to lc_2019rj.txt
# Renamed lc_2019rle_cleaned.txt to lc_2019rle.txt
# Renamed lc_2019rmp_cleaned.txt to lc_2019rmp.txt
# Renamed lc_2019rm_cleaned.txt to lc_2019rm.txt
# Renamed lc_2019rpz_cleaned.txt to lc_2019rpz.txt
# Renamed lc_2019rqd_cleaned.txt to lc_2019rqd.txt
# Renamed lc_2019rqf_cleaned.txt to lc_2019rqf.txt
# Renamed lc_2019rqg_cleaned.txt to lc_2019rqg.txt
# Renamed lc_2019rqu_cleaned.txt to lc_2019rqu.txt
# Renamed lc_2019rrc_cleaned.txt to lc_2019rrc.txt
# Renamed lc_2019rrd_cleaned.txt to lc_2019rrd.txt
# Renamed lc_2019rre_cleaned.txt to lc_2019rre.txt
# Renamed lc_2019ruc_cleaned.txt to lc_2019ruc.txt
# Renamed lc_2019ruf_cleaned.txt to lc_2019ruf.txt
# Renamed lc_2019rug_cleaned.txt to lc_2019rug.txt
# Renamed lc_2019rvh_cleaned.txt to lc_2019rvh.txt
# Renamed lc_2019rvx_cleaned.txt to lc_2019rvx.txt
# Renamed lc_2019rwg_cleaned.txt to lc_2019rwg.txt
# Renamed lc_2019rwh_cleaned.txt to lc_2019rwh.txt
# Renamed lc_2019ryj_cleaned.txt to lc_2019ryj.txt
# Renamed lc_2019sap_cleaned.txt to lc_2019sap.txt
# Renamed lc_2019saz_cleaned.txt to lc_2019saz.txt
# Renamed lc_2019sbi_cleaned.txt to lc_2019sbi.txt
# Renamed lc_2019sbu_cleaned.txt to lc_2019sbu.txt
# Renamed lc_2019sbx_cleaned.txt to lc_2019sbx.txt
# Renamed lc_2019sbz_cleaned.txt to lc_2019sbz.txt
# Renamed lc_2019sdl_cleaned.txt to lc_2019sdl.txt
# Renamed lc_2019sdp_cleaned.txt to lc_2019sdp.txt
# Renamed lc_2019sej_cleaned.txt to lc_2019sej.txt
# Renamed lc_2019sep_cleaned.txt to lc_2019sep.txt
# Renamed lc_2019sfx_cleaned.txt to lc_2019sfx.txt
# Renamed lc_2019sgb_cleaned.txt to lc_2019sgb.txt
# Renamed lc_2019sgq_cleaned.txt to lc_2019sgq.txt
# Renamed lc_2019sgu_cleaned.txt to lc_2019sgu.txt
# Renamed lc_2019sgv_cleaned.txt to lc_2019sgv.txt
# Renamed lc_2019sho_cleaned.txt to lc_2019sho.txt
# Renamed lc_2019sic_cleaned.txt to lc_2019sic.txt
# Renamed lc_2019sig_cleaned.txt to lc_2019sig.txt
# Renamed lc_2019sih_cleaned.txt to lc_2019sih.txt
# Renamed lc_2019sij_cleaned.txt to lc_2019sij.txt
# Renamed lc_2019skg_cleaned.txt to lc_2019skg.txt
# Renamed lc_2019skx_cleaned.txt to lc_2019skx.txt
# Renamed lc_2019sld_cleaned.txt to lc_2019sld.txt
# Renamed lc_2019slh_cleaned.txt to lc_2019slh.txt
# Renamed lc_2019slj_cleaned.txt to lc_2019slj.txt
# Renamed lc_2019slp_cleaned.txt to lc_2019slp.txt
# Renamed lc_2019slt_cleaned.txt to lc_2019slt.txt
# Renamed lc_2019sme_cleaned.txt to lc_2019sme.txt
# Renamed lc_2019smf_cleaned.txt to lc_2019smf.txt
# Renamed lc_2019snw_cleaned.txt to lc_2019snw.txt
# Renamed lc_2019soh_cleaned.txt to lc_2019soh.txt
# Renamed lc_2019soi_cleaned.txt to lc_2019soi.txt
# Renamed lc_2019soj_cleaned.txt to lc_2019soj.txt
# Renamed lc_2019sop_cleaned.txt to lc_2019sop.txt
# Renamed lc_2019sos_cleaned.txt to lc_2019sos.txt
# Renamed lc_2019spn_cleaned.txt to lc_2019spn.txt
# Renamed lc_2019sqf_cleaned.txt to lc_2019sqf.txt
# Renamed lc_2019sqj_cleaned.txt to lc_2019sqj.txt
# Renamed lc_2019sqk_cleaned.txt to lc_2019sqk.txt
# Renamed lc_2019sql_cleaned.txt to lc_2019sql.txt
# Renamed lc_2019sqm_cleaned.txt to lc_2019sqm.txt
# Renamed lc_2019sqn_cleaned.txt to lc_2019sqn.txt
# Renamed lc_2019sqo_cleaned.txt to lc_2019sqo.txt
# Renamed lc_2019src_cleaned.txt to lc_2019src.txt
# Renamed lc_2019sse_cleaned.txt to lc_2019sse.txt
# Renamed lc_2019ssx_cleaned.txt to lc_2019ssx.txt
# Renamed lc_2019sta_cleaned.txt to lc_2019sta.txt
# Renamed lc_2019stj_cleaned.txt to lc_2019stj.txt
# Renamed lc_2019stn_cleaned.txt to lc_2019stn.txt
# Renamed lc_2019str_cleaned.txt to lc_2019str.txt
# Renamed lc_2019sts_cleaned.txt to lc_2019sts.txt
# Renamed lc_2019svm_cleaned.txt to lc_2019svm.txt
# Renamed lc_2019swx_cleaned.txt to lc_2019swx.txt
# Renamed lc_2019swy_cleaned.txt to lc_2019swy.txt
# Renamed lc_2019sxa_cleaned.txt to lc_2019sxa.txt
# Renamed lc_2019sxb_cleaned.txt to lc_2019sxb.txt
# Renamed lc_2019sxc_cleaned.txt to lc_2019sxc.txt
# Renamed lc_2019sxe_cleaned.txt to lc_2019sxe.txt
# Renamed lc_2019sxq_cleaned.txt to lc_2019sxq.txt
# Renamed lc_2019syl_cleaned.txt to lc_2019syl.txt
# Renamed lc_2019tac_cleaned.txt to lc_2019tac.txt
# Renamed lc_2019tae_cleaned.txt to lc_2019tae.txt
# Renamed lc_2019tat_cleaned.txt to lc_2019tat.txt
# Renamed lc_2019tbg_cleaned.txt to lc_2019tbg.txt
# Renamed lc_2019tdi_cleaned.txt to lc_2019tdi.txt
# Renamed lc_2019tfa_cleaned.txt to lc_2019tfa.txt
# Renamed lc_2019tfd_cleaned.txt to lc_2019tfd.txt
# Renamed lc_2019tfu_cleaned.txt to lc_2019tfu.txt
# Renamed lc_2019tgj_cleaned.txt to lc_2019tgj.txt
# Renamed lc_2019thj_cleaned.txt to lc_2019thj.txt
# Renamed lc_2019thz_cleaned.txt to lc_2019thz.txt
# Renamed lc_2019til_cleaned.txt to lc_2019til.txt
# Renamed lc_2019tjl_cleaned.txt to lc_2019tjl.txt
# Renamed lc_2019tjs_cleaned.txt to lc_2019tjs.txt
# Renamed lc_2019tjt_cleaned.txt to lc_2019tjt.txt
# Renamed lc_2019tju_cleaned.txt to lc_2019tju.txt
# Renamed lc_2019tjw_cleaned.txt to lc_2019tjw.txt
# Renamed lc_2019tjx_cleaned.txt to lc_2019tjx.txt
# Renamed lc_2019tjz_cleaned.txt to lc_2019tjz.txt
# Renamed lc_2019tka_cleaned.txt to lc_2019tka.txt
# Renamed lc_2019tlo_cleaned.txt to lc_2019tlo.txt
# Renamed lc_2019tlp_cleaned.txt to lc_2019tlp.txt
# Renamed lc_2019tlu_cleaned.txt to lc_2019tlu.txt
# Renamed lc_2019tmw_cleaned.txt to lc_2019tmw.txt
# Renamed lc_2019tnf_cleaned.txt to lc_2019tnf.txt
# Renamed lc_2019tng_cleaned.txt to lc_2019tng.txt
# Renamed lc_2019tov_cleaned.txt to lc_2019tov.txt
# Renamed lc_2019tq_cleaned.txt to lc_2019tq.txt
# Renamed lc_2019trl_cleaned.txt to lc_2019trl.txt
# Renamed lc_2019tsc_cleaned.txt to lc_2019tsc.txt
# Renamed lc_2019tsm_cleaned.txt to lc_2019tsm.txt
# Renamed lc_2019tsq_cleaned.txt to lc_2019tsq.txt
# Renamed lc_2019tsu_cleaned.txt to lc_2019tsu.txt
# Renamed lc_2019tsv_cleaned.txt to lc_2019tsv.txt
# Renamed lc_2019tsw_cleaned.txt to lc_2019tsw.txt
# Renamed lc_2019tsx_cleaned.txt to lc_2019tsx.txt
# Renamed lc_2019tsy_cleaned.txt to lc_2019tsy.txt
# Renamed lc_2019tsz_cleaned.txt to lc_2019tsz.txt
# Renamed lc_2019tta_cleaned.txt to lc_2019tta.txt
# Renamed lc_2019tum_cleaned.txt to lc_2019tum.txt
# Renamed lc_2019tvu_cleaned.txt to lc_2019tvu.txt
# Renamed lc_2019tyu_cleaned.txt to lc_2019tyu.txt
# Renamed lc_2019uag_cleaned.txt to lc_2019uag.txt
# Renamed lc_2019uaj_cleaned.txt to lc_2019uaj.txt
# Renamed lc_2019ubd_cleaned.txt to lc_2019ubd.txt
# Renamed lc_2019ubf_cleaned.txt to lc_2019ubf.txt
# Renamed lc_2019ubi_cleaned.txt to lc_2019ubi.txt
# Renamed lc_2019uca_cleaned.txt to lc_2019uca.txt
# Renamed lc_2019udl_cleaned.txt to lc_2019udl.txt
# Renamed lc_2019udn_cleaned.txt to lc_2019udn.txt
# Renamed lc_2019uem_cleaned.txt to lc_2019uem.txt
# Renamed lc_2019uen_cleaned.txt to lc_2019uen.txt
# Renamed lc_2019ufu_cleaned.txt to lc_2019ufu.txt
# Renamed lc_2019ufy_cleaned.txt to lc_2019ufy.txt
# Renamed lc_2019ufz_cleaned.txt to lc_2019ufz.txt
# Renamed lc_2019ugb_cleaned.txt to lc_2019ugb.txt
# Renamed lc_2019uge_cleaned.txt to lc_2019uge.txt
# Renamed lc_2019ugr_cleaned.txt to lc_2019ugr.txt
# Renamed lc_2019ugy_cleaned.txt to lc_2019ugy.txt
# Renamed lc_2019ugz_cleaned.txt to lc_2019ugz.txt
# Renamed lc_2019uje_cleaned.txt to lc_2019uje.txt
# Renamed lc_2019ujq_cleaned.txt to lc_2019ujq.txt
# Renamed lc_2019ujt_cleaned.txt to lc_2019ujt.txt
# Renamed lc_2019ujw_cleaned.txt to lc_2019ujw.txt
# Renamed lc_2019ukb_cleaned.txt to lc_2019ukb.txt
# Renamed lc_2019ukd_cleaned.txt to lc_2019ukd.txt
# Renamed lc_2019ukv_cleaned.txt to lc_2019ukv.txt
# Renamed lc_2019ule_cleaned.txt to lc_2019ule.txt
# Renamed lc_2019ulr_cleaned.txt to lc_2019ulr.txt
# Renamed lc_2019ulr_detrended_cleaned.txt to lc_2019ulr_detrended.txt
# Renamed lc_2019ulv_cleaned.txt to lc_2019ulv.txt
# Renamed lc_2019ulw_cleaned.txt to lc_2019ulw.txt
# Renamed lc_2019umq_cleaned.txt to lc_2019umq.txt
# Renamed lc_2019unq_cleaned.txt to lc_2019unq.txt
# Renamed lc_2019uwj_cleaned.txt to lc_2019uwj.txt
# Renamed lc_2019uwk_cleaned.txt to lc_2019uwk.txt
# Renamed lc_2019uyn_cleaned.txt to lc_2019uyn.txt
# Renamed lc_2019uyr_cleaned.txt to lc_2019uyr.txt
# Renamed lc_2019val_cleaned.txt to lc_2019val.txt
# Renamed lc_2019vbi_cleaned.txt to lc_2019vbi.txt
# Renamed lc_2019vbj_cleaned.txt to lc_2019vbj.txt
# Renamed lc_2019vby_cleaned.txt to lc_2019vby.txt
# Renamed lc_2019vcz_cleaned.txt to lc_2019vcz.txt
# Renamed lc_2019vda_cleaned.txt to lc_2019vda.txt
# Renamed lc_2019vde_cleaned.txt to lc_2019vde.txt
# Renamed lc_2019vjv_cleaned.txt to lc_2019vjv.txt
# Renamed lc_2019vkn_cleaned.txt to lc_2019vkn.txt
# Renamed lc_2019vli_cleaned.txt to lc_2019vli.txt
# Renamed lc_2019vlt_cleaned.txt to lc_2019vlt.txt
# Renamed lc_2019vlu_cleaned.txt to lc_2019vlu.txt
# Renamed lc_2019vma_cleaned.txt to lc_2019vma.txt
# Renamed lc_2019vmb_cleaned.txt to lc_2019vmb.txt
# Renamed lc_2019vmc_cleaned.txt to lc_2019vmc.txt
# Renamed lc_2019vmm_cleaned.txt to lc_2019vmm.txt
# Renamed lc_2019vrh_cleaned.txt to lc_2019vrh.txt
# Renamed lc_2019vuj_cleaned.txt to lc_2019vuj.txt
# Renamed lc_2019vyb_cleaned.txt to lc_2019vyb.txt
# Renamed lc_2019vyf_cleaned.txt to lc_2019vyf.txt
# Renamed lc_2019vyj_cleaned.txt to lc_2019vyj.txt
# Renamed lc_2019vyk_cleaned.txt to lc_2019vyk.txt
# Renamed lc_2019vzi_cleaned.txt to lc_2019vzi.txt
# Renamed lc_2019vzv_cleaned.txt to lc_2019vzv.txt
# Renamed lc_2019vzx_cleaned.txt to lc_2019vzx.txt
# Renamed lc_2019vzy_cleaned.txt to lc_2019vzy.txt
# Renamed lc_2019wbk_cleaned.txt to lc_2019wbk.txt
# Renamed lc_2019wbl_cleaned.txt to lc_2019wbl.txt
# Renamed lc_2019wbo_cleaned.txt to lc_2019wbo.txt
# Renamed lc_2019wbr_cleaned.txt to lc_2019wbr.txt
# Renamed lc_2019wey_cleaned.txt to lc_2019wey.txt
# Renamed lc_2019whd_cleaned.txt to lc_2019whd.txt
# Renamed lc_2019wim_cleaned.txt to lc_2019wim.txt
# Renamed lc_2019wio_cleaned.txt to lc_2019wio.txt
# Renamed lc_2019wjj_cleaned.txt to lc_2019wjj.txt
# Renamed lc_2019wjl_cleaned.txt to lc_2019wjl.txt
# Renamed lc_2019wkz_cleaned.txt to lc_2019wkz.txt
# Renamed lc_2019wla_cleaned.txt to lc_2019wla.txt
# Renamed lc_2019wle_cleaned.txt to lc_2019wle.txt
# Renamed lc_2019wmw_cleaned.txt to lc_2019wmw.txt
# Renamed lc_2019wnu_cleaned.txt to lc_2019wnu.txt
# Renamed lc_2019wrr_cleaned.txt to lc_2019wrr.txt
# Renamed lc_2019wuu_cleaned.txt to lc_2019wuu.txt
# Renamed lc_2019wve_cleaned.txt to lc_2019wve.txt
# Renamed lc_2019wvo_cleaned.txt to lc_2019wvo.txt
# Renamed lc_2019wwo_cleaned.txt to lc_2019wwo.txt
# Renamed lc_2019wxp_cleaned.txt to lc_2019wxp.txt
# Renamed lc_2019wz_cleaned.txt to lc_2019wz.txt
# Renamed lc_2019xao_cleaned.txt to lc_2019xao.txt
# Renamed lc_2019xaq_cleaned.txt to lc_2019xaq.txt
# Renamed lc_2019xar_cleaned.txt to lc_2019xar.txt
# Renamed lc_2019xcn_cleaned.txt to lc_2019xcn.txt
# Renamed lc_2019xdl_cleaned.txt to lc_2019xdl.txt
# Renamed lc_2019xe_cleaned.txt to lc_2019xe.txt
# Renamed lc_2019xhk_cleaned.txt to lc_2019xhk.txt
# Renamed lc_2019xip_cleaned.txt to lc_2019xip.txt
# Renamed lc_2019xtf_cleaned.txt to lc_2019xtf.txt
# Renamed lc_2019xuk_cleaned.txt to lc_2019xuk.txt
# Renamed lc_2019xul_cleaned.txt to lc_2019xul.txt
# Renamed lc_2019xvs_cleaned.txt to lc_2019xvs.txt
# Renamed lc_2019yek_cleaned.txt to lc_2019yek.txt
# Renamed lc_2019yel_cleaned.txt to lc_2019yel.txt
# Renamed lc_2019yxj_cleaned.txt to lc_2019yxj.txt
# Renamed lc_2019yyw_cleaned.txt to lc_2019yyw.txt
# Renamed lc_2019zag_cleaned.txt to lc_2019zag.txt
# Renamed lc_2019zam_cleaned.txt to lc_2019zam.txt
# Renamed lc_2019zdo_cleaned.txt to lc_2019zdo.txt
# Renamed lc_2019zei_cleaned.txt to lc_2019zei.txt
# Renamed lc_2019zej_cleaned.txt to lc_2019zej.txt
# Renamed lc_2019zem_cleaned.txt to lc_2019zem.txt
# Renamed lc_2019zen_cleaned.txt to lc_2019zen.txt
# Renamed lc_2019zep_cleaned.txt to lc_2019zep.txt
# Renamed lc_2019zes_cleaned.txt to lc_2019zes.txt
# Renamed lc_2019zhj_cleaned.txt to lc_2019zhj.txt
# Renamed lc_2019zhm_cleaned.txt to lc_2019zhm.txt
# Renamed lc_2019zrd_cleaned.txt to lc_2019zrd.txt
# Renamed lc_2019zsi_cleaned.txt to lc_2019zsi.txt
# Renamed lc_2020aaab_cleaned.txt to lc_2020aaab.txt
# Renamed lc_2020aaaj_cleaned.txt to lc_2020aaaj.txt
# Renamed lc_2020aaap_cleaned.txt to lc_2020aaap.txt
# Renamed lc_2020aacy_cleaned.txt to lc_2020aacy.txt
# Renamed lc_2020aafo_cleaned.txt to lc_2020aafo.txt
# Renamed lc_2020aagz_cleaned.txt to lc_2020aagz.txt
# Renamed lc_2020aahq_cleaned.txt to lc_2020aahq.txt
# Renamed lc_2020aajf_cleaned.txt to lc_2020aajf.txt
# Renamed lc_2020aajq_cleaned.txt to lc_2020aajq.txt
# Renamed lc_2020aalz_cleaned.txt to lc_2020aalz.txt
# Renamed lc_2020aame_cleaned.txt to lc_2020aame.txt
# Renamed lc_2020aami_cleaned.txt to lc_2020aami.txt
# Renamed lc_2020aamu_cleaned.txt to lc_2020aamu.txt
# Renamed lc_2020aanf_cleaned.txt to lc_2020aanf.txt
# Renamed lc_2020aanv_cleaned.txt to lc_2020aanv.txt
# Renamed lc_2020aany_cleaned.txt to lc_2020aany.txt
# Renamed lc_2020aan_cleaned.txt to lc_2020aan.txt
# Renamed lc_2020aaog_cleaned.txt to lc_2020aaog.txt
# Renamed lc_2020aao_cleaned.txt to lc_2020aao.txt
# Renamed lc_2020aaqm_cleaned.txt to lc_2020aaqm.txt
# Renamed lc_2020aaqu_cleaned.txt to lc_2020aaqu.txt
# Renamed lc_2020aarw_cleaned.txt to lc_2020aarw.txt
# Renamed lc_2020aarz_cleaned.txt to lc_2020aarz.txt
# Renamed lc_2020aatb_cleaned.txt to lc_2020aatb.txt
# Renamed lc_2020aauh_cleaned.txt to lc_2020aauh.txt
# Renamed lc_2020aavd_cleaned.txt to lc_2020aavd.txt
# Renamed lc_2020aawh_cleaned.txt to lc_2020aawh.txt
# Renamed lc_2020aawi_cleaned.txt to lc_2020aawi.txt
# Renamed lc_2020aawj_cleaned.txt to lc_2020aawj.txt
# Renamed lc_2020aayb_cleaned.txt to lc_2020aayb.txt
# Renamed lc_2020aayc_cleaned.txt to lc_2020aayc.txt
# Renamed lc_2020aaye_cleaned.txt to lc_2020aaye.txt
# Renamed lc_2020aayk_cleaned.txt to lc_2020aayk.txt
# Renamed lc_2020aayr_cleaned.txt to lc_2020aayr.txt
# Renamed lc_2020aayt_cleaned.txt to lc_2020aayt.txt
# Renamed lc_2020aayv_cleaned.txt to lc_2020aayv.txt
# Renamed lc_2020aayy_cleaned.txt to lc_2020aayy.txt
# Renamed lc_2020abbx_cleaned.txt to lc_2020abbx.txt
# Renamed lc_2020abcd_cleaned.txt to lc_2020abcd.txt
# Renamed lc_2020abcr_cleaned.txt to lc_2020abcr.txt
# Renamed lc_2020abdk_cleaned.txt to lc_2020abdk.txt
# Renamed lc_2020abdk_detrended_cleaned.txt to lc_2020abdk_detrended.txt
# Renamed lc_2020abdu_cleaned.txt to lc_2020abdu.txt
# Renamed lc_2020abez_cleaned.txt to lc_2020abez.txt
# Renamed lc_2020abfn_cleaned.txt to lc_2020abfn.txt
# Renamed lc_2020abfo_cleaned.txt to lc_2020abfo.txt
# Renamed lc_2020abfw_cleaned.txt to lc_2020abfw.txt
# Renamed lc_2020abgz_cleaned.txt to lc_2020abgz.txt
# Renamed lc_2020abjj_cleaned.txt to lc_2020abjj.txt
# Renamed lc_2020abjl_cleaned.txt to lc_2020abjl.txt
# Renamed lc_2020abky_cleaned.txt to lc_2020abky.txt
# Renamed lc_2020ablu_cleaned.txt to lc_2020ablu.txt
# Renamed lc_2020abof_cleaned.txt to lc_2020abof.txt
# Renamed lc_2020abqs_cleaned.txt to lc_2020abqs.txt
# Renamed lc_2020abqu_cleaned.txt to lc_2020abqu.txt
# Renamed lc_2020abqy_cleaned.txt to lc_2020abqy.txt
# Renamed lc_2020abq_cleaned.txt to lc_2020abq.txt
# Renamed lc_2020abrp_cleaned.txt to lc_2020abrp.txt
# Renamed lc_2020absm_cleaned.txt to lc_2020absm.txt
# Renamed lc_2020abtd_cleaned.txt to lc_2020abtd.txt
# Renamed lc_2020abuo_cleaned.txt to lc_2020abuo.txt
# Renamed lc_2020abvc_cleaned.txt to lc_2020abvc.txt
# Renamed lc_2020abvn_cleaned.txt to lc_2020abvn.txt
# Renamed lc_2020abvz_cleaned.txt to lc_2020abvz.txt
# Renamed lc_2020abwb_cleaned.txt to lc_2020abwb.txt
# Renamed lc_2020abwn_cleaned.txt to lc_2020abwn.txt
# Renamed lc_2020abwr_cleaned.txt to lc_2020abwr.txt
# Renamed lc_2020abwu_cleaned.txt to lc_2020abwu.txt
# Renamed lc_2020abxa_cleaned.txt to lc_2020abxa.txt
# Renamed lc_2020abxj_cleaned.txt to lc_2020abxj.txt
# Renamed lc_2020abxl_cleaned.txt to lc_2020abxl.txt
# Renamed lc_2020abxn_cleaned.txt to lc_2020abxn.txt
# Renamed lc_2020abxo_cleaned.txt to lc_2020abxo.txt
# Renamed lc_2020acaa_cleaned.txt to lc_2020acaa.txt
# Renamed lc_2020acaj_cleaned.txt to lc_2020acaj.txt
# Renamed lc_2020acaw_cleaned.txt to lc_2020acaw.txt
# Renamed lc_2020acax_cleaned.txt to lc_2020acax.txt
# Renamed lc_2020acay_cleaned.txt to lc_2020acay.txt
# Renamed lc_2020acba_cleaned.txt to lc_2020acba.txt
# Renamed lc_2020acbc_cleaned.txt to lc_2020acbc.txt
# Renamed lc_2020acbf_cleaned.txt to lc_2020acbf.txt
# Renamed lc_2020acbp_cleaned.txt to lc_2020acbp.txt
# Renamed lc_2020accy_cleaned.txt to lc_2020accy.txt
# Renamed lc_2020accz_cleaned.txt to lc_2020accz.txt
# Renamed lc_2020acdk_cleaned.txt to lc_2020acdk.txt
# Renamed lc_2020acds_cleaned.txt to lc_2020acds.txt
# Renamed lc_2020acgb_cleaned.txt to lc_2020acgb.txt
# Renamed lc_2020acgc_cleaned.txt to lc_2020acgc.txt
# Renamed lc_2020acgd_cleaned.txt to lc_2020acgd.txt
# Renamed lc_2020acge_cleaned.txt to lc_2020acge.txt
# Renamed lc_2020acgf_cleaned.txt to lc_2020acgf.txt
# Renamed lc_2020acgi_cleaned.txt to lc_2020acgi.txt
# Renamed lc_2020achi_cleaned.txt to lc_2020achi.txt
# Renamed lc_2020achk_cleaned.txt to lc_2020achk.txt
# Renamed lc_2020aclq_cleaned.txt to lc_2020aclq.txt
# Renamed lc_2020acls_cleaned.txt to lc_2020acls.txt
# Renamed lc_2020aclz_cleaned.txt to lc_2020aclz.txt
# Renamed lc_2020acmr_cleaned.txt to lc_2020acmr.txt
# Renamed lc_2020acna_cleaned.txt to lc_2020acna.txt
# Renamed lc_2020acnj_cleaned.txt to lc_2020acnj.txt
# Renamed lc_2020acpo_cleaned.txt to lc_2020acpo.txt
# Renamed lc_2020acpu_cleaned.txt to lc_2020acpu.txt
# Renamed lc_2020acpv_cleaned.txt to lc_2020acpv.txt
# Renamed lc_2020acqf_cleaned.txt to lc_2020acqf.txt
# Renamed lc_2020acrs_cleaned.txt to lc_2020acrs.txt
# Renamed lc_2020acrz_cleaned.txt to lc_2020acrz.txt
# Renamed lc_2020acxg_cleaned.txt to lc_2020acxg.txt
# Renamed lc_2020acxt_cleaned.txt to lc_2020acxt.txt
# Renamed lc_2020acya_cleaned.txt to lc_2020acya.txt
# Renamed lc_2020aczd_cleaned.txt to lc_2020aczd.txt
# Renamed lc_2020adbn_cleaned.txt to lc_2020adbn.txt
# ...
# Renamed lc_2023alt_cleaned.txt to lc_2023alt.txt
# Renamed lc_2023alw_cleaned.txt to lc_2023alw.txt
# Renamed lc_2023ams_cleaned.txt to lc_2023ams.txt
# Renamed lc_2023amt_cleaned.txt to lc_2023amt.txt
# Renamed lc_2023amw_cleaned.txt to lc_2023amw.txt
# Renamed lc_2023anc_cleaned.txt to lc_2023anc.txt
# Renamed lc_2023anj_cleaned.txt to lc_2023anj.txt
# Renamed lc_2023anm_cleaned.txt to lc_2023anm.txt
# Renamed lc_2023ann_cleaned.txt to lc_2023ann.txt
# Renamed lc_2023anw_cleaned.txt to lc_2023anw.txt
# Renamed lc_2023aob_cleaned.txt to lc_2023aob.txt
# Renamed lc_2023aoi_cleaned.txt to lc_2023aoi.txt
# Renamed lc_2023aot_cleaned.txt to lc_2023aot.txt
# Renamed lc_2023aoz_cleaned.txt to lc_2023aoz.txt
# Renamed lc_2023apz_cleaned.txt to lc_2023apz.txt
# Renamed lc_2023arx_cleaned.txt to lc_2023arx.txt
# Renamed lc_2023ato_cleaned.txt to lc_2023ato.txt
# Renamed lc_2023atp_cleaned.txt to lc_2023atp.txt
# Renamed lc_2023aty_cleaned.txt to lc_2023aty.txt
# Renamed lc_2023atz_cleaned.txt to lc_2023atz.txt
# Renamed lc_2023auh_cleaned.txt to lc_2023auh.txt
# Renamed lc_2023auu_cleaned.txt to lc_2023auu.txt
# Renamed lc_2023ave_cleaned.txt to lc_2023ave.txt
# Renamed lc_2023avw_cleaned.txt to lc_2023avw.txt
# Renamed lc_2023axa_cleaned.txt to lc_2023axa.txt
# Renamed lc_2023axc_cleaned.txt to lc_2023axc.txt
# Renamed lc_2023baz_cleaned.txt to lc_2023baz.txt
# Renamed lc_2023bba_cleaned.txt to lc_2023bba.txt
# Renamed lc_2023bbi_cleaned.txt to lc_2023bbi.txt
# Renamed lc_2023bbt_cleaned.txt to lc_2023bbt.txt
# Renamed lc_2023bee_cleaned.txt to lc_2023bee.txt
# Renamed lc_2023bgq_cleaned.txt to lc_2023bgq.txt
# Renamed lc_2023bgt_cleaned.txt to lc_2023bgt.txt
# Renamed lc_2023bhp_cleaned.txt to lc_2023bhp.txt
# Renamed lc_2023bjr_cleaned.txt to lc_2023bjr.txt
# Renamed lc_2023bju_cleaned.txt to lc_2023bju.txt
# Renamed lc_2023bjv_cleaned.txt to lc_2023bjv.txt
# Renamed lc_2023blo_cleaned.txt to lc_2023blo.txt
# Renamed lc_2023blv_cleaned.txt to lc_2023blv.txt
# Renamed lc_2023bmf_cleaned.txt to lc_2023bmf.txt
# Renamed lc_2023bms_cleaned.txt to lc_2023bms.txt
# Renamed lc_2023bod_cleaned.txt to lc_2023bod.txt
# Renamed lc_2023boh_cleaned.txt to lc_2023boh.txt
# Renamed lc_2023bov_cleaned.txt to lc_2023bov.txt
# Renamed lc_2023bpc_cleaned.txt to lc_2023bpc.txt
# Renamed lc_2023bqj_cleaned.txt to lc_2023bqj.txt
# Renamed lc_2023bqn_cleaned.txt to lc_2023bqn.txt
# Renamed lc_2023bqp_cleaned.txt to lc_2023bqp.txt
# Renamed lc_2023bqr_cleaned.txt to lc_2023bqr.txt
# Renamed lc_2023bqv_cleaned.txt to lc_2023bqv.txt
# Renamed lc_2023bqz_cleaned.txt to lc_2023bqz.txt
# Renamed lc_2023bre_cleaned.txt to lc_2023bre.txt
# Renamed lc_2023bsd_cleaned.txt to lc_2023bsd.txt
# Renamed lc_2023bsr_cleaned.txt to lc_2023bsr.txt
# Renamed lc_2023bs_cleaned.txt to lc_2023bs.txt
# Renamed lc_2023btp_cleaned.txt to lc_2023btp.txt
# Renamed lc_2023btu_cleaned.txt to lc_2023btu.txt
# Renamed lc_2023bue_cleaned.txt to lc_2023bue.txt
# Renamed lc_2023buh_cleaned.txt to lc_2023buh.txt
# Renamed lc_2023bui_cleaned.txt to lc_2023bui.txt
# Renamed lc_2023buj_cleaned.txt to lc_2023buj.txt
# Renamed lc_2023bur_cleaned.txt to lc_2023bur.txt
# Renamed lc_2023bus_cleaned.txt to lc_2023bus.txt
# Renamed lc_2023bux_cleaned.txt to lc_2023bux.txt
# Renamed lc_2023bwv_cleaned.txt to lc_2023bwv.txt
# Renamed lc_2023bwx_cleaned.txt to lc_2023bwx.txt
# Renamed lc_2023bxf_cleaned.txt to lc_2023bxf.txt
# Renamed lc_2023bxq_cleaned.txt to lc_2023bxq.txt
# Renamed lc_2023bxt_cleaned.txt to lc_2023bxt.txt
# Renamed lc_2023bys_cleaned.txt to lc_2023bys.txt
# Renamed lc_2023bzw_cleaned.txt to lc_2023bzw.txt
# Renamed lc_2023caa_cleaned.txt to lc_2023caa.txt
# Renamed lc_2023cbn_cleaned.txt to lc_2023cbn.txt
# Renamed lc_2023cbr_cleaned.txt to lc_2023cbr.txt
# Renamed lc_2023ccg_cleaned.txt to lc_2023ccg.txt
# Renamed lc_2023ccu_cleaned.txt to lc_2023ccu.txt
# Renamed lc_2023cdd_cleaned.txt to lc_2023cdd.txt
# Renamed lc_2023cew_cleaned.txt to lc_2023cew.txt
# Renamed lc_2023cgi_cleaned.txt to lc_2023cgi.txt
# Renamed lc_2023cgk_cleaned.txt to lc_2023cgk.txt
# Renamed lc_2023chu_cleaned.txt to lc_2023chu.txt
# Renamed lc_2023chv_cleaned.txt to lc_2023chv.txt
# Renamed lc_2023cjf_cleaned.txt to lc_2023cjf.txt
# Renamed lc_2023cjj_cleaned.txt to lc_2023cjj.txt
# Renamed lc_2023cjm_cleaned.txt to lc_2023cjm.txt
# Renamed lc_2023cku_cleaned.txt to lc_2023cku.txt
# Renamed lc_2023cli_cleaned.txt to lc_2023cli.txt
# Renamed lc_2023cll_cleaned.txt to lc_2023cll.txt
# Renamed lc_2023clz_cleaned.txt to lc_2023clz.txt
# Renamed lc_2023cna_cleaned.txt to lc_2023cna.txt
# Renamed lc_2023cnm_cleaned.txt to lc_2023cnm.txt
# Renamed lc_2023coa_cleaned.txt to lc_2023coa.txt
# Renamed lc_2023cod_cleaned.txt to lc_2023cod.txt
# Renamed lc_2023cor_cleaned.txt to lc_2023cor.txt
# Renamed lc_2023cow_cleaned.txt to lc_2023cow.txt
# Renamed lc_2023crz_cleaned.txt to lc_2023crz.txt
# Renamed lc_2023csc_cleaned.txt to lc_2023csc.txt
# Renamed lc_2023cum_cleaned.txt to lc_2023cum.txt
# Renamed lc_2023cvk_cleaned.txt to lc_2023cvk.txt
# Renamed lc_2023cwy_cleaned.txt to lc_2023cwy.txt
# Renamed lc_2023cwz_cleaned.txt to lc_2023cwz.txt
# Renamed lc_2023cxc_cleaned.txt to lc_2023cxc.txt
# Renamed lc_2023cxd_cleaned.txt to lc_2023cxd.txt
# Renamed lc_2023cxg_cleaned.txt to lc_2023cxg.txt
# Renamed lc_2023cyf_cleaned.txt to lc_2023cyf.txt
# Renamed lc_2023cyi_cleaned.txt to lc_2023cyi.txt
# Renamed lc_2023dbj_cleaned.txt to lc_2023dbj.txt
# Renamed lc_2023ddy_cleaned.txt to lc_2023ddy.txt
# Renamed lc_2023dep_cleaned.txt to lc_2023dep.txt
# Renamed lc_2023deq_cleaned.txt to lc_2023deq.txt
# Renamed lc_2023dfb_cleaned.txt to lc_2023dfb.txt
# Renamed lc_2023dfr_cleaned.txt to lc_2023dfr.txt
# Renamed lc_2023dfx_cleaned.txt to lc_2023dfx.txt
# Renamed lc_2023dfz_cleaned.txt to lc_2023dfz.txt
# Renamed lc_2023dma_cleaned.txt to lc_2023dma.txt
# Renamed lc_2023dov_cleaned.txt to lc_2023dov.txt
# Renamed lc_2023dox_cleaned.txt to lc_2023dox.txt
# Renamed lc_2023dpq_cleaned.txt to lc_2023dpq.txt
# Renamed lc_2023dpu_cleaned.txt to lc_2023dpu.txt
# Renamed lc_2023dpz_cleaned.txt to lc_2023dpz.txt
# Renamed lc_2023dqd_cleaned.txt to lc_2023dqd.txt
# Renamed lc_2023dqh_cleaned.txt to lc_2023dqh.txt
# Renamed lc_2023dst_cleaned.txt to lc_2023dst.txt
# Renamed lc_2023duc_cleaned.txt to lc_2023duc.txt
# Renamed lc_2023dug_cleaned.txt to lc_2023dug.txt
# Renamed lc_2023dup_cleaned.txt to lc_2023dup.txt
# Renamed lc_2023dva_cleaned.txt to lc_2023dva.txt
# Renamed lc_2023dvj_cleaned.txt to lc_2023dvj.txt
# Renamed lc_2023dvq_cleaned.txt to lc_2023dvq.txt
# Renamed lc_2023dvz_cleaned.txt to lc_2023dvz.txt
# Renamed lc_2023dwl_cleaned.txt to lc_2023dwl.txt
# Renamed lc_2023dze_cleaned.txt to lc_2023dze.txt
# Renamed lc_2023ebl_cleaned.txt to lc_2023ebl.txt
# Renamed lc_2023ebq_cleaned.txt to lc_2023ebq.txt
# Renamed lc_2023ecd_cleaned.txt to lc_2023ecd.txt
# Renamed lc_2023edf_cleaned.txt to lc_2023edf.txt
# Renamed lc_2023edn_cleaned.txt to lc_2023edn.txt
# Renamed lc_2023edo_cleaned.txt to lc_2023edo.txt
# Renamed lc_2023edy_cleaned.txt to lc_2023edy.txt
# Renamed lc_2023eez_cleaned.txt to lc_2023eez.txt
# Renamed lc_2023egc_cleaned.txt to lc_2023egc.txt
# Renamed lc_2023egh_cleaned.txt to lc_2023egh.txt
# Renamed lc_2023egk_cleaned.txt to lc_2023egk.txt
# Renamed lc_2023egm_cleaned.txt to lc_2023egm.txt
# Renamed lc_2023egu_cleaned.txt to lc_2023egu.txt
# Renamed lc_2023ejj_cleaned.txt to lc_2023ejj.txt
# Renamed lc_2023ejl_cleaned.txt to lc_2023ejl.txt
# Renamed lc_2023ejp_cleaned.txt to lc_2023ejp.txt
# Renamed lc_2023ejy_cleaned.txt to lc_2023ejy.txt
# Renamed lc_2023ekc_cleaned.txt to lc_2023ekc.txt
# Renamed lc_2023eke_cleaned.txt to lc_2023eke.txt
# Renamed lc_2023elb_cleaned.txt to lc_2023elb.txt
# Renamed lc_2023elj_cleaned.txt to lc_2023elj.txt
# Renamed lc_2023elo_cleaned.txt to lc_2023elo.txt
# Renamed lc_2023eow_cleaned.txt to lc_2023eow.txt
# Renamed lc_2023epl_cleaned.txt to lc_2023epl.txt
# Renamed lc_2023epw_cleaned.txt to lc_2023epw.txt
# Renamed lc_2023eqh_cleaned.txt to lc_2023eqh.txt
# Renamed lc_2023eqj_cleaned.txt to lc_2023eqj.txt
# Renamed lc_2023eua_cleaned.txt to lc_2023eua.txt
# Renamed lc_2023eux_cleaned.txt to lc_2023eux.txt
# Renamed lc_2023evi_cleaned.txt to lc_2023evi.txt
# Renamed lc_2023evx_cleaned.txt to lc_2023evx.txt
# Renamed lc_2023exr_cleaned.txt to lc_2023exr.txt
# Renamed lc_2023exz_cleaned.txt to lc_2023exz.txt
# Renamed lc_2023ezg_cleaned.txt to lc_2023ezg.txt
# Renamed lc_2023ezt_cleaned.txt to lc_2023ezt.txt
# Renamed lc_2023fak_cleaned.txt to lc_2023fak.txt
# Renamed lc_2023far_cleaned.txt to lc_2023far.txt
# Renamed lc_2023fat_cleaned.txt to lc_2023fat.txt
# Renamed lc_2023fbr_cleaned.txt to lc_2023fbr.txt
# Renamed lc_2023fcv_cleaned.txt to lc_2023fcv.txt
# Renamed lc_2023fda_cleaned.txt to lc_2023fda.txt
# Renamed lc_2023fdj_cleaned.txt to lc_2023fdj.txt
# Renamed lc_2023fel_cleaned.txt to lc_2023fel.txt
# Renamed lc_2023fep_cleaned.txt to lc_2023fep.txt
# Renamed lc_2023ffq_cleaned.txt to lc_2023ffq.txt
# Renamed lc_2023fhl_cleaned.txt to lc_2023fhl.txt
# Renamed lc_2023fit_cleaned.txt to lc_2023fit.txt
# Renamed lc_2023flj_cleaned.txt to lc_2023flj.txt
# Renamed lc_2023fls_cleaned.txt to lc_2023fls.txt
# Renamed lc_2023fol_cleaned.txt to lc_2023fol.txt
# Renamed lc_2023fpc_cleaned.txt to lc_2023fpc.txt
# Renamed lc_2023fpe_cleaned.txt to lc_2023fpe.txt
# Renamed lc_2023fpo_cleaned.txt to lc_2023fpo.txt
# Renamed lc_2023fpq_cleaned.txt to lc_2023fpq.txt
# Renamed lc_2023fqu_cleaned.txt to lc_2023fqu.txt
# Renamed lc_2023fqz_cleaned.txt to lc_2023fqz.txt
# Renamed lc_2023ftx_cleaned.txt to lc_2023ftx.txt
# Renamed lc_2023fty_cleaned.txt to lc_2023fty.txt
# Renamed lc_2023fua_cleaned.txt to lc_2023fua.txt
# Renamed lc_2023fud_cleaned.txt to lc_2023fud.txt
# Renamed lc_2023fuo_cleaned.txt to lc_2023fuo.txt
# Renamed lc_2023fut_cleaned.txt to lc_2023fut.txt
# Renamed lc_2023fvg_cleaned.txt to lc_2023fvg.txt
# Renamed lc_2023fx_cleaned.txt to lc_2023fx.txt
# Renamed lc_2023fzf_cleaned.txt to lc_2023fzf.txt
# Renamed lc_2023gas_cleaned.txt to lc_2023gas.txt
# Renamed lc_2023gcj_cleaned.txt to lc_2023gcj.txt
# Renamed lc_2023gdn_cleaned.txt to lc_2023gdn.txt
# Renamed lc_2023gdu_cleaned.txt to lc_2023gdu.txt
# Renamed lc_2023ghs_cleaned.txt to lc_2023ghs.txt
# Renamed lc_2023gim_cleaned.txt to lc_2023gim.txt
# Renamed lc_2023gio_cleaned.txt to lc_2023gio.txt
# Renamed lc_2023gjx_cleaned.txt to lc_2023gjx.txt
# Renamed lc_2023gjz_cleaned.txt to lc_2023gjz.txt
# Renamed lc_2023gj_cleaned.txt to lc_2023gj.txt
# Renamed lc_2023gns_cleaned.txt to lc_2023gns.txt
# Renamed lc_2023gnx_cleaned.txt to lc_2023gnx.txt
# Renamed lc_2023gos_cleaned.txt to lc_2023gos.txt
# Renamed lc_2023gpu_cleaned.txt to lc_2023gpu.txt
# Renamed lc_2023gp_cleaned.txt to lc_2023gp.txt
# Renamed lc_2023gr_cleaned.txt to lc_2023gr.txt
# Renamed lc_2023gsf_cleaned.txt to lc_2023gsf.txt
# Renamed lc_2023gsh_cleaned.txt to lc_2023gsh.txt
# Renamed lc_2023gsp_cleaned.txt to lc_2023gsp.txt
# Renamed lc_2023gss_cleaned.txt to lc_2023gss.txt
# Renamed lc_2023gs_cleaned.txt to lc_2023gs.txt
# Renamed lc_2023gtp_cleaned.txt to lc_2023gtp.txt
# Renamed lc_2023gtx_cleaned.txt to lc_2023gtx.txt
# Renamed lc_2023guj_cleaned.txt to lc_2023guj.txt
# Renamed lc_2023gup_cleaned.txt to lc_2023gup.txt
# Renamed lc_2023gu_cleaned.txt to lc_2023gu.txt
# Renamed lc_2023gwh_cleaned.txt to lc_2023gwh.txt
# Renamed lc_2023gxh_cleaned.txt to lc_2023gxh.txt
# Renamed lc_2023gx_cleaned.txt to lc_2023gx.txt
# Renamed lc_2023gza_cleaned.txt to lc_2023gza.txt
# Renamed lc_2023gzq_cleaned.txt to lc_2023gzq.txt
# Renamed lc_2023gzz_cleaned.txt to lc_2023gzz.txt
# Renamed lc_2023hac_cleaned.txt to lc_2023hac.txt
# Renamed lc_2023had_cleaned.txt to lc_2023had.txt
# Renamed lc_2023hao_cleaned.txt to lc_2023hao.txt
# Renamed lc_2023hap_cleaned.txt to lc_2023hap.txt
# Renamed lc_2023hdl_cleaned.txt to lc_2023hdl.txt
# Renamed lc_2023hdy_cleaned.txt to lc_2023hdy.txt
# Renamed lc_2023hdz_cleaned.txt to lc_2023hdz.txt
# Renamed lc_2023hea_cleaned.txt to lc_2023hea.txt
# Renamed lc_2023heb_cleaned.txt to lc_2023heb.txt
# Renamed lc_2023hec_cleaned.txt to lc_2023hec.txt
# Renamed lc_2023hga_cleaned.txt to lc_2023hga.txt
# Renamed lc_2023hgb_cleaned.txt to lc_2023hgb.txt
# Renamed lc_2023hgd_cleaned.txt to lc_2023hgd.txt
# Renamed lc_2023hgg_cleaned.txt to lc_2023hgg.txt
# Renamed lc_2023hgm_cleaned.txt to lc_2023hgm.txt
# Renamed lc_2023hhg_cleaned.txt to lc_2023hhg.txt
# Renamed lc_2023hhi_cleaned.txt to lc_2023hhi.txt
# Renamed lc_2023hhl_cleaned.txt to lc_2023hhl.txt
# Renamed lc_2023hhs_cleaned.txt to lc_2023hhs.txt
# Renamed lc_2023hif_cleaned.txt to lc_2023hif.txt
# Renamed lc_2023hiu_cleaned.txt to lc_2023hiu.txt
# Renamed lc_2023hjr_cleaned.txt to lc_2023hjr.txt
# Renamed lc_2023hka_cleaned.txt to lc_2023hka.txt
# Renamed lc_2023hkj_cleaned.txt to lc_2023hkj.txt
# Renamed lc_2023hma_cleaned.txt to lc_2023hma.txt
# Renamed lc_2023hmp_cleaned.txt to lc_2023hmp.txt
# Renamed lc_2023hnb_cleaned.txt to lc_2023hnb.txt
# Renamed lc_2023hnd_cleaned.txt to lc_2023hnd.txt
# Renamed lc_2023hng_cleaned.txt to lc_2023hng.txt
# Renamed lc_2023ho_cleaned.txt to lc_2023ho.txt
# Renamed lc_2023hpf_cleaned.txt to lc_2023hpf.txt
# Renamed lc_2023hpn_cleaned.txt to lc_2023hpn.txt
# Renamed lc_2023hqg_cleaned.txt to lc_2023hqg.txt
# Renamed lc_2023hqh_cleaned.txt to lc_2023hqh.txt
# Renamed lc_2023hqz_cleaned.txt to lc_2023hqz.txt
# Renamed lc_2023hra_cleaned.txt to lc_2023hra.txt
# Renamed lc_2023hsk_cleaned.txt to lc_2023hsk.txt
# Renamed lc_2023hti_cleaned.txt to lc_2023hti.txt
# Renamed lc_2023htj_cleaned.txt to lc_2023htj.txt
# Renamed lc_2023htk_cleaned.txt to lc_2023htk.txt
# Renamed lc_2023hto_cleaned.txt to lc_2023hto.txt
# Renamed lc_2023htp_cleaned.txt to lc_2023htp.txt
# Renamed lc_2023hts_cleaned.txt to lc_2023hts.txt
# Renamed lc_2023hua_cleaned.txt to lc_2023hua.txt
# Renamed lc_2023hvz_cleaned.txt to lc_2023hvz.txt
# Renamed lc_2023hwc_cleaned.txt to lc_2023hwc.txt
# Renamed lc_2023hwj_cleaned.txt to lc_2023hwj.txt
# Renamed lc_2023hxz_cleaned.txt to lc_2023hxz.txt
# Renamed lc_2023hym_cleaned.txt to lc_2023hym.txt
# Renamed lc_2023hy_cleaned.txt to lc_2023hy.txt
# Renamed lc_2023ied_cleaned.txt to lc_2023ied.txt
# Renamed lc_2023ie_cleaned.txt to lc_2023ie.txt
# Renamed lc_2023iio_cleaned.txt to lc_2023iio.txt
# Renamed lc_2023ikp_cleaned.txt to lc_2023ikp.txt
# Renamed lc_2023inb_cleaned.txt to lc_2023inb.txt
# Renamed lc_2023iny_cleaned.txt to lc_2023iny.txt
# Renamed lc_2023iua_cleaned.txt to lc_2023iua.txt
# Renamed lc_2023iuk_cleaned.txt to lc_2023iuk.txt
# Renamed lc_2023iwl_cleaned.txt to lc_2023iwl.txt
# Renamed lc_2023ixg_cleaned.txt to lc_2023ixg.txt
# Renamed lc_2023iyb_cleaned.txt to lc_2023iyb.txt
# Renamed lc_2023iy_cleaned.txt to lc_2023iy.txt
# Renamed lc_2023jaw_cleaned.txt to lc_2023jaw.txt
# Renamed lc_2023jba_cleaned.txt to lc_2023jba.txt
# Renamed lc_2023jbj_cleaned.txt to lc_2023jbj.txt
# Renamed lc_2023jia_cleaned.txt to lc_2023jia.txt
# Renamed lc_2023jml_cleaned.txt to lc_2023jml.txt
# Renamed lc_2023jo_cleaned.txt to lc_2023jo.txt
# Renamed lc_2023jtz_cleaned.txt to lc_2023jtz.txt
# Renamed lc_2023jub_cleaned.txt to lc_2023jub.txt
# Renamed lc_2023ma_cleaned.txt to lc_2023ma.txt
# Renamed lc_2023mf_cleaned.txt to lc_2023mf.txt
# Renamed lc_2023mg_cleaned.txt to lc_2023mg.txt
# Renamed lc_2023ms_cleaned.txt to lc_2023ms.txt
# Renamed lc_2023nm_cleaned.txt to lc_2023nm.txt
# Renamed lc_2023np_cleaned.txt to lc_2023np.txt
# Renamed lc_2023qb_cleaned.txt to lc_2023qb.txt
# Renamed lc_2023rn_cleaned.txt to lc_2023rn.txt
# Renamed lc_2023rr_cleaned.txt to lc_2023rr.txt
# Renamed lc_2023rt_cleaned.txt to lc_2023rt.txt
# Renamed lc_2023su_cleaned.txt to lc_2023su.txt
# Renamed lc_2023tg_cleaned.txt to lc_2023tg.txt
# Renamed lc_2023ua_cleaned.txt to lc_2023ua.txt
# Renamed lc_2023ub_cleaned.txt to lc_2023ub.txt
# Renamed lc_2023ut_cleaned.txt to lc_2023ut.txt
# Renamed lc_2023wj_cleaned.txt to lc_2023wj.txt
# Renamed lc_2023wo_cleaned.txt to lc_2023wo.txt
# Renamed lc_2023wq_cleaned.txt to lc_2023wq.txt
# Renamed lc_2023xk_cleaned.txt to lc_2023xk.txt
# Renamed lc_2023xq_cleaned.txt to lc_2023xq.txt
# Renamed lc_2023xw_cleaned.txt to lc_2023xw.txt
# Renamed lc_2023xx_cleaned.txt to lc_2023xx.txt
# Renamed lc_2023xz_cleaned.txt to lc_2023xz.txt
# Renamed lc_2023yp_cleaned.txt to lc_2023yp.txt
# Renamed lc_2023yx_cleaned.txt to lc_2023yx.txt
# Renamed lc_2023yz_cleaned.txt to lc_2023yz.txt
# Renamed lc_2023zt_cleaned.txt to lc_2023zt.txt
# Renamed lc_GRB191016a_cleaned.txt to lc_GRB191016a.txt
# Suffixes removed successfully

# %%
import os

def remove_lc_prefix(txt_files_directory):
    # Traverse each file in the directory
    for file_name in os.listdir(txt_files_directory):
        file_path = os.path.join(txt_files_directory, file_name)
        # Check if the file starts with "lc_"
        if file_name.startswith("lc_"):
            # Remove the "lc_" prefix from the file name
            new_file_name = file_name.replace("lc_", "")
            os.rename(file_path, os.path.join(txt_files_directory, new_file_name))
            print(f"Renamed {file_name} to {new_file_name}")

def main():
    # Directory containing the TXT files
    txt_files_directory = r"C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\TXT_Files"

    # Remove "lc_" from file names
    print("Removing 'lc_' from file names...")
    remove_lc_prefix(txt_files_directory)
    print("Prefix removed successfully")

if __name__ == "__main__":
    main()
# Out:
# Removing 'lc_' from file names...
# Renamed lc_2018eel.txt to 2018eel.txt
# Renamed lc_2018emt.txt to 2018emt.txt
# Renamed lc_2018eny.txt to 2018eny.txt
# Renamed lc_2018eoa.txt to 2018eoa.txt
# Renamed lc_2018eoc.txt to 2018eoc.txt
# Renamed lc_2018eod.txt to 2018eod.txt
# Renamed lc_2018eph.txt to 2018eph.txt
# Renamed lc_2018eqo.txt to 2018eqo.txt
# Renamed lc_2018esp.txt to 2018esp.txt
# Renamed lc_2018esw.txt to 2018esw.txt
# Renamed lc_2018evo.txt to 2018evo.txt
# Renamed lc_2018exc.txt to 2018exc.txt
# Renamed lc_2018fbm.txt to 2018fbm.txt
# Renamed lc_2018fdw.txt to 2018fdw.txt
# Renamed lc_2018fdx.txt to 2018fdx.txt
# Renamed lc_2018fgb.txt to 2018fgb.txt
# Renamed lc_2018fhs.txt to 2018fhs.txt
# Renamed lc_2018fhw.txt to 2018fhw.txt
# Renamed lc_2018fhw_detrended.txt to 2018fhw_detrended.txt
# Renamed lc_2018flj.txt to 2018flj.txt
# Renamed lc_2018fll.txt to 2018fll.txt
# Renamed lc_2018flq.txt to 2018flq.txt
# Renamed lc_2018flr.txt to 2018flr.txt
# Renamed lc_2018flt.txt to 2018flt.txt
# Renamed lc_2018flz.txt to 2018flz.txt
# Renamed lc_2018fmg.txt to 2018fmg.txt
# Renamed lc_2018fmm.txt to 2018fmm.txt
# Renamed lc_2018fmn.txt to 2018fmn.txt
# Renamed lc_2018fns.txt to 2018fns.txt
# Renamed lc_2018fqn.txt to 2018fqn.txt
# Renamed lc_2018ftf.txt to 2018ftf.txt
# Renamed lc_2018fub.txt to 2018fub.txt
# Renamed lc_2018fvi.txt to 2018fvi.txt
# Renamed lc_2018fvi_detrended.txt to 2018fvi_detrended.txt
# Renamed lc_2018fwd.txt to 2018fwd.txt
# Renamed lc_2018fwi.txt to 2018fwi.txt
# Renamed lc_2018fwk.txt to 2018fwk.txt
# Renamed lc_2018fwm.txt to 2018fwm.txt
# Renamed lc_2018fwr.txt to 2018fwr.txt
# Renamed lc_2018fxj.txt to 2018fxj.txt
# Renamed lc_2018fxl.txt to 2018fxl.txt
# Renamed lc_2018fzi.txt to 2018fzi.txt
# Renamed lc_2018gey.txt to 2018gey.txt
# Renamed lc_2018gfj.txt to 2018gfj.txt
# Renamed lc_2018gfk.txt to 2018gfk.txt
# Renamed lc_2018gku.txt to 2018gku.txt
# Renamed lc_2018glp.txt to 2018glp.txt
# Renamed lc_2018glq.txt to 2018glq.txt
# Renamed lc_2018glv.txt to 2018glv.txt
# Renamed lc_2018glw.txt to 2018glw.txt
# Renamed lc_2018goa.txt to 2018goa.txt
# Renamed lc_2018gqc.txt to 2018gqc.txt
# Renamed lc_2018grv.txt to 2018grv.txt
# Renamed lc_2018gsg.txt to 2018gsg.txt
# Renamed lc_2018gty.txt to 2018gty.txt
# Renamed lc_2018gum.txt to 2018gum.txt
# Renamed lc_2018gxi.txt to 2018gxi.txt
# Renamed lc_2018hac.txt to 2018hac.txt
# Renamed lc_2018har.txt to 2018har.txt
# Renamed lc_2018has.txt to 2018has.txt
# Renamed lc_2018hbw.txt to 2018hbw.txt
# Renamed lc_2018hdl.txt to 2018hdl.txt
# Renamed lc_2018hdo.txt to 2018hdo.txt
# Renamed lc_2018hdq.txt to 2018hdq.txt
# Renamed lc_2018hgc.txt to 2018hgc.txt
# Renamed lc_2018hgi.txt to 2018hgi.txt
# Renamed lc_2018hgl.txt to 2018hgl.txt
# Renamed lc_2018hib.txt to 2018hib.txt
# Renamed lc_2018hib_detrended.txt to 2018hib_detrended.txt
# Renamed lc_2018hjo.txt to 2018hjo.txt
# Renamed lc_2018hjr.txt to 2018hjr.txt
# Renamed lc_2018hka.txt to 2018hka.txt
# Renamed lc_2018hkb.txt to 2018hkb.txt
# Renamed lc_2018hkh.txt to 2018hkh.txt
# Renamed lc_2018hks.txt to 2018hks.txt
# Renamed lc_2018hkx.txt to 2018hkx.txt
# Renamed lc_2018hlp.txt to 2018hlp.txt
# Renamed lc_2018hmo.txt to 2018hmo.txt
# Renamed lc_2018hnc.txt to 2018hnc.txt
# Renamed lc_2018hnq.txt to 2018hnq.txt
# Renamed lc_2018hoc.txt to 2018hoc.txt
# Renamed lc_2018hpd.txt to 2018hpd.txt
# Renamed lc_2018hpj.txt to 2018hpj.txt
# Renamed lc_2018hps.txt to 2018hps.txt
# Renamed lc_2018hpu.txt to 2018hpu.txt
# Renamed lc_2018hql.txt to 2018hql.txt
# Renamed lc_2018hrs.txt to 2018hrs.txt
# Renamed lc_2018hsf.txt to 2018hsf.txt
# Renamed lc_2018hsq.txt to 2018hsq.txt
# Renamed lc_2018hss.txt to 2018hss.txt
# Renamed lc_2018hss_detrended.txt to 2018hss_detrended.txt
# Renamed lc_2018hsz.txt to 2018hsz.txt
# Renamed lc_2018hte.txt to 2018hte.txt
# Renamed lc_2018huc.txt to 2018huc.txt
# Renamed lc_2018hue.txt to 2018hue.txt
# Renamed lc_2018hum.txt to 2018hum.txt
# Renamed lc_2018hxq.txt to 2018hxq.txt
# Renamed lc_2018hyq.txt to 2018hyq.txt
# Renamed lc_2018hyx.txt to 2018hyx.txt
# Renamed lc_2018hyy.txt to 2018hyy.txt
# Renamed lc_2018hzh.txt to 2018hzh.txt
# Renamed lc_2018ien.txt to 2018ien.txt
# Renamed lc_2018ieu.txt to 2018ieu.txt
# Renamed lc_2018iez.txt to 2018iez.txt
# Renamed lc_2018ifa.txt to 2018ifa.txt
# Renamed lc_2018ifh.txt to 2018ifh.txt
# Renamed lc_2018ifm.txt to 2018ifm.txt
# Renamed lc_2018ift.txt to 2018ift.txt
# Renamed lc_2018ihp.txt to 2018ihp.txt
# Renamed lc_2018ihq.txt to 2018ihq.txt
# Renamed lc_2018iht.txt to 2018iht.txt
# Renamed lc_2018iin.txt to 2018iin.txt
# Renamed lc_2018ijn.txt to 2018ijn.txt
# Renamed lc_2018ime.txt to 2018ime.txt
# Renamed lc_2018ioa.txt to 2018ioa.txt
# Renamed lc_2018iti.txt to 2018iti.txt
# Renamed lc_2018itr.txt to 2018itr.txt
# Renamed lc_2018iuj.txt to 2018iuj.txt
# Renamed lc_2018iwg.txt to 2018iwg.txt
# Renamed lc_2018iwl.txt to 2018iwl.txt
# Renamed lc_2018iyh.txt to 2018iyh.txt
# Renamed lc_2018iyx.txt to 2018iyx.txt
# Renamed lc_2018izg.txt to 2018izg.txt
# Renamed lc_2018izr.txt to 2018izr.txt
# Renamed lc_2018izt.txt to 2018izt.txt
# Renamed lc_2018jad.txt to 2018jad.txt
# Renamed lc_2018jbn.txt to 2018jbn.txt
# Renamed lc_2018jco.txt to 2018jco.txt
# Renamed lc_2018jdc.txt to 2018jdc.txt
# Renamed lc_2018jeb.txt to 2018jeb.txt
# Renamed lc_2018jej.txt to 2018jej.txt
# Renamed lc_2018jfk.txt to 2018jfk.txt
# Renamed lc_2018jgq.txt to 2018jgq.txt
# Renamed lc_2018jhc.txt to 2018jhc.txt
# Renamed lc_2018jhq.txt to 2018jhq.txt
# Renamed lc_2018jih.txt to 2018jih.txt
# Renamed lc_2018jjc.txt to 2018jjc.txt
# Renamed lc_2018jjd.txt to 2018jjd.txt
# Renamed lc_2018jjh.txt to 2018jjh.txt
# Renamed lc_2018jjs.txt to 2018jjs.txt
# Renamed lc_2018jju.txt to 2018jju.txt
# Renamed lc_2018jkg.txt to 2018jkg.txt
# Renamed lc_2018jms.txt to 2018jms.txt
# Renamed lc_2018jmt.txt to 2018jmt.txt
# Renamed lc_2018jnd.txt to 2018jnd.txt
# Renamed lc_2018jpy.txt to 2018jpy.txt
# Renamed lc_2018jri.txt to 2018jri.txt
# Renamed lc_2018jro.txt to 2018jro.txt
# Renamed lc_2018jsl.txt to 2018jsl.txt
# Renamed lc_2018jtu.txt to 2018jtu.txt
# Renamed lc_2018jtv.txt to 2018jtv.txt
# Renamed lc_2018jwd.txt to 2018jwd.txt
# Renamed lc_2018jwg.txt to 2018jwg.txt
# Renamed lc_2018jwh.txt to 2018jwh.txt
# Renamed lc_2018jwi.txt to 2018jwi.txt
# Renamed lc_2018jwj.txt to 2018jwj.txt
# Renamed lc_2018kah.txt to 2018kah.txt
# Renamed lc_2018kao.txt to 2018kao.txt
# Renamed lc_2018kbi.txt to 2018kbi.txt
# Renamed lc_2018kbq.txt to 2018kbq.txt
# Renamed lc_2018kcu.txt to 2018kcu.txt
# Renamed lc_2018kfv.txt to 2018kfv.txt
# Renamed lc_2018kfv_detrended.txt to 2018kfv_detrended.txt
# Renamed lc_2018kgg.txt to 2018kgg.txt
# Renamed lc_2018kib.txt to 2018kib.txt
# Renamed lc_2018kif.txt to 2018kif.txt
# Renamed lc_2018kig.txt to 2018kig.txt
# Renamed lc_2018kih.txt to 2018kih.txt
# Renamed lc_2018kjp.txt to 2018kjp.txt
# Renamed lc_2018knl.txt to 2018knl.txt
# Renamed lc_2018koy.txt to 2018koy.txt
# Renamed lc_2018kpc.txt to 2018kpc.txt
# Renamed lc_2018kqk.txt to 2018kqk.txt
# Renamed lc_2018kqz.txt to 2018kqz.txt
# Renamed lc_2018krw.txt to 2018krw.txt
# Renamed lc_2018ksi.txt to 2018ksi.txt
# Renamed lc_2018ksr.txt to 2018ksr.txt
# Renamed lc_2018kuo.txt to 2018kuo.txt
# Renamed lc_2018kuv.txt to 2018kuv.txt
# Renamed lc_2018kvc.txt to 2018kvc.txt
# Renamed lc_2018kvr.txt to 2018kvr.txt
# Renamed lc_2018kvz.txt to 2018kvz.txt
# Renamed lc_2018kwm.txt to 2018kwm.txt
# Renamed lc_2018kwo.txt to 2018kwo.txt
# Renamed lc_2018lab.txt to 2018lab.txt
# Renamed lc_2018lad.txt to 2018lad.txt
# Renamed lc_2018lit.txt to 2018lit.txt
# Renamed lc_2018lla.txt to 2018lla.txt
# Renamed lc_2018lml.txt to 2018lml.txt
# Renamed lc_2018lne.txt to 2018lne.txt
# Renamed lc_2018lot.txt to 2018lot.txt
# Renamed lc_2019aan.txt to 2019aan.txt
# Renamed lc_2019aaq.txt to 2019aaq.txt
# Renamed lc_2019aay.txt to 2019aay.txt
# Renamed lc_2019aba.txt to 2019aba.txt
# Renamed lc_2019abb.txt to 2019abb.txt
# Renamed lc_2019abc.txt to 2019abc.txt
# Renamed lc_2019aby.txt to 2019aby.txt
# Renamed lc_2019ach.txt to 2019ach.txt
# Renamed lc_2019aeg.txt to 2019aeg.txt
# Renamed lc_2019aen.txt to 2019aen.txt
# Renamed lc_2019aeu.txt to 2019aeu.txt
# Renamed lc_2019agu.txt to 2019agu.txt
# Renamed lc_2019ahk.txt to 2019ahk.txt
# Renamed lc_2019aib.txt to 2019aib.txt
# Renamed lc_2019aih.txt to 2019aih.txt
# Renamed lc_2019ait.txt to 2019ait.txt
# Renamed lc_2019ajf.txt to 2019ajf.txt
# Renamed lc_2019ako.txt to 2019ako.txt
# Renamed lc_2019alb.txt to 2019alb.txt
# Renamed lc_2019alj.txt to 2019alj.txt
# Renamed lc_2019all.txt to 2019all.txt
# Renamed lc_2019alq.txt to 2019alq.txt
# Renamed lc_2019alv.txt to 2019alv.txt
# Renamed lc_2019ane.txt to 2019ane.txt
# Renamed lc_2019ank.txt to 2019ank.txt
# Renamed lc_2019any.txt to 2019any.txt
# Renamed lc_2019aqe.txt to 2019aqe.txt
# Renamed lc_2019arw.txt to 2019arw.txt
# Renamed lc_2019atc.txt to 2019atc.txt
# Renamed lc_2019auk.txt to 2019auk.txt
# Renamed lc_2019axh.txt to 2019axh.txt
# Renamed lc_2019axj.txt to 2019axj.txt
# Renamed lc_2019ayy.txt to 2019ayy.txt
# Renamed lc_2019azi.txt to 2019azi.txt
# Renamed lc_2019bap.txt to 2019bap.txt
# Renamed lc_2019bca.txt to 2019bca.txt
# Renamed lc_2019bcp.txt to 2019bcp.txt
# Renamed lc_2019bcu.txt to 2019bcu.txt
# Renamed lc_2019bea.txt to 2019bea.txt
# Renamed lc_2019beb.txt to 2019beb.txt
# Renamed lc_2019bes.txt to 2019bes.txt
# Renamed lc_2019bet.txt to 2019bet.txt
# Renamed lc_2019beu.txt to 2019beu.txt
# Renamed lc_2019bfb.txt to 2019bfb.txt
# Renamed lc_2019bfd.txt to 2019bfd.txt
# Renamed lc_2019bfz.txt to 2019bfz.txt
# Renamed lc_2019bgo.txt to 2019bgo.txt
# Renamed lc_2019bgp.txt to 2019bgp.txt
# Renamed lc_2019bip.txt to 2019bip.txt
# Renamed lc_2019biq.txt to 2019biq.txt
# Renamed lc_2019biu.txt to 2019biu.txt
# Renamed lc_2019bnk.txt to 2019bnk.txt
# Renamed lc_2019boo.txt to 2019boo.txt
# Renamed lc_2019bop.txt to 2019bop.txt
# Renamed lc_2019boq.txt to 2019boq.txt
# Renamed lc_2019box.txt to 2019box.txt
# Renamed lc_2019bqk.txt to 2019bqk.txt
# Renamed lc_2019bql.txt to 2019bql.txt
# Renamed lc_2019bsw.txt to 2019bsw.txt
# Renamed lc_2019bvp.txt to 2019bvp.txt
# Renamed lc_2019bwb.txt to 2019bwb.txt
# Renamed lc_2019bwo.txt to 2019bwo.txt
# Renamed lc_2019bwu.txt to 2019bwu.txt
# Renamed lc_2019bxg.txt to 2019bxg.txt
# Renamed lc_2019bxi.txt to 2019bxi.txt
# Renamed lc_2019bxl.txt to 2019bxl.txt
# Renamed lc_2019caa.txt to 2019caa.txt
# Renamed lc_2019cdy.txt to 2019cdy.txt
# Renamed lc_2019cgy.txt to 2019cgy.txt
# Renamed lc_2019cix.txt to 2019cix.txt
# Renamed lc_2019cj.txt to 2019cj.txt
# Renamed lc_2019cjp.txt to 2019cjp.txt
# Renamed lc_2019cjz.txt to 2019cjz.txt
# Renamed lc_2019clt.txt to 2019clt.txt
# Renamed lc_2019clu.txt to 2019clu.txt
# Renamed lc_2019cmb.txt to 2019cmb.txt
# Renamed lc_2019cmf.txt to 2019cmf.txt
# Renamed lc_2019cml.txt to 2019cml.txt
# Renamed lc_2019coc.txt to 2019coc.txt
# Renamed lc_2019con.txt to 2019con.txt
# Renamed lc_2019cos.txt to 2019cos.txt
# Renamed lc_2019cot.txt to 2019cot.txt
# Renamed lc_2019cou.txt to 2019cou.txt
# Renamed lc_2019cow.txt to 2019cow.txt
# Renamed lc_2019coz.txt to 2019coz.txt
# Renamed lc_2019cqf.txt to 2019cqf.txt
# Renamed lc_2019cqi.txt to 2019cqi.txt
# Renamed lc_2019cqk.txt to 2019cqk.txt
# Renamed lc_2019cql.txt to 2019cql.txt
# Renamed lc_2019crw.txt to 2019crw.txt
# Renamed lc_2019crx.txt to 2019crx.txt
# Renamed lc_2019crz.txt to 2019crz.txt
# Renamed lc_2019cwr.txt to 2019cwr.txt
# Renamed lc_2019cxt.txt to 2019cxt.txt
# Renamed lc_2019czn.txt to 2019czn.txt
# Renamed lc_2019dbm.txt to 2019dbm.txt
# Renamed lc_2019dcj.txt to 2019dcj.txt
# Renamed lc_2019ddc.txt to 2019ddc.txt
# Renamed lc_2019deo.txt to 2019deo.txt
# Renamed lc_2019dfr.txt to 2019dfr.txt
# Renamed lc_2019dhm.txt to 2019dhm.txt
# Renamed lc_2019dhz.txt to 2019dhz.txt
# Renamed lc_2019din.txt to 2019din.txt
# Renamed lc_2019dit.txt to 2019dit.txt
# Renamed lc_2019djd.txt to 2019djd.txt
# Renamed lc_2019dji.txt to 2019dji.txt
# Renamed lc_2019dke.txt to 2019dke.txt
# Renamed lc_2019dng.txt to 2019dng.txt
# Renamed lc_2019dns.txt to 2019dns.txt
# Renamed lc_2019dov.txt to 2019dov.txt
# Renamed lc_2019dpd.txt to 2019dpd.txt
# Renamed lc_2019dpz.txt to 2019dpz.txt
# Renamed lc_2019dqg.txt to 2019dqg.txt
# Renamed lc_2019dsn.txt to 2019dsn.txt
# Renamed lc_2019dtv.txt to 2019dtv.txt
# Renamed lc_2019dut.txt to 2019dut.txt
# Renamed lc_2019dwl.txt to 2019dwl.txt
# Renamed lc_2019dww.txt to 2019dww.txt
# Renamed lc_2019dzc.txt to 2019dzc.txt
# Renamed lc_2019dzs.txt to 2019dzs.txt
# Renamed lc_2019ebe.txt to 2019ebe.txt
# Renamed lc_2019ebh.txt to 2019ebh.txt
# Renamed lc_2019ecn.txt to 2019ecn.txt
# Renamed lc_2019edh.txt to 2019edh.txt
# Renamed lc_2019egw.txt to 2019egw.txt
# Renamed lc_2019ehv.txt to 2019ehv.txt
# Renamed lc_2019ehx.txt to 2019ehx.txt
# Renamed lc_2019ehy.txt to 2019ehy.txt
# Renamed lc_2019ekk.txt to 2019ekk.txt
# Renamed lc_2019ekn.txt to 2019ekn.txt
# Renamed lc_2019ekp.txt to 2019ekp.txt
# Renamed lc_2019erz.txt to 2019erz.txt
# Renamed lc_2019esa.txt to 2019esa.txt
# Renamed lc_2019esl.txt to 2019esl.txt
# Renamed lc_2019esm.txt to 2019esm.txt
# Renamed lc_2019exu.txt to 2019exu.txt
# Renamed lc_2019fcc.txt to 2019fcc.txt
# Renamed lc_2019fir.txt to 2019fir.txt
# Renamed lc_2019fis.txt to 2019fis.txt
# Renamed lc_2019fjs.txt to 2019fjs.txt
# Renamed lc_2019fp.txt to 2019fp.txt
# Renamed lc_2019gac.txt to 2019gac.txt
# Renamed lc_2019gak.txt to 2019gak.txt
# Renamed lc_2019gb.txt to 2019gb.txt
# Renamed lc_2019gdc.txt to 2019gdc.txt
# Renamed lc_2019gdg.txt to 2019gdg.txt
# Renamed lc_2019gdy.txt to 2019gdy.txt
# Renamed lc_2019gg.txt to 2019gg.txt
# Renamed lc_2019gn.txt to 2019gn.txt
# Renamed lc_2019gqv.txt to 2019gqv.txt
# Renamed lc_2019guh.txt to 2019guh.txt
# Renamed lc_2019gvc.txt to 2019gvc.txt
# Renamed lc_2019gvi.txt to 2019gvi.txt
# Renamed lc_2019gvp.txt to 2019gvp.txt
# Renamed lc_2019gwq.txt to 2019gwq.txt
# Renamed lc_2019gws.txt to 2019gws.txt
# Renamed lc_2019gyb.txt to 2019gyb.txt
# Renamed lc_2019gzu.txt to 2019gzu.txt
# Renamed lc_2019hcn.txt to 2019hcn.txt
# Renamed lc_2019hit.txt to 2019hit.txt
# Renamed lc_2019hkx.txt to 2019hkx.txt
# Renamed lc_2019hlb.txt to 2019hlb.txt
# Renamed lc_2019hmh.txt to 2019hmh.txt
# Renamed lc_2019hnp.txt to 2019hnp.txt
# Renamed lc_2019hpg.txt to 2019hpg.txt
# Renamed lc_2019hrs.txt to 2019hrs.txt
# Renamed lc_2019hsc.txt to 2019hsc.txt
# Renamed lc_2019hsl.txt to 2019hsl.txt
# Renamed lc_2019hsq.txt to 2019hsq.txt
# Renamed lc_2019htm.txt to 2019htm.txt
# Renamed lc_2019htv.txt to 2019htv.txt
# Renamed lc_2019htx.txt to 2019htx.txt
# Renamed lc_2019hvx.txt to 2019hvx.txt
# Renamed lc_2019hyu.txt to 2019hyu.txt
# Renamed lc_2019hzo.txt to 2019hzo.txt
# Renamed lc_2019hzq.txt to 2019hzq.txt
# Renamed lc_2019iac.txt to 2019iac.txt
# Renamed lc_2019iar.txt to 2019iar.txt
# Renamed lc_2019ibg.txt to 2019ibg.txt
# Renamed lc_2019ifd.txt to 2019ifd.txt
# Renamed lc_2019ify.txt to 2019ify.txt
# Renamed lc_2019ihi.txt to 2019ihi.txt
# Renamed lc_2019iio.txt to 2019iio.txt
# Renamed lc_2019iiv.txt to 2019iiv.txt
# Renamed lc_2019iy.txt to 2019iy.txt
# Renamed lc_2019jh.txt to 2019jh.txt
# Renamed lc_2019jom.txt to 2019jom.txt
# Renamed lc_2019jor.txt to 2019jor.txt
# Renamed lc_2019jyj.txt to 2019jyj.txt
# Renamed lc_2019kag.txt to 2019kag.txt
# Renamed lc_2019kh.txt to 2019kh.txt
# Renamed lc_2019khg.txt to 2019khg.txt
# Renamed lc_2019kim.txt to 2019kim.txt
# Renamed lc_2019kli.txt to 2019kli.txt
# Renamed lc_2019kll.txt to 2019kll.txt
# Renamed lc_2019kqd.txt to 2019kqd.txt
# Renamed lc_2019kqq.txt to 2019kqq.txt
# Renamed lc_2019krd.txt to 2019krd.txt
# Renamed lc_2019krj.txt to 2019krj.txt
# Renamed lc_2019kt.txt to 2019kt.txt
# Renamed lc_2019kvh.txt to 2019kvh.txt
# Renamed lc_2019kwc.txt to 2019kwc.txt
# Renamed lc_2019lbm.txt to 2019lbm.txt
# Renamed lc_2019llb.txt to 2019llb.txt
# Renamed lc_2019lld.txt to 2019lld.txt
# Renamed lc_2019llg.txt to 2019llg.txt
# Renamed lc_2019lli.txt to 2019lli.txt
# Renamed lc_2019lls.txt to 2019lls.txt
# Renamed lc_2019lmf.txt to 2019lmf.txt
# Renamed lc_2019lmi.txt to 2019lmi.txt
# Renamed lc_2019lo.txt to 2019lo.txt
# Renamed lc_2019lpf.txt to 2019lpf.txt
# Renamed lc_2019lph.txt to 2019lph.txt
# Renamed lc_2019lpk.txt to 2019lpk.txt
# Renamed lc_2019lpr.txt to 2019lpr.txt
# Renamed lc_2019lpw.txt to 2019lpw.txt
# Renamed lc_2019lqc.txt to 2019lqc.txt
# Renamed lc_2019lqg.txt to 2019lqg.txt
# Renamed lc_2019lqo.txt to 2019lqo.txt
# Renamed lc_2019lrq.txt to 2019lrq.txt
# Renamed lc_2019lrs.txt to 2019lrs.txt
# Renamed lc_2019lru.txt to 2019lru.txt
# Renamed lc_2019lrx.txt to 2019lrx.txt
# Renamed lc_2019lsf.txt to 2019lsf.txt
# Renamed lc_2019lso.txt to 2019lso.txt
# Renamed lc_2019lst.txt to 2019lst.txt
# Renamed lc_2019luq.txt to 2019luq.txt
# Renamed lc_2019lus.txt to 2019lus.txt
# Renamed lc_2019lut.txt to 2019lut.txt
# Renamed lc_2019lyd.txt to 2019lyd.txt
# Renamed lc_2019lym.txt to 2019lym.txt
# Renamed lc_2019mah.txt to 2019mah.txt
# Renamed lc_2019maz.txt to 2019maz.txt
# Renamed lc_2019mba.txt to 2019mba.txt
# Renamed lc_2019mbi.txt to 2019mbi.txt
# Renamed lc_2019mdc.txt to 2019mdc.txt
# Renamed lc_2019mdp.txt to 2019mdp.txt
# Renamed lc_2019mdq.txt to 2019mdq.txt
# Renamed lc_2019mdr.txt to 2019mdr.txt
# Renamed lc_2019mds.txt to 2019mds.txt
# Renamed lc_2019mdw.txt to 2019mdw.txt
# Renamed lc_2019meb.txt to 2019meb.txt
# Renamed lc_2019mec.txt to 2019mec.txt
# Renamed lc_2019med.txt to 2019med.txt
# Renamed lc_2019mee.txt to 2019mee.txt
# Renamed lc_2019mef.txt to 2019mef.txt
# Renamed lc_2019meg.txt to 2019meg.txt
# Renamed lc_2019men.txt to 2019men.txt
# Renamed lc_2019mgr.txt to 2019mgr.txt
# Renamed lc_2019mhv.txt to 2019mhv.txt
# Renamed lc_2019mim.txt to 2019mim.txt
# Renamed lc_2019mkg.txt to 2019mkg.txt
# Renamed lc_2019mkl.txt to 2019mkl.txt
# Renamed lc_2019mku.txt to 2019mku.txt
# Renamed lc_2019mos.txt to 2019mos.txt
# Renamed lc_2019mpq.txt to 2019mpq.txt
# Renamed lc_2019mpt.txt to 2019mpt.txt
# Renamed lc_2019mqc.txt to 2019mqc.txt
# Renamed lc_2019mqg.txt to 2019mqg.txt
# Renamed lc_2019mqz.txt to 2019mqz.txt
# Renamed lc_2019mrd.txt to 2019mrd.txt
# Renamed lc_2019mrf.txt to 2019mrf.txt
# Renamed lc_2019mrg.txt to 2019mrg.txt
# Renamed lc_2019msr.txt to 2019msr.txt
# Renamed lc_2019mtm.txt to 2019mtm.txt
# Renamed lc_2019mts.txt to 2019mts.txt
# Renamed lc_2019mtt.txt to 2019mtt.txt
# Renamed lc_2019mtz.txt to 2019mtz.txt
# Renamed lc_2019mue.txt to 2019mue.txt
# Renamed lc_2019mue_detrended-detrended.txt to 2019mue_detrended-detrended.txt
# Renamed lc_2019mue_detrended.txt to 2019mue_detrended.txt
# Renamed lc_2019muf.txt to 2019muf.txt
# Renamed lc_2019muu.txt to 2019muu.txt
# Renamed lc_2019muz.txt to 2019muz.txt
# Renamed lc_2019mvj.txt to 2019mvj.txt
# Renamed lc_2019mzo.txt to 2019mzo.txt
# Renamed lc_2019mzy.txt to 2019mzy.txt
# Renamed lc_2019ncd.txt to 2019ncd.txt
# Renamed lc_2019ndl.txt to 2019ndl.txt
# Renamed lc_2019nfq.txt to 2019nfq.txt
# Renamed lc_2019nfv.txt to 2019nfv.txt
# Renamed lc_2019nil.txt to 2019nil.txt
# Renamed lc_2019njg.txt to 2019njg.txt
# Renamed lc_2019njr.txt to 2019njr.txt
# Renamed lc_2019njy.txt to 2019njy.txt
# Renamed lc_2019nkq.txt to 2019nkq.txt
# Renamed lc_2019nkr.txt to 2019nkr.txt
# Renamed lc_2019nlc.txt to 2019nlc.txt
# Renamed lc_2019nld.txt to 2019nld.txt
# Renamed lc_2019nms.txt to 2019nms.txt
# Renamed lc_2019nng.txt to 2019nng.txt
# Renamed lc_2019nnr.txt to 2019nnr.txt
# Renamed lc_2019noc.txt to 2019noc.txt
# Renamed lc_2019nof.txt to 2019nof.txt
# Renamed lc_2019nql.txt to 2019nql.txt
# Renamed lc_2019nqn.txt to 2019nqn.txt
# Renamed lc_2019nty.txt to 2019nty.txt
# Renamed lc_2019ntz.txt to 2019ntz.txt
# Renamed lc_2019nud.txt to 2019nud.txt
# Renamed lc_2019nvj.txt to 2019nvj.txt
# Renamed lc_2019nvk.txt to 2019nvk.txt
# Renamed lc_2019nvl.txt to 2019nvl.txt
# Renamed lc_2019nvm.txt to 2019nvm.txt
# Renamed lc_2019nvw.txt to 2019nvw.txt
# Renamed lc_2019nwu.txt to 2019nwu.txt
# Renamed lc_2019nxp.txt to 2019nxp.txt
# Renamed lc_2019nyf.txt to 2019nyf.txt
# Renamed lc_2019nyo.txt to 2019nyo.txt
# Renamed lc_2019nzp.txt to 2019nzp.txt
# Renamed lc_2019nzq.txt to 2019nzq.txt
# Renamed lc_2019oba.txt to 2019oba.txt
# Renamed lc_2019obp.txt to 2019obp.txt
# Renamed lc_2019oda.txt to 2019oda.txt
# Renamed lc_2019ofn.txt to 2019ofn.txt
# Renamed lc_2019oft.txt to 2019oft.txt
# Renamed lc_2019ohj.txt to 2019ohj.txt
# Renamed lc_2019omq.txt to 2019omq.txt
# Renamed lc_2019onn.txt to 2019onn.txt
# Renamed lc_2019ooj.txt to 2019ooj.txt
# Renamed lc_2019ook.txt to 2019ook.txt
# Renamed lc_2019opq.txt to 2019opq.txt
# Renamed lc_2019opz.txt to 2019opz.txt
# Renamed lc_2019oqb.txt to 2019oqb.txt
# Renamed lc_2019oqc.txt to 2019oqc.txt
# Renamed lc_2019ord.txt to 2019ord.txt
# Renamed lc_2019osp.txt to 2019osp.txt
# Renamed lc_2019osx.txt to 2019osx.txt
# Renamed lc_2019osz.txt to 2019osz.txt
# Renamed lc_2019oug.txt to 2019oug.txt
# Renamed lc_2019ouk.txt to 2019ouk.txt
# Renamed lc_2019ouw.txt to 2019ouw.txt
# Renamed lc_2019ows.txt to 2019ows.txt
# Renamed lc_2019owy.txt to 2019owy.txt
# Renamed lc_2019oxg.txt to 2019oxg.txt
# Renamed lc_2019oxo.txt to 2019oxo.txt
# Renamed lc_2019oye.txt to 2019oye.txt
# Renamed lc_2019oyk.txt to 2019oyk.txt
# Renamed lc_2019ozf.txt to 2019ozf.txt
# Renamed lc_2019ozg.txt to 2019ozg.txt
# Renamed lc_2019pac.txt to 2019pac.txt
# Renamed lc_2019pai.txt to 2019pai.txt
# Renamed lc_2019pat.txt to 2019pat.txt
# Renamed lc_2019pau.txt to 2019pau.txt
# Renamed lc_2019pco.txt to 2019pco.txt
# Renamed lc_2019pcy.txt to 2019pcy.txt
# Renamed lc_2019pdx.txt to 2019pdx.txt
# Renamed lc_2019pfb.txt to 2019pfb.txt
# Renamed lc_2019pgi.txt to 2019pgi.txt
# Renamed lc_2019pgp.txt to 2019pgp.txt
# Renamed lc_2019pgu.txt to 2019pgu.txt
# Renamed lc_2019pho.txt to 2019pho.txt
# Renamed lc_2019php.txt to 2019php.txt
# Renamed lc_2019pjk.txt to 2019pjk.txt
# Renamed lc_2019pjm.txt to 2019pjm.txt
# Renamed lc_2019pju.txt to 2019pju.txt
# Renamed lc_2019pkz.txt to 2019pkz.txt
# Renamed lc_2019pla.txt to 2019pla.txt
# Renamed lc_2019pm.txt to 2019pm.txt
# Renamed lc_2019pmr.txt to 2019pmr.txt
# Renamed lc_2019pmt.txt to 2019pmt.txt
# Renamed lc_2019pnp.txt to 2019pnp.txt
# Renamed lc_2019pnw.txt to 2019pnw.txt
# Renamed lc_2019pnw_detrended.txt to 2019pnw_detrended.txt
# Renamed lc_2019pny.txt to 2019pny.txt
# Renamed lc_2019poz.txt to 2019poz.txt
# Renamed lc_2019pqm.txt to 2019pqm.txt
# Renamed lc_2019pqv.txt to 2019pqv.txt
# Renamed lc_2019prm.txt to 2019prm.txt
# Renamed lc_2019prs.txt to 2019prs.txt
# Renamed lc_2019prw.txt to 2019prw.txt
# Renamed lc_2019prw_detrended.txt to 2019prw_detrended.txt
# Renamed lc_2019prx.txt to 2019prx.txt
# Renamed lc_2019ptf.txt to 2019ptf.txt
# Renamed lc_2019ptg.txt to 2019ptg.txt
# Renamed lc_2019ptv.txt to 2019ptv.txt
# Renamed lc_2019ptv_detrended.txt to 2019ptv_detrended.txt
# Renamed lc_2019pv.txt to 2019pv.txt
# Renamed lc_2019pwa.txt to 2019pwa.txt
# Renamed lc_2019pwd.txt to 2019pwd.txt
# Renamed lc_2019pwq.txt to 2019pwq.txt
# Renamed lc_2019pwr.txt to 2019pwr.txt
# Renamed lc_2019pxv.txt to 2019pxv.txt
# Renamed lc_2019pxx.txt to 2019pxx.txt
# Renamed lc_2019pzj.txt to 2019pzj.txt
# Renamed lc_2019pzn.txt to 2019pzn.txt
# Renamed lc_2019pzq.txt to 2019pzq.txt
# Renamed lc_2019pzt.txt to 2019pzt.txt
# Renamed lc_2019qbs.txt to 2019qbs.txt
# Renamed lc_2019qck.txt to 2019qck.txt
# Renamed lc_2019qcu.txt to 2019qcu.txt
# Renamed lc_2019qcw.txt to 2019qcw.txt
# Renamed lc_2019qdh.txt to 2019qdh.txt
# Renamed lc_2019qdi.txt to 2019qdi.txt
# Renamed lc_2019qdm.txt to 2019qdm.txt
# Renamed lc_2019qew.txt to 2019qew.txt
# Renamed lc_2019qey.txt to 2019qey.txt
# Renamed lc_2019qgh.txt to 2019qgh.txt
# Renamed lc_2019qgj.txt to 2019qgj.txt
# Renamed lc_2019qgx.txt to 2019qgx.txt
# Renamed lc_2019qhg.txt to 2019qhg.txt
# Renamed lc_2019qhh.txt to 2019qhh.txt
# Renamed lc_2019qib.txt to 2019qib.txt
# Renamed lc_2019qjh.txt to 2019qjh.txt
# Renamed lc_2019qmm.txt to 2019qmm.txt
# Renamed lc_2019qmm_detrended.txt to 2019qmm_detrended.txt
# Renamed lc_2019qmt.txt to 2019qmt.txt
# Renamed lc_2019qoj.txt to 2019qoj.txt
# Renamed lc_2019qpc.txt to 2019qpc.txt
# Renamed lc_2019qpx.txt to 2019qpx.txt
# Renamed lc_2019qqk.txt to 2019qqk.txt
# Renamed lc_2019qql.txt to 2019qql.txt
# Renamed lc_2019qqr.txt to 2019qqr.txt
# Renamed lc_2019qqs.txt to 2019qqs.txt
# Renamed lc_2019qrh.txt to 2019qrh.txt
# Renamed lc_2019qsc.txt to 2019qsc.txt
# Renamed lc_2019qsc_detrended.txt to 2019qsc_detrended.txt
# Renamed lc_2019qtw.txt to 2019qtw.txt
# Renamed lc_2019qty.txt to 2019qty.txt
# Renamed lc_2019qwf.txt to 2019qwf.txt
# Renamed lc_2019qwj.txt to 2019qwj.txt
# Renamed lc_2019qwl.txt to 2019qwl.txt
# Renamed lc_2019qxo.txt to 2019qxo.txt
# Renamed lc_2019qyb.txt to 2019qyb.txt
# Renamed lc_2019qyc.txt to 2019qyc.txt
# Renamed lc_2019rdl.txt to 2019rdl.txt
# Renamed lc_2019rdp.txt to 2019rdp.txt
# Renamed lc_2019rex.txt to 2019rex.txt
# Renamed lc_2019rhl.txt to 2019rhl.txt
# Renamed lc_2019rhy.txt to 2019rhy.txt
# Renamed lc_2019rid.txt to 2019rid.txt
# Renamed lc_2019ris.txt to 2019ris.txt
# Renamed lc_2019rj.txt to 2019rj.txt
# Renamed lc_2019rle.txt to 2019rle.txt
# Renamed lc_2019rm.txt to 2019rm.txt
# Renamed lc_2019rmp.txt to 2019rmp.txt
# Renamed lc_2019rpz.txt to 2019rpz.txt
# Renamed lc_2019rqd.txt to 2019rqd.txt
# Renamed lc_2019rqf.txt to 2019rqf.txt
# Renamed lc_2019rqg.txt to 2019rqg.txt
# Renamed lc_2019rqu.txt to 2019rqu.txt
# Renamed lc_2019rrc.txt to 2019rrc.txt
# Renamed lc_2019rrd.txt to 2019rrd.txt
# Renamed lc_2019rre.txt to 2019rre.txt
# Renamed lc_2019ruc.txt to 2019ruc.txt
# Renamed lc_2019ruf.txt to 2019ruf.txt
# Renamed lc_2019rug.txt to 2019rug.txt
# Renamed lc_2019rvh.txt to 2019rvh.txt
# Renamed lc_2019rvx.txt to 2019rvx.txt
# Renamed lc_2019rwg.txt to 2019rwg.txt
# Renamed lc_2019rwh.txt to 2019rwh.txt
# Renamed lc_2019ryj.txt to 2019ryj.txt
# Renamed lc_2019sap.txt to 2019sap.txt
# Renamed lc_2019saz.txt to 2019saz.txt
# Renamed lc_2019sbi.txt to 2019sbi.txt
# Renamed lc_2019sbu.txt to 2019sbu.txt
# Renamed lc_2019sbx.txt to 2019sbx.txt
# Renamed lc_2019sbz.txt to 2019sbz.txt
# Renamed lc_2019sdl.txt to 2019sdl.txt
# Renamed lc_2019sdp.txt to 2019sdp.txt
# Renamed lc_2019sej.txt to 2019sej.txt
# Renamed lc_2019sep.txt to 2019sep.txt
# Renamed lc_2019sfx.txt to 2019sfx.txt
# Renamed lc_2019sgb.txt to 2019sgb.txt
# Renamed lc_2019sgq.txt to 2019sgq.txt
# Renamed lc_2019sgu.txt to 2019sgu.txt
# Renamed lc_2019sgv.txt to 2019sgv.txt
# Renamed lc_2019sho.txt to 2019sho.txt
# Renamed lc_2019sic.txt to 2019sic.txt
# Renamed lc_2019sig.txt to 2019sig.txt
# Renamed lc_2019sih.txt to 2019sih.txt
# Renamed lc_2019sij.txt to 2019sij.txt
# Renamed lc_2019skg.txt to 2019skg.txt
# Renamed lc_2019skx.txt to 2019skx.txt
# Renamed lc_2019sld.txt to 2019sld.txt
# Renamed lc_2019slh.txt to 2019slh.txt
# Renamed lc_2019slj.txt to 2019slj.txt
# Renamed lc_2019slp.txt to 2019slp.txt
# Renamed lc_2019slt.txt to 2019slt.txt
# Renamed lc_2019sme.txt to 2019sme.txt
# Renamed lc_2019smf.txt to 2019smf.txt
# Renamed lc_2019snw.txt to 2019snw.txt
# Renamed lc_2019soh.txt to 2019soh.txt
# Renamed lc_2019soi.txt to 2019soi.txt
# Renamed lc_2019soj.txt to 2019soj.txt
# Renamed lc_2019sop.txt to 2019sop.txt
# Renamed lc_2019sos.txt to 2019sos.txt
# Renamed lc_2019spn.txt to 2019spn.txt
# Renamed lc_2019sqf.txt to 2019sqf.txt
# Renamed lc_2019sqj.txt to 2019sqj.txt
# Renamed lc_2019sqk.txt to 2019sqk.txt
# Renamed lc_2019sql.txt to 2019sql.txt
# Renamed lc_2019sqm.txt to 2019sqm.txt
# Renamed lc_2019sqn.txt to 2019sqn.txt
# Renamed lc_2019sqo.txt to 2019sqo.txt
# Renamed lc_2019src.txt to 2019src.txt
# Renamed lc_2019sse.txt to 2019sse.txt
# Renamed lc_2019ssx.txt to 2019ssx.txt
# Renamed lc_2019sta.txt to 2019sta.txt
# Renamed lc_2019stj.txt to 2019stj.txt
# Renamed lc_2019stn.txt to 2019stn.txt
# Renamed lc_2019str.txt to 2019str.txt
# Renamed lc_2019sts.txt to 2019sts.txt
# Renamed lc_2019svm.txt to 2019svm.txt
# Renamed lc_2019swx.txt to 2019swx.txt
# Renamed lc_2019swy.txt to 2019swy.txt
# Renamed lc_2019sxa.txt to 2019sxa.txt
# Renamed lc_2019sxb.txt to 2019sxb.txt
# Renamed lc_2019sxc.txt to 2019sxc.txt
# Renamed lc_2019sxe.txt to 2019sxe.txt
# Renamed lc_2019sxq.txt to 2019sxq.txt
# Renamed lc_2019syl.txt to 2019syl.txt
# Renamed lc_2019tac.txt to 2019tac.txt
# Renamed lc_2019tae.txt to 2019tae.txt
# Renamed lc_2019tat.txt to 2019tat.txt
# Renamed lc_2019tbg.txt to 2019tbg.txt
# Renamed lc_2019tdi.txt to 2019tdi.txt
# Renamed lc_2019tfa.txt to 2019tfa.txt
# Renamed lc_2019tfd.txt to 2019tfd.txt
# Renamed lc_2019tfu.txt to 2019tfu.txt
# Renamed lc_2019tgj.txt to 2019tgj.txt
# Renamed lc_2019thj.txt to 2019thj.txt
# Renamed lc_2019thz.txt to 2019thz.txt
# Renamed lc_2019til.txt to 2019til.txt
# Renamed lc_2019tjl.txt to 2019tjl.txt
# Renamed lc_2019tjs.txt to 2019tjs.txt
# Renamed lc_2019tjt.txt to 2019tjt.txt
# Renamed lc_2019tju.txt to 2019tju.txt
# Renamed lc_2019tjw.txt to 2019tjw.txt
# Renamed lc_2019tjx.txt to 2019tjx.txt
# Renamed lc_2019tjz.txt to 2019tjz.txt
# Renamed lc_2019tka.txt to 2019tka.txt
# Renamed lc_2019tlo.txt to 2019tlo.txt
# Renamed lc_2019tlp.txt to 2019tlp.txt
# Renamed lc_2019tlu.txt to 2019tlu.txt
# Renamed lc_2019tmw.txt to 2019tmw.txt
# Renamed lc_2019tnf.txt to 2019tnf.txt
# Renamed lc_2019tng.txt to 2019tng.txt
# Renamed lc_2019tov.txt to 2019tov.txt
# Renamed lc_2019tq.txt to 2019tq.txt
# Renamed lc_2019trl.txt to 2019trl.txt
# Renamed lc_2019tsc.txt to 2019tsc.txt
# Renamed lc_2019tsm.txt to 2019tsm.txt
# Renamed lc_2019tsq.txt to 2019tsq.txt
# Renamed lc_2019tsu.txt to 2019tsu.txt
# Renamed lc_2019tsv.txt to 2019tsv.txt
# Renamed lc_2019tsw.txt to 2019tsw.txt
# Renamed lc_2019tsx.txt to 2019tsx.txt
# Renamed lc_2019tsy.txt to 2019tsy.txt
# Renamed lc_2019tsz.txt to 2019tsz.txt
# Renamed lc_2019tta.txt to 2019tta.txt
# Renamed lc_2019tum.txt to 2019tum.txt
# Renamed lc_2019tvu.txt to 2019tvu.txt
# Renamed lc_2019tyu.txt to 2019tyu.txt
# Renamed lc_2019uag.txt to 2019uag.txt
# Renamed lc_2019uaj.txt to 2019uaj.txt
# Renamed lc_2019ubd.txt to 2019ubd.txt
# Renamed lc_2019ubf.txt to 2019ubf.txt
# Renamed lc_2019ubi.txt to 2019ubi.txt
# Renamed lc_2019uca.txt to 2019uca.txt
# Renamed lc_2019udl.txt to 2019udl.txt
# Renamed lc_2019udn.txt to 2019udn.txt
# Renamed lc_2019uem.txt to 2019uem.txt
# Renamed lc_2019uen.txt to 2019uen.txt
# Renamed lc_2019ufu.txt to 2019ufu.txt
# Renamed lc_2019ufy.txt to 2019ufy.txt
# Renamed lc_2019ufz.txt to 2019ufz.txt
# Renamed lc_2019ugb.txt to 2019ugb.txt
# Renamed lc_2019uge.txt to 2019uge.txt
# Renamed lc_2019ugr.txt to 2019ugr.txt
# Renamed lc_2019ugy.txt to 2019ugy.txt
# Renamed lc_2019ugz.txt to 2019ugz.txt
# Renamed lc_2019uje.txt to 2019uje.txt
# Renamed lc_2019ujq.txt to 2019ujq.txt
# Renamed lc_2019ujt.txt to 2019ujt.txt
# Renamed lc_2019ujw.txt to 2019ujw.txt
# Renamed lc_2019ukb.txt to 2019ukb.txt
# Renamed lc_2019ukd.txt to 2019ukd.txt
# Renamed lc_2019ukv.txt to 2019ukv.txt
# Renamed lc_2019ule.txt to 2019ule.txt
# Renamed lc_2019ulr.txt to 2019ulr.txt
# Renamed lc_2019ulr_detrended.txt to 2019ulr_detrended.txt
# Renamed lc_2019ulv.txt to 2019ulv.txt
# Renamed lc_2019ulw.txt to 2019ulw.txt
# Renamed lc_2019umq.txt to 2019umq.txt
# Renamed lc_2019unq.txt to 2019unq.txt
# Renamed lc_2019uwj.txt to 2019uwj.txt
# Renamed lc_2019uwk.txt to 2019uwk.txt
# Renamed lc_2019uyn.txt to 2019uyn.txt
# Renamed lc_2019uyr.txt to 2019uyr.txt
# Renamed lc_2019val.txt to 2019val.txt
# Renamed lc_2019vbi.txt to 2019vbi.txt
# Renamed lc_2019vbj.txt to 2019vbj.txt
# Renamed lc_2019vby.txt to 2019vby.txt
# Renamed lc_2019vcz.txt to 2019vcz.txt
# Renamed lc_2019vda.txt to 2019vda.txt
# Renamed lc_2019vde.txt to 2019vde.txt
# Renamed lc_2019vjv.txt to 2019vjv.txt
# Renamed lc_2019vkn.txt to 2019vkn.txt
# Renamed lc_2019vli.txt to 2019vli.txt
# Renamed lc_2019vlt.txt to 2019vlt.txt
# Renamed lc_2019vlu.txt to 2019vlu.txt
# Renamed lc_2019vma.txt to 2019vma.txt
# Renamed lc_2019vmb.txt to 2019vmb.txt
# Renamed lc_2019vmc.txt to 2019vmc.txt
# Renamed lc_2019vmm.txt to 2019vmm.txt
# Renamed lc_2019vrh.txt to 2019vrh.txt
# Renamed lc_2019vuj.txt to 2019vuj.txt
# Renamed lc_2019vyb.txt to 2019vyb.txt
# Renamed lc_2019vyf.txt to 2019vyf.txt
# Renamed lc_2019vyj.txt to 2019vyj.txt
# Renamed lc_2019vyk.txt to 2019vyk.txt
# Renamed lc_2019vzi.txt to 2019vzi.txt
# Renamed lc_2019vzv.txt to 2019vzv.txt
# Renamed lc_2019vzx.txt to 2019vzx.txt
# Renamed lc_2019vzy.txt to 2019vzy.txt
# Renamed lc_2019wbk.txt to 2019wbk.txt
# Renamed lc_2019wbl.txt to 2019wbl.txt
# Renamed lc_2019wbo.txt to 2019wbo.txt
# Renamed lc_2019wbr.txt to 2019wbr.txt
# Renamed lc_2019wey.txt to 2019wey.txt
# Renamed lc_2019whd.txt to 2019whd.txt
# Renamed lc_2019wim.txt to 2019wim.txt
# Renamed lc_2019wio.txt to 2019wio.txt
# Renamed lc_2019wjj.txt to 2019wjj.txt
# Renamed lc_2019wjl.txt to 2019wjl.txt
# Renamed lc_2019wkz.txt to 2019wkz.txt
# Renamed lc_2019wla.txt to 2019wla.txt
# Renamed lc_2019wle.txt to 2019wle.txt
# Renamed lc_2019wmw.txt to 2019wmw.txt
# Renamed lc_2019wnu.txt to 2019wnu.txt
# Renamed lc_2019wrr.txt to 2019wrr.txt
# Renamed lc_2019wuu.txt to 2019wuu.txt
# Renamed lc_2019wve.txt to 2019wve.txt
# Renamed lc_2019wvo.txt to 2019wvo.txt
# Renamed lc_2019wwo.txt to 2019wwo.txt
# Renamed lc_2019wxp.txt to 2019wxp.txt
# Renamed lc_2019wz.txt to 2019wz.txt
# Renamed lc_2019xao.txt to 2019xao.txt
# Renamed lc_2019xaq.txt to 2019xaq.txt
# Renamed lc_2019xar.txt to 2019xar.txt
# Renamed lc_2019xcn.txt to 2019xcn.txt
# Renamed lc_2019xdl.txt to 2019xdl.txt
# Renamed lc_2019xe.txt to 2019xe.txt
# Renamed lc_2019xhk.txt to 2019xhk.txt
# Renamed lc_2019xip.txt to 2019xip.txt
# Renamed lc_2019xtf.txt to 2019xtf.txt
# Renamed lc_2019xuk.txt to 2019xuk.txt
# Renamed lc_2019xul.txt to 2019xul.txt
# Renamed lc_2019xvs.txt to 2019xvs.txt
# Renamed lc_2019yek.txt to 2019yek.txt
# Renamed lc_2019yel.txt to 2019yel.txt
# Renamed lc_2019yxj.txt to 2019yxj.txt
# Renamed lc_2019yyw.txt to 2019yyw.txt
# Renamed lc_2019zag.txt to 2019zag.txt
# Renamed lc_2019zam.txt to 2019zam.txt
# Renamed lc_2019zdo.txt to 2019zdo.txt
# Renamed lc_2019zei.txt to 2019zei.txt
# Renamed lc_2019zej.txt to 2019zej.txt
# Renamed lc_2019zem.txt to 2019zem.txt
# Renamed lc_2019zen.txt to 2019zen.txt
# Renamed lc_2019zep.txt to 2019zep.txt
# Renamed lc_2019zes.txt to 2019zes.txt
# Renamed lc_2019zhj.txt to 2019zhj.txt
# Renamed lc_2019zhm.txt to 2019zhm.txt
# Renamed lc_2019zrd.txt to 2019zrd.txt
# Renamed lc_2019zsi.txt to 2019zsi.txt
# Renamed lc_2020aaab.txt to 2020aaab.txt
# Renamed lc_2020aaaj.txt to 2020aaaj.txt
# Renamed lc_2020aaap.txt to 2020aaap.txt
# Renamed lc_2020aacy.txt to 2020aacy.txt
# Renamed lc_2020aafo.txt to 2020aafo.txt
# Renamed lc_2020aagz.txt to 2020aagz.txt
# Renamed lc_2020aahq.txt to 2020aahq.txt
# Renamed lc_2020aajf.txt to 2020aajf.txt
# Renamed lc_2020aajq.txt to 2020aajq.txt
# Renamed lc_2020aalz.txt to 2020aalz.txt
# Renamed lc_2020aame.txt to 2020aame.txt
# Renamed lc_2020aami.txt to 2020aami.txt
# Renamed lc_2020aamu.txt to 2020aamu.txt
# Renamed lc_2020aan.txt to 2020aan.txt
# Renamed lc_2020aanf.txt to 2020aanf.txt
# Renamed lc_2020aanv.txt to 2020aanv.txt
# Renamed lc_2020aany.txt to 2020aany.txt
# Renamed lc_2020aao.txt to 2020aao.txt
# Renamed lc_2020aaog.txt to 2020aaog.txt
# Renamed lc_2020aaqm.txt to 2020aaqm.txt
# Renamed lc_2020aaqu.txt to 2020aaqu.txt
# Renamed lc_2020aarw.txt to 2020aarw.txt
# Renamed lc_2020aarz.txt to 2020aarz.txt
# Renamed lc_2020aatb.txt to 2020aatb.txt
# Renamed lc_2020aauh.txt to 2020aauh.txt
# Renamed lc_2020aavd.txt to 2020aavd.txt
# Renamed lc_2020aawh.txt to 2020aawh.txt
# Renamed lc_2020aawi.txt to 2020aawi.txt
# Renamed lc_2020aawj.txt to 2020aawj.txt
# Renamed lc_2020aayb.txt to 2020aayb.txt
# Renamed lc_2020aayc.txt to 2020aayc.txt
# Renamed lc_2020aaye.txt to 2020aaye.txt
# Renamed lc_2020aayk.txt to 2020aayk.txt
# Renamed lc_2020aayr.txt to 2020aayr.txt
# Renamed lc_2020aayt.txt to 2020aayt.txt
# Renamed lc_2020aayv.txt to 2020aayv.txt
# Renamed lc_2020aayy.txt to 2020aayy.txt
# Renamed lc_2020abbx.txt to 2020abbx.txt
# Renamed lc_2020abcd.txt to 2020abcd.txt
# Renamed lc_2020abcr.txt to 2020abcr.txt
# Renamed lc_2020abdk.txt to 2020abdk.txt
# Renamed lc_2020abdk_detrended.txt to 2020abdk_detrended.txt
# Renamed lc_2020abdu.txt to 2020abdu.txt
# Renamed lc_2020abez.txt to 2020abez.txt
# Renamed lc_2020abfn.txt to 2020abfn.txt
# Renamed lc_2020abfo.txt to 2020abfo.txt
# Renamed lc_2020abfw.txt to 2020abfw.txt
# Renamed lc_2020abgz.txt to 2020abgz.txt
# Renamed lc_2020abjj.txt to 2020abjj.txt
# Renamed lc_2020abjl.txt to 2020abjl.txt
# Renamed lc_2020abky.txt to 2020abky.txt
# Renamed lc_2020ablu.txt to 2020ablu.txt
# Renamed lc_2020abof.txt to 2020abof.txt
# Renamed lc_2020abq.txt to 2020abq.txt
# Renamed lc_2020abqs.txt to 2020abqs.txt
# Renamed lc_2020abqu.txt to 2020abqu.txt
# Renamed lc_2020abqy.txt to 2020abqy.txt
# Renamed lc_2020abrp.txt to 2020abrp.txt
# Renamed lc_2020absm.txt to 2020absm.txt
# Renamed lc_2020abtd.txt to 2020abtd.txt
# Renamed lc_2020abuo.txt to 2020abuo.txt
# Renamed lc_2020abvc.txt to 2020abvc.txt
# Renamed lc_2020abvn.txt to 2020abvn.txt
# Renamed lc_2020abvz.txt to 2020abvz.txt
# Renamed lc_2020abwb.txt to 2020abwb.txt
# Renamed lc_2020abwn.txt to 2020abwn.txt
# Renamed lc_2020abwr.txt to 2020abwr.txt
# Renamed lc_2020abwu.txt to 2020abwu.txt
# Renamed lc_2020abxa.txt to 2020abxa.txt
# Renamed lc_2020abxj.txt to 2020abxj.txt
# Renamed lc_2020abxl.txt to 2020abxl.txt
# Renamed lc_2020abxn.txt to 2020abxn.txt
# Renamed lc_2020abxo.txt to 2020abxo.txt
# Renamed lc_2020acaa.txt to 2020acaa.txt
# Renamed lc_2020acaj.txt to 2020acaj.txt
# Renamed lc_2020acaw.txt to 2020acaw.txt
# Renamed lc_2020acax.txt to 2020acax.txt
# Renamed lc_2020acay.txt to 2020acay.txt
# Renamed lc_2020acba.txt to 2020acba.txt
# Renamed lc_2020acbc.txt to 2020acbc.txt
# Renamed lc_2020acbf.txt to 2020acbf.txt
# Renamed lc_2020acbp.txt to 2020acbp.txt
# Renamed lc_2020accy.txt to 2020accy.txt
# Renamed lc_2020accz.txt to 2020accz.txt
# Renamed lc_2020acdk.txt to 2020acdk.txt
# Renamed lc_2020acds.txt to 2020acds.txt
# Renamed lc_2020acgb.txt to 2020acgb.txt
# Renamed lc_2020acgc.txt to 2020acgc.txt
# Renamed lc_2020acgd.txt to 2020acgd.txt
# Renamed lc_2020acge.txt to 2020acge.txt
# Renamed lc_2020acgf.txt to 2020acgf.txt
# Renamed lc_2020acgi.txt to 2020acgi.txt
# Renamed lc_2020achi.txt to 2020achi.txt
# Renamed lc_2020achk.txt to 2020achk.txt
# Renamed lc_2020aclq.txt to 2020aclq.txt
# Renamed lc_2020acls.txt to 2020acls.txt
# Renamed lc_2020aclz.txt to 2020aclz.txt
# Renamed lc_2020acmr.txt to 2020acmr.txt
# Renamed lc_2020acna.txt to 2020acna.txt
# Renamed lc_2020acnj.txt to 2020acnj.txt
# Renamed lc_2020acpo.txt to 2020acpo.txt
# Renamed lc_2020acpu.txt to 2020acpu.txt
# Renamed lc_2020acpv.txt to 2020acpv.txt
# Renamed lc_2020acqf.txt to 2020acqf.txt
# Renamed lc_2020acrs.txt to 2020acrs.txt
# Renamed lc_2020acrz.txt to 2020acrz.txt
# Renamed lc_2020acxg.txt to 2020acxg.txt
# Renamed lc_2020acxt.txt to 2020acxt.txt
# Renamed lc_2020acya.txt to 2020acya.txt
# Renamed lc_2020aczd.txt to 2020aczd.txt
# Renamed lc_2020adbn.txt to 2020adbn.txt
# Renamed lc_2020adbq.txt to 2020adbq.txt
# Renamed lc_2020adbx.txt to 2020adbx.txt
# Renamed lc_2020adch.txt to 2020adch.txt
# Renamed lc_2020adda.txt to 2020adda.txt
# Renamed lc_2020addg.txt to 2020addg.txt
# Renamed lc_2020adeh.txt to 2020adeh.txt
# Renamed lc_2020adff.txt to 2020adff.txt
# Renamed lc_2020adfz.txt to 2020adfz.txt
# Renamed lc_2020adgf.txt to 2020adgf.txt
# Renamed lc_2020adgj.txt to 2020adgj.txt
# Renamed lc_2020adgm.txt to 2020adgm.txt
# Renamed lc_2020adgq.txt to 2020adgq.txt
# Renamed lc_2020adgv.txt to 2020adgv.txt
# Renamed lc_2020adim.txt to 2020adim.txt
# Renamed lc_2020adiw.txt to 2020adiw.txt
# Renamed lc_2020adjd.txt to 2020adjd.txt
# Renamed lc_2020adkj.txt to 2020adkj.txt
# Renamed lc_2020adkk.txt to 2020adkk.txt
# Renamed lc_2020adkr.txt to 2020adkr.txt
# Renamed lc_2020adky.txt to 2020adky.txt
# Renamed lc_2020adlb.txt to 2020adlb.txt
# Renamed lc_2020adlc.txt to 2020adlc.txt
# Renamed lc_2020adle.txt to 2020adle.txt
# Renamed lc_2020adlw.txt to 2020adlw.txt
# Renamed lc_2020adlx.txt to 2020adlx.txt
# Renamed lc_2020adnk.txt to 2020adnk.txt
# Renamed lc_2020adnv.txt to 2020adnv.txt
# Renamed lc_2020adoj.txt to 2020adoj.txt
# Renamed lc_2020adox.txt to 2020adox.txt
# Renamed lc_2020adpr.txt to 2020adpr.txt
# Renamed lc_2020adsj.txt to 2020adsj.txt
# Renamed lc_2020adsx.txt to 2020adsx.txt
# Renamed lc_2020adth.txt to 2020adth.txt
# Renamed lc_2020adtr.txt to 2020adtr.txt
# Renamed lc_2020advu.txt to 2020advu.txt
# Renamed lc_2020adw.txt to 2020adw.txt
# Renamed lc_2020adwr.txt to 2020adwr.txt
# Renamed lc_2020adww.txt to 2020adww.txt
# Renamed lc_2020adyh.txt to 2020adyh.txt
# Renamed lc_2020adyt.txt to 2020adyt.txt
# Renamed lc_2020adyz.txt to 2020adyz.txt
# Renamed lc_2020aeat.txt to 2020aeat.txt
# Renamed lc_2020aeax.txt to 2020aeax.txt
# Renamed lc_2020aeay.txt to 2020aeay.txt
# Renamed lc_2020aebg.txt to 2020aebg.txt
# Renamed lc_2020aecm.txt to 2020aecm.txt
# Renamed lc_2020aecz.txt to 2020aecz.txt
# Renamed lc_2020aedd.txt to 2020aedd.txt
# Renamed lc_2020aedr.txt to 2020aedr.txt
# Renamed lc_2020aedv.txt to 2020aedv.txt
# Renamed lc_2020aedx.txt to 2020aedx.txt
# Renamed lc_2020aeed.txt to 2020aeed.txt
# Renamed lc_2020aeee.txt to 2020aeee.txt
# Renamed lc_2020aeel.txt to 2020aeel.txt
# Renamed lc_2020aeeq.txt to 2020aeeq.txt
# Renamed lc_2020aeey.txt to 2020aeey.txt
# Renamed lc_2020aefd.txt to 2020aefd.txt
# Renamed lc_2020aefg.txt to 2020aefg.txt
# Renamed lc_2020aefr.txt to 2020aefr.txt
# Renamed lc_2020aefv.txt to 2020aefv.txt
# Renamed lc_2020aegb.txt to 2020aegb.txt
# Renamed lc_2020aegs.txt to 2020aegs.txt
# Renamed lc_2020aegx.txt to 2020aegx.txt
# Renamed lc_2020aehe.txt to 2020aehe.txt
# Renamed lc_2020aehp.txt to 2020aehp.txt
# Renamed lc_2020aehr.txt to 2020aehr.txt
# Renamed lc_2020aehv.txt to 2020aehv.txt
# Renamed lc_2020aehy.txt to 2020aehy.txt
# Renamed lc_2020aein.txt to 2020aein.txt
# Renamed lc_2020aeio.txt to 2020aeio.txt
# Renamed lc_2020aeip.txt to 2020aeip.txt
# Renamed lc_2020aeit.txt to 2020aeit.txt
# Renamed lc_2020aeix.txt to 2020aeix.txt
# Renamed lc_2020aeja.txt to 2020aeja.txt
# Renamed lc_2020aejj.txt to 2020aejj.txt
# Renamed lc_2020aek.txt to 2020aek.txt
# Renamed lc_2020aekq.txt to 2020aekq.txt
# Renamed lc_2020ael.txt to 2020ael.txt
# Renamed lc_2020aelf.txt to 2020aelf.txt
# Renamed lc_2020aem.txt to 2020aem.txt
# Renamed lc_2020aemi.txt to 2020aemi.txt
# Renamed lc_2020aemn.txt to 2020aemn.txt
# Renamed lc_2020aemy.txt to 2020aemy.txt
# Renamed lc_2020aen.txt to 2020aen.txt
# Renamed lc_2020aeny.txt to 2020aeny.txt
# Renamed lc_2020aenz.txt to 2020aenz.txt
# Renamed lc_2020aeoe.txt to 2020aeoe.txt
# Renamed lc_2020aeof.txt to 2020aeof.txt
# Renamed lc_2020aeos.txt to 2020aeos.txt
# Renamed lc_2020aeot.txt to 2020aeot.txt
# Renamed lc_2020aeqb.txt to 2020aeqb.txt
# Renamed lc_2020aera.txt to 2020aera.txt
# Renamed lc_2020aesr.txt to 2020aesr.txt
# Renamed lc_2020aetk.txt to 2020aetk.txt
# Renamed lc_2020aeto.txt to 2020aeto.txt
# Renamed lc_2020aetp.txt to 2020aetp.txt
# Renamed lc_2020aeuq.txt to 2020aeuq.txt
# Renamed lc_2020aeux.txt to 2020aeux.txt
# Renamed lc_2020aevp.txt to 2020aevp.txt
# Renamed lc_2020aevq.txt to 2020aevq.txt
# Renamed lc_2020aevt.txt to 2020aevt.txt
# Renamed lc_2020aewb.txt to 2020aewb.txt
# Renamed lc_2020aewf.txt to 2020aewf.txt
# Renamed lc_2020aewg.txt to 2020aewg.txt
# Renamed lc_2020afg.txt to 2020afg.txt
# Renamed lc_2020afh.txt to 2020afh.txt
# Renamed lc_2020afq.txt to 2020afq.txt
# Renamed lc_2020akf.txt to 2020akf.txt
# Renamed lc_2020akk.txt to 2020akk.txt
# Renamed lc_2020aku.txt to 2020aku.txt
# Renamed lc_2020akw.txt to 2020akw.txt
# Renamed lc_2020amv.txt to 2020amv.txt
# Renamed lc_2020amw.txt to 2020amw.txt
# Renamed lc_2020amx.txt to 2020amx.txt
# Renamed lc_2020ana.txt to 2020ana.txt
# Renamed lc_2020anc.txt to 2020anc.txt
# Renamed lc_2020aob.txt to 2020aob.txt
# Renamed lc_2020aog.txt to 2020aog.txt
# Renamed lc_2020aoh.txt to 2020aoh.txt
# Renamed lc_2020aoi.txt to 2020aoi.txt
# Renamed lc_2020apm.txt to 2020apm.txt
# Renamed lc_2020aqc.txt to 2020aqc.txt
# Renamed lc_2020aqf.txt to 2020aqf.txt
# Renamed lc_2020asn.txt to 2020asn.txt
# Renamed lc_2020ato.txt to 2020ato.txt
# Renamed lc_2020ats.txt to 2020ats.txt
# Renamed lc_2020auo.txt to 2020auo.txt
# Renamed lc_2020awl.txt to 2020awl.txt
# Renamed lc_2020axn.txt to 2020axn.txt
# Renamed lc_2020axq.txt to 2020axq.txt
# Renamed lc_2020ayo.txt to 2020ayo.txt
# Renamed lc_2020ayv.txt to 2020ayv.txt
# Renamed lc_2020ayw.txt to 2020ayw.txt
# Renamed lc_2020azg.txt to 2020azg.txt
# Renamed lc_2020azi.txt to 2020azi.txt
# Renamed lc_2020azz.txt to 2020azz.txt
# Renamed lc_2020bag.txt to 2020bag.txt
# Renamed lc_2020bbe.txt to 2020bbe.txt
# Renamed lc_2020bbg.txt to 2020bbg.txt
# Renamed lc_2020bbs.txt to 2020bbs.txt
# Renamed lc_2020bbt.txt to 2020bbt.txt
# Renamed lc_2020bbu.txt to 2020bbu.txt
# Renamed lc_2020bbx.txt to 2020bbx.txt
# Renamed lc_2020bcj.txt to 2020bcj.txt
# Renamed lc_2020bck.txt to 2020bck.txt
# Renamed lc_2020bdk.txt to 2020bdk.txt
# Renamed lc_2020bdw.txt to 2020bdw.txt
# Renamed lc_2020bdx.txt to 2020bdx.txt
# Renamed lc_2020bea.txt to 2020bea.txt
# Renamed lc_2020beq.txt to 2020beq.txt
# Renamed lc_2020bew.txt to 2020bew.txt
# Renamed lc_2020bfy.txt to 2020bfy.txt
# Renamed lc_2020bg.txt to 2020bg.txt
# Renamed lc_2020bgq.txt to 2020bgq.txt
# Renamed lc_2020bh.txt to 2020bh.txt
# Renamed lc_2020bhg.txt to 2020bhg.txt
# Renamed lc_2020bhh.txt to 2020bhh.txt
# Renamed lc_2020bir.txt to 2020bir.txt
# Renamed lc_2020bis.txt to 2020bis.txt
# Renamed lc_2020biz.txt to 2020biz.txt
# Renamed lc_2020bj.txt to 2020bj.txt
# Renamed lc_2020bja.txt to 2020bja.txt
# Renamed lc_2020bjc.txt to 2020bjc.txt
# Renamed lc_2020bjf.txt to 2020bjf.txt
# Renamed lc_2020bjj.txt to 2020bjj.txt
# Renamed lc_2020bjq.txt to 2020bjq.txt
# Renamed lc_2020bkm.txt to 2020bkm.txt
# Renamed lc_2020blh.txt to 2020blh.txt
# Renamed lc_2020blo.txt to 2020blo.txt
# Renamed lc_2020blv.txt to 2020blv.txt
# Renamed lc_2020bly.txt to 2020bly.txt
# Renamed lc_2020bmc.txt to 2020bmc.txt
# Renamed lc_2020bmf.txt to 2020bmf.txt
# Renamed lc_2020bmp.txt to 2020bmp.txt
# Renamed lc_2020bms.txt to 2020bms.txt
# Renamed lc_2020bmw.txt to 2020bmw.txt
# Renamed lc_2020bob.txt to 2020bob.txt
# Renamed lc_2020bol.txt to 2020bol.txt
# Renamed lc_2020bop.txt to 2020bop.txt
# Renamed lc_2020bor.txt to 2020bor.txt
# Renamed lc_2020bpb.txt to 2020bpb.txt
# Renamed lc_2020bpw.txt to 2020bpw.txt
# Renamed lc_2020bqf.txt to 2020bqf.txt
# Renamed lc_2020bqr.txt to 2020bqr.txt
# Renamed lc_2020brq.txt to 2020brq.txt
# Renamed lc_2020bsb.txt to 2020bsb.txt
# Renamed lc_2020bto.txt to 2020bto.txt
# Renamed lc_2020btp.txt to 2020btp.txt
# Renamed lc_2020bud.txt to 2020bud.txt
# Renamed lc_2020buv.txt to 2020buv.txt
# Renamed lc_2020bvg.txt to 2020bvg.txt
# Renamed lc_2020bvi.txt to 2020bvi.txt
# Renamed lc_2020bvj.txt to 2020bvj.txt
# Renamed lc_2020bvn.txt to 2020bvn.txt
# Renamed lc_2020bvy.txt to 2020bvy.txt
# Renamed lc_2020bw.txt to 2020bw.txt
# Renamed lc_2020bwg.txt to 2020bwg.txt
# Renamed lc_2020bx.txt to 2020bx.txt
# Renamed lc_2020bxc.txt to 2020bxc.txt
# Renamed lc_2020by.txt to 2020by.txt
# Renamed lc_2020bz.txt to 2020bz.txt
# Renamed lc_2020bza.txt to 2020bza.txt
# Renamed lc_2020bzd.txt to 2020bzd.txt
# Renamed lc_2020bzn.txt to 2020bzn.txt
# Renamed lc_2020bzv.txt to 2020bzv.txt
# Renamed lc_2020bzx.txt to 2020bzx.txt
# Renamed lc_2020cbm.txt to 2020cbm.txt
# Renamed lc_2020cc.txt to 2020cc.txt
# Renamed lc_2020cdi.txt to 2020cdi.txt
# Renamed lc_2020cdj.txt to 2020cdj.txt
# Renamed lc_2020cdq.txt to 2020cdq.txt
# Renamed lc_2020cfp.txt to 2020cfp.txt
# Renamed lc_2020chi.txt to 2020chi.txt
# Renamed lc_2020chm.txt to 2020chm.txt
# Renamed lc_2020cjm.txt to 2020cjm.txt
# Renamed lc_2020cjr.txt to 2020cjr.txt
# Renamed lc_2020ckw.txt to 2020ckw.txt
# Renamed lc_2020clr.txt to 2020clr.txt
# Renamed lc_2020cmb.txt to 2020cmb.txt
# Renamed lc_2020cmj.txt to 2020cmj.txt
# Renamed lc_2020cms.txt to 2020cms.txt
# Renamed lc_2020cmt.txt to 2020cmt.txt
# Renamed lc_2020cmv.txt to 2020cmv.txt
# Renamed lc_2020cnl.txt to 2020cnl.txt
# Renamed lc_2020cnr.txt to 2020cnr.txt
# Renamed lc_2020coi.txt to 2020coi.txt
# Renamed lc_2020cqk.txt to 2020cqk.txt
# Renamed lc_2020cqz.txt to 2020cqz.txt
# Renamed lc_2020csx.txt to 2020csx.txt
# Renamed lc_2020cxd.txt to 2020cxd.txt
# Renamed lc_2020cxe.txt to 2020cxe.txt
# Renamed lc_2020cxf.txt to 2020cxf.txt
# Renamed lc_2020cym.txt to 2020cym.txt
# Renamed lc_2020dat.txt to 2020dat.txt
# Renamed lc_2020dbf.txt to 2020dbf.txt
# Renamed lc_2020dbi.txt to 2020dbi.txt
# Renamed lc_2020dbl.txt to 2020dbl.txt
# Renamed lc_2020dcs.txt to 2020dcs.txt
# Renamed lc_2020dcx.txt to 2020dcx.txt
# Renamed lc_2020ddb.txt to 2020ddb.txt
# Renamed lc_2020ddi.txt to 2020ddi.txt
# Renamed lc_2020ddu.txt to 2020ddu.txt
# Renamed lc_2020dgc.txt to 2020dgc.txt
# Renamed lc_2020dge.txt to 2020dge.txt
# Renamed lc_2020dhk.txt to 2020dhk.txt
# Renamed lc_2020dho.txt to 2020dho.txt
# Renamed lc_2020di.txt to 2020di.txt
# Renamed lc_2020dia.txt to 2020dia.txt
# Renamed lc_2020djw.txt to 2020djw.txt
# Renamed lc_2020dkk.txt to 2020dkk.txt
# Renamed lc_2020dnf.txt to 2020dnf.txt
# Renamed lc_2020dnh.txt to 2020dnh.txt
# Renamed lc_2020dnk.txt to 2020dnk.txt
# Renamed lc_2020dns.txt to 2020dns.txt
# Renamed lc_2020doo.txt to 2020doo.txt
# Renamed lc_2020dop.txt to 2020dop.txt
# Renamed lc_2020dos.txt to 2020dos.txt
# Renamed lc_2020dqv.txt to 2020dqv.txt
# Renamed lc_2020dra.txt to 2020dra.txt
# Renamed lc_2020drf.txt to 2020drf.txt
# Renamed lc_2020drk.txt to 2020drk.txt
# Renamed lc_2020drs.txt to 2020drs.txt
# Renamed lc_2020dry.txt to 2020dry.txt
# Renamed lc_2020dsl.txt to 2020dsl.txt
# Renamed lc_2020dsn.txt to 2020dsn.txt
# Renamed lc_2020dts.txt to 2020dts.txt
# Renamed lc_2020dtw.txt to 2020dtw.txt
# Renamed lc_2020duz.txt to 2020duz.txt
# Renamed lc_2020dvf.txt to 2020dvf.txt
# Renamed lc_2020dvo.txt to 2020dvo.txt
# Renamed lc_2020dwj.txt to 2020dwj.txt
# Renamed lc_2020dwn.txt to 2020dwn.txt
# Renamed lc_2020dwy.txt to 2020dwy.txt
# Renamed lc_2020dxu.txt to 2020dxu.txt
# Renamed lc_2020dxw.txt to 2020dxw.txt
# Renamed lc_2020dya.txt to 2020dya.txt
# ...
# Renamed lc_2022ydq.txt to 2022ydq.txt
# Renamed lc_2022ydr.txt to 2022ydr.txt
# Renamed lc_2022yeo.txt to 2022yeo.txt
# Renamed lc_2022yeu.txt to 2022yeu.txt
# Renamed lc_2022ygt.txt to 2022ygt.txt
# Renamed lc_2022yhg.txt to 2022yhg.txt
# Renamed lc_2022yht.txt to 2022yht.txt
# Renamed lc_2022ykj.txt to 2022ykj.txt
# Renamed lc_2022ykl.txt to 2022ykl.txt
# Renamed lc_2022yml.txt to 2022yml.txt
# Renamed lc_2022ymv.txt to 2022ymv.txt
# Renamed lc_2022ynj.txt to 2022ynj.txt
# Renamed lc_2022ynn.txt to 2022ynn.txt
# Renamed lc_2022ynp.txt to 2022ynp.txt
# Renamed lc_2022ynz.txt to 2022ynz.txt
# Renamed lc_2022ype.txt to 2022ype.txt
# Renamed lc_2022ypg.txt to 2022ypg.txt
# Renamed lc_2022yph.txt to 2022yph.txt
# Renamed lc_2022ypi.txt to 2022ypi.txt
# Renamed lc_2022ypw.txt to 2022ypw.txt
# Renamed lc_2022ypz.txt to 2022ypz.txt
# Renamed lc_2022yqa.txt to 2022yqa.txt
# Renamed lc_2022yqi.txt to 2022yqi.txt
# Renamed lc_2022yqp.txt to 2022yqp.txt
# Renamed lc_2022yqs.txt to 2022yqs.txt
# Renamed lc_2022yqz.txt to 2022yqz.txt
# Renamed lc_2022yrf.txt to 2022yrf.txt
# Renamed lc_2022yrl.txt to 2022yrl.txt
# Renamed lc_2022yrm.txt to 2022yrm.txt
# Renamed lc_2022yud.txt to 2022yud.txt
# Renamed lc_2022yue.txt to 2022yue.txt
# Renamed lc_2022yuf.txt to 2022yuf.txt
# Renamed lc_2022yul.txt to 2022yul.txt
# Renamed lc_2022yvc.txt to 2022yvc.txt
# Renamed lc_2022yve.txt to 2022yve.txt
# Renamed lc_2022yvf.txt to 2022yvf.txt
# Renamed lc_2022yw.txt to 2022yw.txt
# Renamed lc_2022yxq.txt to 2022yxq.txt
# Renamed lc_2022yxt.txt to 2022yxt.txt
# Renamed lc_2022yxv.txt to 2022yxv.txt
# Renamed lc_2022yxx.txt to 2022yxx.txt
# Renamed lc_2022yye.txt to 2022yye.txt
# Renamed lc_2022yyg.txt to 2022yyg.txt
# Renamed lc_2022zaa.txt to 2022zaa.txt
# Renamed lc_2022zad.txt to 2022zad.txt
# Renamed lc_2022zae.txt to 2022zae.txt
# Renamed lc_2022zaf.txt to 2022zaf.txt
# Renamed lc_2022zaj.txt to 2022zaj.txt
# Renamed lc_2022zay.txt to 2022zay.txt
# Renamed lc_2022zdc.txt to 2022zdc.txt
# Renamed lc_2022zea.txt to 2022zea.txt
# Renamed lc_2022zeh.txt to 2022zeh.txt
# Renamed lc_2022zei.txt to 2022zei.txt
# Renamed lc_2022zfu.txt to 2022zfu.txt
# Renamed lc_2022zgj.txt to 2022zgj.txt
# Renamed lc_2022zgs.txt to 2022zgs.txt
# Renamed lc_2022zhc.txt to 2022zhc.txt
# Renamed lc_2022zjh.txt to 2022zjh.txt
# Renamed lc_2022zji.txt to 2022zji.txt
# Renamed lc_2022zmz.txt to 2022zmz.txt
# Renamed lc_2022znd.txt to 2022znd.txt
# Renamed lc_2022zog.txt to 2022zog.txt
# Renamed lc_2022zpi.txt to 2022zpi.txt
# Renamed lc_2022zpq.txt to 2022zpq.txt
# Renamed lc_2022zql.txt to 2022zql.txt
# Renamed lc_2022zqw.txt to 2022zqw.txt
# Renamed lc_2022zr.txt to 2022zr.txt
# Renamed lc_2022zrt.txt to 2022zrt.txt
# Renamed lc_2022zsk.txt to 2022zsk.txt
# Renamed lc_2022ztv.txt to 2022ztv.txt
# Renamed lc_2022zur.txt to 2022zur.txt
# Renamed lc_2022zwi.txt to 2022zwi.txt
# Renamed lc_2022zxe.txt to 2022zxe.txt
# Renamed lc_2022zxn.txt to 2022zxn.txt
# Renamed lc_2022zxo.txt to 2022zxo.txt
# Renamed lc_2022zxw.txt to 2022zxw.txt
# Renamed lc_2022zyd.txt to 2022zyd.txt
# Renamed lc_2022zyh.txt to 2022zyh.txt
# Renamed lc_2022zyo.txt to 2022zyo.txt
# Renamed lc_2022zyu.txt to 2022zyu.txt
# Renamed lc_2022zzx.txt to 2022zzx.txt
# Renamed lc_2023aan.txt to 2023aan.txt
# Renamed lc_2023aar.txt to 2023aar.txt
# Renamed lc_2023adh.txt to 2023adh.txt
# Renamed lc_2023aed.txt to 2023aed.txt
# Renamed lc_2023aeh.txt to 2023aeh.txt
# Renamed lc_2023aej.txt to 2023aej.txt
# Renamed lc_2023ahn.txt to 2023ahn.txt
# Renamed lc_2023aho.txt to 2023aho.txt
# Renamed lc_2023aic.txt to 2023aic.txt
# Renamed lc_2023aii.txt to 2023aii.txt
# Renamed lc_2023aij.txt to 2023aij.txt
# Renamed lc_2023ail.txt to 2023ail.txt
# Renamed lc_2023air.txt to 2023air.txt
# Renamed lc_2023akj.txt to 2023akj.txt
# Renamed lc_2023alt.txt to 2023alt.txt
# Renamed lc_2023alw.txt to 2023alw.txt
# Renamed lc_2023ams.txt to 2023ams.txt
# Renamed lc_2023amt.txt to 2023amt.txt
# Renamed lc_2023amw.txt to 2023amw.txt
# Renamed lc_2023anc.txt to 2023anc.txt
# Renamed lc_2023anj.txt to 2023anj.txt
# Renamed lc_2023anm.txt to 2023anm.txt
# Renamed lc_2023ann.txt to 2023ann.txt
# Renamed lc_2023anw.txt to 2023anw.txt
# Renamed lc_2023aob.txt to 2023aob.txt
# Renamed lc_2023aoi.txt to 2023aoi.txt
# Renamed lc_2023aot.txt to 2023aot.txt
# Renamed lc_2023aoz.txt to 2023aoz.txt
# Renamed lc_2023apz.txt to 2023apz.txt
# Renamed lc_2023arx.txt to 2023arx.txt
# Renamed lc_2023ato.txt to 2023ato.txt
# Renamed lc_2023atp.txt to 2023atp.txt
# Renamed lc_2023aty.txt to 2023aty.txt
# Renamed lc_2023atz.txt to 2023atz.txt
# Renamed lc_2023auh.txt to 2023auh.txt
# Renamed lc_2023auu.txt to 2023auu.txt
# Renamed lc_2023ave.txt to 2023ave.txt
# Renamed lc_2023avw.txt to 2023avw.txt
# Renamed lc_2023axa.txt to 2023axa.txt
# Renamed lc_2023axc.txt to 2023axc.txt
# Renamed lc_2023baz.txt to 2023baz.txt
# Renamed lc_2023bba.txt to 2023bba.txt
# Renamed lc_2023bbi.txt to 2023bbi.txt
# Renamed lc_2023bbt.txt to 2023bbt.txt
# Renamed lc_2023bee.txt to 2023bee.txt
# Renamed lc_2023bgq.txt to 2023bgq.txt
# Renamed lc_2023bgt.txt to 2023bgt.txt
# Renamed lc_2023bhp.txt to 2023bhp.txt
# Renamed lc_2023bjr.txt to 2023bjr.txt
# Renamed lc_2023bju.txt to 2023bju.txt
# Renamed lc_2023bjv.txt to 2023bjv.txt
# Renamed lc_2023blo.txt to 2023blo.txt
# Renamed lc_2023blv.txt to 2023blv.txt
# Renamed lc_2023bmf.txt to 2023bmf.txt
# Renamed lc_2023bms.txt to 2023bms.txt
# Renamed lc_2023bod.txt to 2023bod.txt
# Renamed lc_2023boh.txt to 2023boh.txt
# Renamed lc_2023bov.txt to 2023bov.txt
# Renamed lc_2023bpc.txt to 2023bpc.txt
# Renamed lc_2023bqj.txt to 2023bqj.txt
# Renamed lc_2023bqn.txt to 2023bqn.txt
# Renamed lc_2023bqp.txt to 2023bqp.txt
# Renamed lc_2023bqr.txt to 2023bqr.txt
# Renamed lc_2023bqv.txt to 2023bqv.txt
# Renamed lc_2023bqz.txt to 2023bqz.txt
# Renamed lc_2023bre.txt to 2023bre.txt
# Renamed lc_2023bs.txt to 2023bs.txt
# Renamed lc_2023bsd.txt to 2023bsd.txt
# Renamed lc_2023bsr.txt to 2023bsr.txt
# Renamed lc_2023btp.txt to 2023btp.txt
# Renamed lc_2023btu.txt to 2023btu.txt
# Renamed lc_2023bue.txt to 2023bue.txt
# Renamed lc_2023buh.txt to 2023buh.txt
# Renamed lc_2023bui.txt to 2023bui.txt
# Renamed lc_2023buj.txt to 2023buj.txt
# Renamed lc_2023bur.txt to 2023bur.txt
# Renamed lc_2023bus.txt to 2023bus.txt
# Renamed lc_2023bux.txt to 2023bux.txt
# Renamed lc_2023bwv.txt to 2023bwv.txt
# Renamed lc_2023bwx.txt to 2023bwx.txt
# Renamed lc_2023bxf.txt to 2023bxf.txt
# Renamed lc_2023bxq.txt to 2023bxq.txt
# Renamed lc_2023bxt.txt to 2023bxt.txt
# Renamed lc_2023bys.txt to 2023bys.txt
# Renamed lc_2023bzw.txt to 2023bzw.txt
# Renamed lc_2023caa.txt to 2023caa.txt
# Renamed lc_2023cbn.txt to 2023cbn.txt
# Renamed lc_2023cbr.txt to 2023cbr.txt
# Renamed lc_2023ccg.txt to 2023ccg.txt
# Renamed lc_2023ccu.txt to 2023ccu.txt
# Renamed lc_2023cdd.txt to 2023cdd.txt
# Renamed lc_2023cew.txt to 2023cew.txt
# Renamed lc_2023cgi.txt to 2023cgi.txt
# Renamed lc_2023cgk.txt to 2023cgk.txt
# Renamed lc_2023chu.txt to 2023chu.txt
# Renamed lc_2023chv.txt to 2023chv.txt
# Renamed lc_2023cjf.txt to 2023cjf.txt
# Renamed lc_2023cjj.txt to 2023cjj.txt
# Renamed lc_2023cjm.txt to 2023cjm.txt
# Renamed lc_2023cku.txt to 2023cku.txt
# Renamed lc_2023cli.txt to 2023cli.txt
# Renamed lc_2023cll.txt to 2023cll.txt
# Renamed lc_2023clz.txt to 2023clz.txt
# Renamed lc_2023cna.txt to 2023cna.txt
# Renamed lc_2023cnm.txt to 2023cnm.txt
# Renamed lc_2023coa.txt to 2023coa.txt
# Renamed lc_2023cod.txt to 2023cod.txt
# Renamed lc_2023cor.txt to 2023cor.txt
# Renamed lc_2023cow.txt to 2023cow.txt
# Renamed lc_2023crz.txt to 2023crz.txt
# Renamed lc_2023csc.txt to 2023csc.txt
# Renamed lc_2023cum.txt to 2023cum.txt
# Renamed lc_2023cvk.txt to 2023cvk.txt
# Renamed lc_2023cwy.txt to 2023cwy.txt
# Renamed lc_2023cwz.txt to 2023cwz.txt
# Renamed lc_2023cxc.txt to 2023cxc.txt
# Renamed lc_2023cxd.txt to 2023cxd.txt
# Renamed lc_2023cxg.txt to 2023cxg.txt
# Renamed lc_2023cyf.txt to 2023cyf.txt
# Renamed lc_2023cyi.txt to 2023cyi.txt
# Renamed lc_2023dbj.txt to 2023dbj.txt
# Renamed lc_2023ddy.txt to 2023ddy.txt
# Renamed lc_2023dep.txt to 2023dep.txt
# Renamed lc_2023deq.txt to 2023deq.txt
# Renamed lc_2023dfb.txt to 2023dfb.txt
# Renamed lc_2023dfr.txt to 2023dfr.txt
# Renamed lc_2023dfx.txt to 2023dfx.txt
# Renamed lc_2023dfz.txt to 2023dfz.txt
# Renamed lc_2023dma.txt to 2023dma.txt
# Renamed lc_2023dov.txt to 2023dov.txt
# Renamed lc_2023dox.txt to 2023dox.txt
# Renamed lc_2023dpq.txt to 2023dpq.txt
# Renamed lc_2023dpu.txt to 2023dpu.txt
# Renamed lc_2023dpz.txt to 2023dpz.txt
# Renamed lc_2023dqd.txt to 2023dqd.txt
# Renamed lc_2023dqh.txt to 2023dqh.txt
# Renamed lc_2023dst.txt to 2023dst.txt
# Renamed lc_2023duc.txt to 2023duc.txt
# Renamed lc_2023dug.txt to 2023dug.txt
# Renamed lc_2023dup.txt to 2023dup.txt
# Renamed lc_2023dva.txt to 2023dva.txt
# Renamed lc_2023dvj.txt to 2023dvj.txt
# Renamed lc_2023dvq.txt to 2023dvq.txt
# Renamed lc_2023dvz.txt to 2023dvz.txt
# Renamed lc_2023dwl.txt to 2023dwl.txt
# Renamed lc_2023dze.txt to 2023dze.txt
# Renamed lc_2023ebl.txt to 2023ebl.txt
# Renamed lc_2023ebq.txt to 2023ebq.txt
# Renamed lc_2023ecd.txt to 2023ecd.txt
# Renamed lc_2023edf.txt to 2023edf.txt
# Renamed lc_2023edn.txt to 2023edn.txt
# Renamed lc_2023edo.txt to 2023edo.txt
# Renamed lc_2023edy.txt to 2023edy.txt
# Renamed lc_2023eez.txt to 2023eez.txt
# Renamed lc_2023egc.txt to 2023egc.txt
# Renamed lc_2023egh.txt to 2023egh.txt
# Renamed lc_2023egk.txt to 2023egk.txt
# Renamed lc_2023egm.txt to 2023egm.txt
# Renamed lc_2023egu.txt to 2023egu.txt
# Renamed lc_2023ejj.txt to 2023ejj.txt
# Renamed lc_2023ejl.txt to 2023ejl.txt
# Renamed lc_2023ejp.txt to 2023ejp.txt
# Renamed lc_2023ejy.txt to 2023ejy.txt
# Renamed lc_2023ekc.txt to 2023ekc.txt
# Renamed lc_2023eke.txt to 2023eke.txt
# Renamed lc_2023elb.txt to 2023elb.txt
# Renamed lc_2023elj.txt to 2023elj.txt
# Renamed lc_2023elo.txt to 2023elo.txt
# Renamed lc_2023eow.txt to 2023eow.txt
# Renamed lc_2023epl.txt to 2023epl.txt
# Renamed lc_2023epw.txt to 2023epw.txt
# Renamed lc_2023eqh.txt to 2023eqh.txt
# Renamed lc_2023eqj.txt to 2023eqj.txt
# Renamed lc_2023eua.txt to 2023eua.txt
# Renamed lc_2023eux.txt to 2023eux.txt
# Renamed lc_2023evi.txt to 2023evi.txt
# Renamed lc_2023evx.txt to 2023evx.txt
# Renamed lc_2023exr.txt to 2023exr.txt
# Renamed lc_2023exz.txt to 2023exz.txt
# Renamed lc_2023ezg.txt to 2023ezg.txt
# Renamed lc_2023ezt.txt to 2023ezt.txt
# Renamed lc_2023fak.txt to 2023fak.txt
# Renamed lc_2023far.txt to 2023far.txt
# Renamed lc_2023fat.txt to 2023fat.txt
# Renamed lc_2023fbr.txt to 2023fbr.txt
# Renamed lc_2023fcv.txt to 2023fcv.txt
# Renamed lc_2023fda.txt to 2023fda.txt
# Renamed lc_2023fdj.txt to 2023fdj.txt
# Renamed lc_2023fel.txt to 2023fel.txt
# Renamed lc_2023fep.txt to 2023fep.txt
# Renamed lc_2023ffq.txt to 2023ffq.txt
# Renamed lc_2023fhl.txt to 2023fhl.txt
# Renamed lc_2023fit.txt to 2023fit.txt
# Renamed lc_2023flj.txt to 2023flj.txt
# Renamed lc_2023fls.txt to 2023fls.txt
# Renamed lc_2023fol.txt to 2023fol.txt
# Renamed lc_2023fpc.txt to 2023fpc.txt
# Renamed lc_2023fpe.txt to 2023fpe.txt
# Renamed lc_2023fpo.txt to 2023fpo.txt
# Renamed lc_2023fpq.txt to 2023fpq.txt
# Renamed lc_2023fqu.txt to 2023fqu.txt
# Renamed lc_2023fqz.txt to 2023fqz.txt
# Renamed lc_2023ftx.txt to 2023ftx.txt
# Renamed lc_2023fty.txt to 2023fty.txt
# Renamed lc_2023fua.txt to 2023fua.txt
# Renamed lc_2023fud.txt to 2023fud.txt
# Renamed lc_2023fuo.txt to 2023fuo.txt
# Renamed lc_2023fut.txt to 2023fut.txt
# Renamed lc_2023fvg.txt to 2023fvg.txt
# Renamed lc_2023fx.txt to 2023fx.txt
# Renamed lc_2023fzf.txt to 2023fzf.txt
# Renamed lc_2023gas.txt to 2023gas.txt
# Renamed lc_2023gcj.txt to 2023gcj.txt
# Renamed lc_2023gdn.txt to 2023gdn.txt
# Renamed lc_2023gdu.txt to 2023gdu.txt
# Renamed lc_2023ghs.txt to 2023ghs.txt
# Renamed lc_2023gim.txt to 2023gim.txt
# Renamed lc_2023gio.txt to 2023gio.txt
# Renamed lc_2023gj.txt to 2023gj.txt
# Renamed lc_2023gjx.txt to 2023gjx.txt
# Renamed lc_2023gjz.txt to 2023gjz.txt
# Renamed lc_2023gns.txt to 2023gns.txt
# Renamed lc_2023gnx.txt to 2023gnx.txt
# Renamed lc_2023gos.txt to 2023gos.txt
# Renamed lc_2023gp.txt to 2023gp.txt
# Renamed lc_2023gpu.txt to 2023gpu.txt
# Renamed lc_2023gr.txt to 2023gr.txt
# Renamed lc_2023gs.txt to 2023gs.txt
# Renamed lc_2023gsf.txt to 2023gsf.txt
# Renamed lc_2023gsh.txt to 2023gsh.txt
# Renamed lc_2023gsp.txt to 2023gsp.txt
# Renamed lc_2023gss.txt to 2023gss.txt
# Renamed lc_2023gtp.txt to 2023gtp.txt
# Renamed lc_2023gtx.txt to 2023gtx.txt
# Renamed lc_2023gu.txt to 2023gu.txt
# Renamed lc_2023guj.txt to 2023guj.txt
# Renamed lc_2023gup.txt to 2023gup.txt
# Renamed lc_2023gwh.txt to 2023gwh.txt
# Renamed lc_2023gx.txt to 2023gx.txt
# Renamed lc_2023gxh.txt to 2023gxh.txt
# Renamed lc_2023gza.txt to 2023gza.txt
# Renamed lc_2023gzq.txt to 2023gzq.txt
# Renamed lc_2023gzz.txt to 2023gzz.txt
# Renamed lc_2023hac.txt to 2023hac.txt
# Renamed lc_2023had.txt to 2023had.txt
# Renamed lc_2023hao.txt to 2023hao.txt
# Renamed lc_2023hap.txt to 2023hap.txt
# Renamed lc_2023hdl.txt to 2023hdl.txt
# Renamed lc_2023hdy.txt to 2023hdy.txt
# Renamed lc_2023hdz.txt to 2023hdz.txt
# Renamed lc_2023hea.txt to 2023hea.txt
# Renamed lc_2023heb.txt to 2023heb.txt
# Renamed lc_2023hec.txt to 2023hec.txt
# Renamed lc_2023hga.txt to 2023hga.txt
# Renamed lc_2023hgb.txt to 2023hgb.txt
# Renamed lc_2023hgd.txt to 2023hgd.txt
# Renamed lc_2023hgg.txt to 2023hgg.txt
# Renamed lc_2023hgm.txt to 2023hgm.txt
# Renamed lc_2023hhg.txt to 2023hhg.txt
# Renamed lc_2023hhi.txt to 2023hhi.txt
# Renamed lc_2023hhl.txt to 2023hhl.txt
# Renamed lc_2023hhs.txt to 2023hhs.txt
# Renamed lc_2023hif.txt to 2023hif.txt
# Renamed lc_2023hiu.txt to 2023hiu.txt
# Renamed lc_2023hjr.txt to 2023hjr.txt
# Renamed lc_2023hka.txt to 2023hka.txt
# Renamed lc_2023hkj.txt to 2023hkj.txt
# Renamed lc_2023hma.txt to 2023hma.txt
# Renamed lc_2023hmp.txt to 2023hmp.txt
# Renamed lc_2023hnb.txt to 2023hnb.txt
# Renamed lc_2023hnd.txt to 2023hnd.txt
# Renamed lc_2023hng.txt to 2023hng.txt
# Renamed lc_2023ho.txt to 2023ho.txt
# Renamed lc_2023hpf.txt to 2023hpf.txt
# Renamed lc_2023hpn.txt to 2023hpn.txt
# Renamed lc_2023hqg.txt to 2023hqg.txt
# Renamed lc_2023hqh.txt to 2023hqh.txt
# Renamed lc_2023hqz.txt to 2023hqz.txt
# Renamed lc_2023hra.txt to 2023hra.txt
# Renamed lc_2023hsk.txt to 2023hsk.txt
# Renamed lc_2023hti.txt to 2023hti.txt
# Renamed lc_2023htj.txt to 2023htj.txt
# Renamed lc_2023htk.txt to 2023htk.txt
# Renamed lc_2023hto.txt to 2023hto.txt
# Renamed lc_2023htp.txt to 2023htp.txt
# Renamed lc_2023hts.txt to 2023hts.txt
# Renamed lc_2023hua.txt to 2023hua.txt
# Renamed lc_2023hvz.txt to 2023hvz.txt
# Renamed lc_2023hwc.txt to 2023hwc.txt
# Renamed lc_2023hwj.txt to 2023hwj.txt
# Renamed lc_2023hxz.txt to 2023hxz.txt
# Renamed lc_2023hy.txt to 2023hy.txt
# Renamed lc_2023hym.txt to 2023hym.txt
# Renamed lc_2023ie.txt to 2023ie.txt
# Renamed lc_2023ied.txt to 2023ied.txt
# Renamed lc_2023iio.txt to 2023iio.txt
# Renamed lc_2023ikp.txt to 2023ikp.txt
# Renamed lc_2023inb.txt to 2023inb.txt
# Renamed lc_2023iny.txt to 2023iny.txt
# Renamed lc_2023iua.txt to 2023iua.txt
# Renamed lc_2023iuk.txt to 2023iuk.txt
# Renamed lc_2023iwl.txt to 2023iwl.txt
# Renamed lc_2023ixg.txt to 2023ixg.txt
# Renamed lc_2023iy.txt to 2023iy.txt
# Renamed lc_2023iyb.txt to 2023iyb.txt
# Renamed lc_2023jaw.txt to 2023jaw.txt
# Renamed lc_2023jba.txt to 2023jba.txt
# Renamed lc_2023jbj.txt to 2023jbj.txt
# Renamed lc_2023jia.txt to 2023jia.txt
# Renamed lc_2023jml.txt to 2023jml.txt
# Renamed lc_2023jo.txt to 2023jo.txt
# Renamed lc_2023jtz.txt to 2023jtz.txt
# Renamed lc_2023jub.txt to 2023jub.txt
# Renamed lc_2023ma.txt to 2023ma.txt
# Renamed lc_2023mf.txt to 2023mf.txt
# Renamed lc_2023mg.txt to 2023mg.txt
# Renamed lc_2023ms.txt to 2023ms.txt
# Renamed lc_2023nm.txt to 2023nm.txt
# Renamed lc_2023np.txt to 2023np.txt
# Renamed lc_2023qb.txt to 2023qb.txt
# Renamed lc_2023rn.txt to 2023rn.txt
# Renamed lc_2023rr.txt to 2023rr.txt
# Renamed lc_2023rt.txt to 2023rt.txt
# Renamed lc_2023su.txt to 2023su.txt
# Renamed lc_2023tg.txt to 2023tg.txt
# Renamed lc_2023ua.txt to 2023ua.txt
# Renamed lc_2023ub.txt to 2023ub.txt
# Renamed lc_2023ut.txt to 2023ut.txt
# Renamed lc_2023wj.txt to 2023wj.txt
# Renamed lc_2023wo.txt to 2023wo.txt
# Renamed lc_2023wq.txt to 2023wq.txt
# Renamed lc_2023xk.txt to 2023xk.txt
# Renamed lc_2023xq.txt to 2023xq.txt
# Renamed lc_2023xw.txt to 2023xw.txt
# Renamed lc_2023xx.txt to 2023xx.txt
# Renamed lc_2023xz.txt to 2023xz.txt
# Renamed lc_2023yp.txt to 2023yp.txt
# Renamed lc_2023yx.txt to 2023yx.txt
# Renamed lc_2023yz.txt to 2023yz.txt
# Renamed lc_2023zt.txt to 2023zt.txt
# Renamed lc_GRB191016a.txt to GRB191016a.txt
# Prefix removed successfully

# %%
#This code takes all figures generated in each sector notebook and saves them as jpeg files
import os
import nbformat
from nbconvert.preprocessors import ExecutePreprocessor
from PIL import Image
import base64
import io

# Function to execute a notebook
def execute_notebook(notebook_path):
    with open(notebook_path) as f:
        nb = nbformat.read(f, as_version=4)

    # Execute the notebook
    ep = ExecutePreprocessor(timeout=600, kernel_name='python3')
    ep.preprocess(nb)

# Function to extract and save plots
def save_plots(notebook_path, output_dir):
    with open(notebook_path) as f:
        nb = nbformat.read(f, as_version=4)

    # Execute the notebook
    execute_notebook(notebook_path)

    # Extract plots from the executed notebook
    for cell in nb.cells:
        if 'outputs' in cell and cell.cell_type == 'code':
            for output in cell.outputs:
                if output.output_type == 'display_data' and 'image/png' in output.data:
                    image_data = output.data['image/png']
                    # Decode base64 encoded image data
                    image_bytes = base64.b64decode(image_data)
                    # Save the plot as a JPEG image file
                    plot_name = f"plot_{cell.execution_count}.jpeg"  # Change the file extension
                    plot_path = os.path.join(output_dir, plot_name)
                    with Image.open(io.BytesIO(image_bytes)) as img:
                        img.convert('RGB').save(plot_path, format='JPEG')  # Save as JPEG

# Function to process notebooks for sectors
def process_sectors():
    for sector in range(1, 67):
        sector_notebook_path = rf'C:\Users\nic51\TESS RESEARCH\Interesting_curves\sector_{sector}.ipynb'
        sector_output_dir = rf'C:\Users\nic51\TESS RESEARCH\Interesting_curves\sector{sector}_interestingcurves'
        os.makedirs(sector_output_dir, exist_ok=True)  # Create directory if it doesn't exist
        save_plots(sector_notebook_path, sector_output_dir)

process_sectors()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 48
#      45         os.makedirs(sector_output_dir, exist_ok=True)  # Create directory if it doesn't exist
#      46         save_plots(sector_notebook_path, sector_output_dir)
# ---> 48 process_sectors()
#
# Cell In[12], line 46, in process_sectors()
#      44 sector_output_dir = rf'C:\Users\nic51\TESS RESEARCH\Interesting_curves\sector{sector}_interestingcurves'
#      45 os.makedirs(sector_output_dir, exist_ok=True)  # Create directory if it doesn't exist
# ---> 46 save_plots(sector_notebook_path, sector_output_dir)
#
# Cell In[12], line 20, in save_plots(notebook_path, output_dir)
#      19 def save_plots(notebook_path, output_dir):
# ---> 20     with open(notebook_path) as f:
#      21         nb = nbformat.read(f, as_version=4)
#      23     # Execute the notebook
#
# File c:\Users\nic51\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\nic51\\TESS RESEARCH\\Interesting_curves\\sector_1.ipynb'

# %%
import os
from pptx import Presentation
from pptx.util import Inches
from PIL import Image
import tempfile

def resize_image(image_path, max_width, max_height):
    image = Image.open(image_path)
    width, height = image.size
    aspect_ratio = width / height

    if width > max_width or height > max_height:
        if aspect_ratio > 1:
            new_width = max_width
            new_height = max_width / aspect_ratio
        else:
            new_width = max_height * aspect_ratio
            new_height = max_height

        image = image.resize((int(new_width), int(new_height)), Image.ANTIALIAS)

    return image

def create_ppt_from_images(root_folder, output_pptx):
    prs = Presentation()
    max_width = Inches(8)
    max_height = Inches(6)

    for folder in os.listdir(root_folder):
        folder_path = os.path.join(root_folder, folder)
        if os.path.isdir(folder_path):
            # Add title slide for each folder
            title_slide_layout = prs.slide_layouts[0]  # Index 0 corresponds to the title slide layout
            title_slide = prs.slides.add_slide(title_slide_layout)
            title = title_slide.shapes.title
            title.text = folder

            for file_name in os.listdir(folder_path):
                if file_name.endswith(".jpg") or file_name.endswith(".jpeg"):
                    file_path = os.path.join(folder_path, file_name)
                    resized_image = resize_image(file_path, max_width, max_height)
                    with tempfile.NamedTemporaryFile(delete=False, suffix=".jpg") as temp_file:
                        temp_file_path = temp_file.name
                        resized_image.save(temp_file_path, format="JPEG")
                        slide_layout = prs.slide_layouts[6]
                        slide = prs.slides.add_slide(slide_layout)
                        left = top = Inches(1)
                        slide.shapes.add_picture(temp_file_path, left, top, width=max_width, height=max_height)

    prs.save(output_pptx)
    print("PowerPoint presentation created successfully!")

root_folder = r"C:\Users\nic51\TESS RESEARCH\Interesting_curves"
output_pptx = "output2.pptx"

create_ppt_from_images(root_folder, output_pptx)
# Out:
# PowerPoint presentation created successfully!
