# %%
import os
import requests

def download_tarball(url, save_path):
    response = requests.get(url)
    with open(save_path, 'wb') as f:
        f.write(response.content)

def main():
    # Base URL where the tarballs are located
    base_url = "https://tess.mit.edu/public/tesstransients/pages/"
    
    # Range of tarball numbers
    start_num = 1
    end_num = 66
    
    # Local directory where you want to save the tarballs
    local_directory = r"C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs"
    
    # Create the directory if it does not exist
    if not os.path.exists(local_directory):
        os.makedirs(local_directory)
    
    # Download each tarball file
    for i in range(start_num, end_num + 1):
        # Pad the number with leading zeros if necessary (e.g., s01, s02, ..., s66)
        tarball_num = str(i).zfill(2)
        # Construct the relative URL for the current tarball
        relative_url = f"../lc_bulk/s{tarball_num}.tgz"
        # Construct the full URL by joining the base URL and the relative URL
        full_url = base_url + relative_url
        # Extract the filename from the relative URL
        filename = os.path.basename(relative_url)
        # Construct the local save path
        local_save_path = os.path.join(local_directory, filename)
        # Download the tarball
        print(f"Downloading {filename} from {full_url}...")
        download_tarball(full_url, local_save_path)
        print(f"Downloaded {filename} to {local_save_path}")

if __name__ == "__main__":
    main()
# Out:
# Downloading s01.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s01.tgz...
# Downloaded s01.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s01.tgz
# Downloading s02.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s02.tgz...
# Downloaded s02.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s02.tgz
# Downloading s03.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s03.tgz...
# Downloaded s03.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s03.tgz
# Downloading s04.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s04.tgz...
# Downloaded s04.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s04.tgz
# Downloading s05.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s05.tgz...
# Downloaded s05.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s05.tgz
# Downloading s06.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s06.tgz...
# Downloaded s06.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s06.tgz
# Downloading s07.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s07.tgz...
# Downloaded s07.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s07.tgz
# Downloading s08.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s08.tgz...
# Downloaded s08.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s08.tgz
# Downloading s09.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s09.tgz...
# Downloaded s09.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s09.tgz
# Downloading s10.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s10.tgz...
# Downloaded s10.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s10.tgz
# Downloading s11.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s11.tgz...
# Downloaded s11.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s11.tgz
# Downloading s12.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s12.tgz...
# Downloaded s12.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s12.tgz
# Downloading s13.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s13.tgz...
# Downloaded s13.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s13.tgz
# Downloading s14.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s14.tgz...
# Downloaded s14.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s14.tgz
# Downloading s15.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s15.tgz...
# Downloaded s15.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s15.tgz
# Downloading s16.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s16.tgz...
# Downloaded s16.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s16.tgz
# Downloading s17.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s17.tgz...
# Downloaded s17.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s17.tgz
# Downloading s18.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s18.tgz...
# Downloaded s18.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s18.tgz
# Downloading s19.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s19.tgz...
# Downloaded s19.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s19.tgz
# Downloading s20.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s20.tgz...
# Downloaded s20.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s20.tgz
# Downloading s21.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s21.tgz...
# Downloaded s21.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s21.tgz
# Downloading s22.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s22.tgz...
# Downloaded s22.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s22.tgz
# Downloading s23.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s23.tgz...
# Downloaded s23.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s23.tgz
# Downloading s24.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s24.tgz...
# Downloaded s24.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s24.tgz
# Downloading s25.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s25.tgz...
# Downloaded s25.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s25.tgz
# Downloading s26.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s26.tgz...
# Downloaded s26.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s26.tgz
# Downloading s27.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s27.tgz...
# Downloaded s27.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s27.tgz
# Downloading s28.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s28.tgz...
# Downloaded s28.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s28.tgz
# Downloading s29.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s29.tgz...
# Downloaded s29.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s29.tgz
# Downloading s30.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s30.tgz...
# Downloaded s30.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s30.tgz
# Downloading s31.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s31.tgz...
# Downloaded s31.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s31.tgz
# Downloading s32.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s32.tgz...
# Downloaded s32.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s32.tgz
# Downloading s33.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s33.tgz...
# Downloaded s33.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s33.tgz
# Downloading s34.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s34.tgz...
# Downloaded s34.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s34.tgz
# Downloading s35.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s35.tgz...
# Downloaded s35.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s35.tgz
# Downloading s36.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s36.tgz...
# Downloaded s36.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s36.tgz
# Downloading s37.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s37.tgz...
# Downloaded s37.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s37.tgz
# Downloading s38.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s38.tgz...
# Downloaded s38.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s38.tgz
# Downloading s39.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s39.tgz...
# Downloaded s39.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s39.tgz
# Downloading s40.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s40.tgz...
# Downloaded s40.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s40.tgz
# Downloading s41.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s41.tgz...
# Downloaded s41.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s41.tgz
# Downloading s42.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s42.tgz...
# Downloaded s42.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s42.tgz
# Downloading s43.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s43.tgz...
# Downloaded s43.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s43.tgz
# Downloading s44.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s44.tgz...
# Downloaded s44.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s44.tgz
# Downloading s45.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s45.tgz...
# Downloaded s45.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s45.tgz
# Downloading s46.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s46.tgz...
# Downloaded s46.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s46.tgz
# Downloading s47.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s47.tgz...
# Downloaded s47.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s47.tgz
# Downloading s48.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s48.tgz...
# Downloaded s48.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s48.tgz
# Downloading s49.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s49.tgz...
# Downloaded s49.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s49.tgz
# Downloading s50.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s50.tgz...
# Downloaded s50.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s50.tgz
# Downloading s51.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s51.tgz...
# Downloaded s51.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s51.tgz
# Downloading s52.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s52.tgz...
# Downloaded s52.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s52.tgz
# Downloading s53.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s53.tgz...
# Downloaded s53.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s53.tgz
# Downloading s54.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s54.tgz...
# Downloaded s54.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s54.tgz
# Downloading s55.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s55.tgz...
# Downloaded s55.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s55.tgz
# Downloading s56.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s56.tgz...
# Downloaded s56.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s56.tgz
# Downloading s57.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s57.tgz...
# Downloaded s57.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s57.tgz
# Downloading s58.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s58.tgz...
# Downloaded s58.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s58.tgz
# Downloading s59.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s59.tgz...
# Downloaded s59.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s59.tgz
# Downloading s60.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s60.tgz...
# Downloaded s60.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s60.tgz
# Downloading s61.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s61.tgz...
# Downloaded s61.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s61.tgz
# Downloading s62.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s62.tgz...
# Downloaded s62.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s62.tgz
# Downloading s63.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s63.tgz...
# Downloaded s63.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s63.tgz
# Downloading s64.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s64.tgz...
# Downloaded s64.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s64.tgz
# Downloading s65.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s65.tgz...
# Downloaded s65.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s65.tgz
# Downloading s66.tgz from https://tess.mit.edu/public/tesstransients/pages/../lc_bulk/s66.tgz...
# Downloaded s66.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\s66.tgz

# %%
import os
import tarfile
import shutil

def extract_and_move_png(tgz_file, output_dir):
    try:
        with tarfile.open(tgz_file, 'r:gz') as tar:
            for member in tar.getmembers():
                if member.name.endswith('.png'):
                    file_name = os.path.basename(member.name)  # Extract just the file name
                    extracted_path = os.path.join(output_dir, file_name)
                    with tar.extractfile(member) as source, open(extracted_path, 'wb') as target:
                        shutil.copyfileobj(source, target)
        print(f"Extracted PNG files from {os.path.basename(tgz_file)} to {output_dir}")
    except tarfile.ReadError as e:
        print(f"Error extracting {os.path.basename(tgz_file)}:", e)

def main():
    # Local directory where the .tgz files are located
    local_directory = r"C:\Users\nic51\Code_Repos\Tess\Data\Tarballs"
    
    # Directory to store extracted PNG files
    output_dir = r"C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES"

    # Create the output directory for PNG files if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # Get a list of .tgz files in the local directory
    tgz_files = [f for f in os.listdir(local_directory) if f.endswith('.tgz')]
    
    # Extract and move PNG files from each .tgz file
    for tgz_file in tgz_files:
        # Construct the full path of the .tgz file
        tgz_file_path = os.path.join(local_directory, tgz_file)
        # Extract the PNG files from the .tgz file and move them to output directory
        extract_and_move_png(tgz_file_path, output_dir)

if __name__ == "__main__":
    main()
# Out:
# Extracted PNG files from s01.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s02.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s03.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s04.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s05.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s06.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s07.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s08.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s09.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s10.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s11.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s12.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s13.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s14.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s15.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s16.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s17.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s18.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s19.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s20.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s21.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s22.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s23.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s24.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s25.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s26.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s27.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s28.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s29.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s30.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s31.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s32.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s33.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s34.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s35.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s36.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s37.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s38.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s39.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s40.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s41.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s42.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s43.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s44.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s45.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s46.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s47.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s48.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s49.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s50.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s51.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s52.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s53.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s54.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s55.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s56.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s57.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s58.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s59.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s60.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s61.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s62.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s63.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s64.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s65.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES
# Extracted PNG files from s66.tgz to C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES

# %%
import os

def rename_files(directory, substrings_to_remove):
    for filename in os.listdir(directory):
        if filename.endswith('.png'):
            new_filename = filename
            # Remove specified substrings from the filename
            for substring in substrings_to_remove:
                if substring in new_filename:
                    new_filename = new_filename.replace(substring, '')
            # Construct the new path with the renamed file
            new_path = os.path.join(directory, new_filename)
            old_path = os.path.join(directory, filename)
            # Check if the new filename already exists
            if new_path != old_path and not os.path.exists(new_path):
                # Rename the file
                os.rename(old_path, new_path)
                print(f"Renamed {filename} to {new_filename}")
            elif new_path != old_path:
                print(f"Skipped renaming {filename}. {new_filename} already exists.")

def main():
    png_directory = r"C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs\PNG_FILES"
    
    # Define substrings to remove from filenames
    substrings_to_remove = ['lc_', '_cleaned']
    
    rename_files(png_directory, substrings_to_remove)

if __name__ == "__main__":
    main()
# Out:
# Skipped renaming lc_2018fhw_detrended_cleaned.png. 2018fhw_detrended.png already exists.
# Renamed lc_2018flj_cleaned.png to 2018flj.png
# Renamed lc_2018fll_cleaned.png to 2018fll.png
# Renamed lc_2018flq_cleaned.png to 2018flq.png
# Renamed lc_2018flr_cleaned.png to 2018flr.png
# Renamed lc_2018flt_cleaned.png to 2018flt.png
# Renamed lc_2018flz_cleaned.png to 2018flz.png
# Renamed lc_2018fmg_cleaned.png to 2018fmg.png
# Renamed lc_2018fmm_cleaned.png to 2018fmm.png
# Renamed lc_2018fmn_cleaned.png to 2018fmn.png
# Renamed lc_2018fns_cleaned.png to 2018fns.png
# Renamed lc_2018fqn_cleaned.png to 2018fqn.png
# Renamed lc_2018ftf_cleaned.png to 2018ftf.png
# Renamed lc_2018fub_cleaned.png to 2018fub.png
# Renamed lc_2018fvi_cleaned.png to 2018fvi.png
# Renamed lc_2018fvi_detrended.png to 2018fvi_detrended.png
# Skipped renaming lc_2018fvi_detrended_cleaned.png. 2018fvi_detrended.png already exists.
# Renamed lc_2018fwd_cleaned.png to 2018fwd.png
# Renamed lc_2018fwi_cleaned.png to 2018fwi.png
# Renamed lc_2018fwk_cleaned.png to 2018fwk.png
# Renamed lc_2018fwm_cleaned.png to 2018fwm.png
# Renamed lc_2018fwr_cleaned.png to 2018fwr.png
# Renamed lc_2018fxj_cleaned.png to 2018fxj.png
# Renamed lc_2018fxl_cleaned.png to 2018fxl.png
# Renamed lc_2018fzi_cleaned.png to 2018fzi.png
# Renamed lc_2018gey_cleaned.png to 2018gey.png
# Renamed lc_2018gfj_cleaned.png to 2018gfj.png
# Renamed lc_2018gfk_cleaned.png to 2018gfk.png
# Renamed lc_2018gku_cleaned.png to 2018gku.png
# Renamed lc_2018glp_cleaned.png to 2018glp.png
# Renamed lc_2018glq_cleaned.png to 2018glq.png
# Renamed lc_2018glv_cleaned.png to 2018glv.png
# Renamed lc_2018glw_cleaned.png to 2018glw.png
# Renamed lc_2018goa_cleaned.png to 2018goa.png
# Renamed lc_2018gqc_cleaned.png to 2018gqc.png
# Renamed lc_2018grv_cleaned.png to 2018grv.png
# Renamed lc_2018gsg_cleaned.png to 2018gsg.png
# Renamed lc_2018gty_cleaned.png to 2018gty.png
# Renamed lc_2018gum_cleaned.png to 2018gum.png
# Renamed lc_2018gxi_cleaned.png to 2018gxi.png
# Renamed lc_2018hac_cleaned.png to 2018hac.png
# Renamed lc_2018har_cleaned.png to 2018har.png
# Renamed lc_2018has_cleaned.png to 2018has.png
# Renamed lc_2018hbw_cleaned.png to 2018hbw.png
# Renamed lc_2018hdl_cleaned.png to 2018hdl.png
# Renamed lc_2018hdo_cleaned.png to 2018hdo.png
# Renamed lc_2018hdq_cleaned.png to 2018hdq.png
# Renamed lc_2018hgc_cleaned.png to 2018hgc.png
# Renamed lc_2018hgi_cleaned.png to 2018hgi.png
# Renamed lc_2018hgl_cleaned.png to 2018hgl.png
# Renamed lc_2018hib_cleaned.png to 2018hib.png
# Renamed lc_2018hib_detrended.png to 2018hib_detrended.png
# Skipped renaming lc_2018hib_detrended_cleaned.png. 2018hib_detrended.png already exists.
# Renamed lc_2018hjo_cleaned.png to 2018hjo.png
# Renamed lc_2018hjr_cleaned.png to 2018hjr.png
# Renamed lc_2018hka_cleaned.png to 2018hka.png
# Renamed lc_2018hkb_cleaned.png to 2018hkb.png
# Renamed lc_2018hkh_cleaned.png to 2018hkh.png
# Renamed lc_2018hks_cleaned.png to 2018hks.png
# Renamed lc_2018hkx_cleaned.png to 2018hkx.png
# Renamed lc_2018hlp_cleaned.png to 2018hlp.png
# Renamed lc_2018hmo_cleaned.png to 2018hmo.png
# Renamed lc_2018hnc_cleaned.png to 2018hnc.png
# Renamed lc_2018hnq_cleaned.png to 2018hnq.png
# Renamed lc_2018hoc_cleaned.png to 2018hoc.png
# Renamed lc_2018hpd_cleaned.png to 2018hpd.png
# Renamed lc_2018hpj_cleaned.png to 2018hpj.png
# Renamed lc_2018hps_cleaned.png to 2018hps.png
# Renamed lc_2018hpu_cleaned.png to 2018hpu.png
# Renamed lc_2018hql_cleaned.png to 2018hql.png
# Renamed lc_2018hrs_cleaned.png to 2018hrs.png
# Renamed lc_2018hsf_cleaned.png to 2018hsf.png
# Renamed lc_2018hsq_cleaned.png to 2018hsq.png
# Renamed lc_2018hss_cleaned.png to 2018hss.png
# Renamed lc_2018hss_detrended.png to 2018hss_detrended.png
# Skipped renaming lc_2018hss_detrended_cleaned.png. 2018hss_detrended.png already exists.
# Renamed lc_2018hsz_cleaned.png to 2018hsz.png
# Renamed lc_2018hte_cleaned.png to 2018hte.png
# Renamed lc_2018huc_cleaned.png to 2018huc.png
# Renamed lc_2018hue_cleaned.png to 2018hue.png
# Renamed lc_2018hum_cleaned.png to 2018hum.png
# Renamed lc_2018hxq_cleaned.png to 2018hxq.png
# Renamed lc_2018hyq_cleaned.png to 2018hyq.png
# Renamed lc_2018hyx_cleaned.png to 2018hyx.png
# Renamed lc_2018hyy_cleaned.png to 2018hyy.png
# Renamed lc_2018hzh_cleaned.png to 2018hzh.png
# Renamed lc_2018ien_cleaned.png to 2018ien.png
# Renamed lc_2018ieu_cleaned.png to 2018ieu.png
# Renamed lc_2018iez_cleaned.png to 2018iez.png
# Renamed lc_2018ifa_cleaned.png to 2018ifa.png
# Renamed lc_2018ifh_cleaned.png to 2018ifh.png
# Renamed lc_2018ifm_cleaned.png to 2018ifm.png
# Renamed lc_2018ift_cleaned.png to 2018ift.png
# Renamed lc_2018ihp_cleaned.png to 2018ihp.png
# Renamed lc_2018ihq_cleaned.png to 2018ihq.png
# Renamed lc_2018iht_cleaned.png to 2018iht.png
# Renamed lc_2018iin_cleaned.png to 2018iin.png
# Renamed lc_2018ijn_cleaned.png to 2018ijn.png
# Renamed lc_2018ime_cleaned.png to 2018ime.png
# Renamed lc_2018ioa_cleaned.png to 2018ioa.png
# Renamed lc_2018iti_cleaned.png to 2018iti.png
# Renamed lc_2018itr_cleaned.png to 2018itr.png
# Renamed lc_2018iuj_cleaned.png to 2018iuj.png
# Renamed lc_2018iwg_cleaned.png to 2018iwg.png
# Renamed lc_2018iwl_cleaned.png to 2018iwl.png
# Renamed lc_2018iyh_cleaned.png to 2018iyh.png
# Renamed lc_2018iyx_cleaned.png to 2018iyx.png
# Renamed lc_2018izg_cleaned.png to 2018izg.png
# Renamed lc_2018izr_cleaned.png to 2018izr.png
# Renamed lc_2018izt_cleaned.png to 2018izt.png
# Renamed lc_2018jad_cleaned.png to 2018jad.png
# Renamed lc_2018jbn_cleaned.png to 2018jbn.png
# Renamed lc_2018jco_cleaned.png to 2018jco.png
# Renamed lc_2018jdc_cleaned.png to 2018jdc.png
# Renamed lc_2018jeb_cleaned.png to 2018jeb.png
# Renamed lc_2018jej_cleaned.png to 2018jej.png
# Renamed lc_2018jfk_cleaned.png to 2018jfk.png
# Renamed lc_2018jgq_cleaned.png to 2018jgq.png
# Renamed lc_2018jhc_cleaned.png to 2018jhc.png
# Renamed lc_2018jhq_cleaned.png to 2018jhq.png
# Renamed lc_2018jih_cleaned.png to 2018jih.png
# Renamed lc_2018jjc_cleaned.png to 2018jjc.png
# Renamed lc_2018jjd_cleaned.png to 2018jjd.png
# Renamed lc_2018jjh_cleaned.png to 2018jjh.png
# Renamed lc_2018jjs_cleaned.png to 2018jjs.png
# Renamed lc_2018jju_cleaned.png to 2018jju.png
# Renamed lc_2018jkg_cleaned.png to 2018jkg.png
# Renamed lc_2018jms_cleaned.png to 2018jms.png
# Renamed lc_2018jmt_cleaned.png to 2018jmt.png
# Renamed lc_2018jnd_cleaned.png to 2018jnd.png
# Renamed lc_2018jpy_cleaned.png to 2018jpy.png
# Renamed lc_2018jri_cleaned.png to 2018jri.png
# Renamed lc_2018jro_cleaned.png to 2018jro.png
# Renamed lc_2018jsl_cleaned.png to 2018jsl.png
# Renamed lc_2018jtu_cleaned.png to 2018jtu.png
# Renamed lc_2018jtv_cleaned.png to 2018jtv.png
# Renamed lc_2018jwd_cleaned.png to 2018jwd.png
# Renamed lc_2018jwg_cleaned.png to 2018jwg.png
# Renamed lc_2018jwh_cleaned.png to 2018jwh.png
# Renamed lc_2018jwi_cleaned.png to 2018jwi.png
# Renamed lc_2018jwj_cleaned.png to 2018jwj.png
# Renamed lc_2018kah_cleaned.png to 2018kah.png
# Renamed lc_2018kao_cleaned.png to 2018kao.png
# Renamed lc_2018kbi_cleaned.png to 2018kbi.png
# Renamed lc_2018kbq_cleaned.png to 2018kbq.png
# Renamed lc_2018kcu_cleaned.png to 2018kcu.png
# Renamed lc_2018kfv_cleaned.png to 2018kfv.png
# Renamed lc_2018kfv_detrended.png to 2018kfv_detrended.png
# Skipped renaming lc_2018kfv_detrended_cleaned.png. 2018kfv_detrended.png already exists.
# Renamed lc_2018kgg_cleaned.png to 2018kgg.png
# Renamed lc_2018kib_cleaned.png to 2018kib.png
# Renamed lc_2018kif_cleaned.png to 2018kif.png
# Renamed lc_2018kig_cleaned.png to 2018kig.png
# Renamed lc_2018kih_cleaned.png to 2018kih.png
# Renamed lc_2018kjp_cleaned.png to 2018kjp.png
# Renamed lc_2018knl_cleaned.png to 2018knl.png
# Renamed lc_2018koy_cleaned.png to 2018koy.png
# Renamed lc_2018kpc_cleaned.png to 2018kpc.png
# Renamed lc_2018kqk_cleaned.png to 2018kqk.png
# Renamed lc_2018kqz_cleaned.png to 2018kqz.png
# Renamed lc_2018krw_cleaned.png to 2018krw.png
# Renamed lc_2018ksi_cleaned.png to 2018ksi.png
# Renamed lc_2018ksr_cleaned.png to 2018ksr.png
# Renamed lc_2018kuo_cleaned.png to 2018kuo.png
# Renamed lc_2018kuv_cleaned.png to 2018kuv.png
# Renamed lc_2018kvc_cleaned.png to 2018kvc.png
# Renamed lc_2018kvr_cleaned.png to 2018kvr.png
# Renamed lc_2018kvz_cleaned.png to 2018kvz.png
# Renamed lc_2018kwm_cleaned.png to 2018kwm.png
# Renamed lc_2018kwo_cleaned.png to 2018kwo.png
# Renamed lc_2018lab_cleaned.png to 2018lab.png
# Renamed lc_2018lad_cleaned.png to 2018lad.png
# Renamed lc_2018lit_cleaned.png to 2018lit.png
# Renamed lc_2018lla_cleaned.png to 2018lla.png
# Renamed lc_2018lml_cleaned.png to 2018lml.png
# Renamed lc_2018lne_cleaned.png to 2018lne.png
# Renamed lc_2018lot_cleaned.png to 2018lot.png
# Renamed lc_2019aan_cleaned.png to 2019aan.png
# Renamed lc_2019aaq_cleaned.png to 2019aaq.png
# Renamed lc_2019aay_cleaned.png to 2019aay.png
# Renamed lc_2019aba_cleaned.png to 2019aba.png
# Renamed lc_2019abb_cleaned.png to 2019abb.png
# Renamed lc_2019abc_cleaned.png to 2019abc.png
# Renamed lc_2019aby_cleaned.png to 2019aby.png
# Renamed lc_2019ach_cleaned.png to 2019ach.png
# Renamed lc_2019aeg_cleaned.png to 2019aeg.png
# Renamed lc_2019aen_cleaned.png to 2019aen.png
# Renamed lc_2019aeu_cleaned.png to 2019aeu.png
# Renamed lc_2019agu_cleaned.png to 2019agu.png
# Renamed lc_2019ahk_cleaned.png to 2019ahk.png
# Renamed lc_2019aib_cleaned.png to 2019aib.png
# Renamed lc_2019aih_cleaned.png to 2019aih.png
# Renamed lc_2019ait_cleaned.png to 2019ait.png
# Renamed lc_2019ajf_cleaned.png to 2019ajf.png
# Renamed lc_2019ako_cleaned.png to 2019ako.png
# Renamed lc_2019alb_cleaned.png to 2019alb.png
# Renamed lc_2019alj_cleaned.png to 2019alj.png
# Renamed lc_2019all_cleaned.png to 2019all.png
# Renamed lc_2019alq_cleaned.png to 2019alq.png
# Renamed lc_2019alv_cleaned.png to 2019alv.png
# Renamed lc_2019ane_cleaned.png to 2019ane.png
# Renamed lc_2019ank_cleaned.png to 2019ank.png
# Renamed lc_2019any_cleaned.png to 2019any.png
# Renamed lc_2019aqe_cleaned.png to 2019aqe.png
# Renamed lc_2019arw_cleaned.png to 2019arw.png
# Renamed lc_2019atc_cleaned.png to 2019atc.png
# Renamed lc_2019auk_cleaned.png to 2019auk.png
# Renamed lc_2019axh_cleaned.png to 2019axh.png
# Renamed lc_2019axj_cleaned.png to 2019axj.png
# Renamed lc_2019ayy_cleaned.png to 2019ayy.png
# Renamed lc_2019azi_cleaned.png to 2019azi.png
# Renamed lc_2019bap_cleaned.png to 2019bap.png
# Renamed lc_2019bca_cleaned.png to 2019bca.png
# Renamed lc_2019bcp_cleaned.png to 2019bcp.png
# Renamed lc_2019bcu_cleaned.png to 2019bcu.png
# Renamed lc_2019bea_cleaned.png to 2019bea.png
# Renamed lc_2019beb_cleaned.png to 2019beb.png
# Renamed lc_2019bes_cleaned.png to 2019bes.png
# Renamed lc_2019bet_cleaned.png to 2019bet.png
# Renamed lc_2019beu_cleaned.png to 2019beu.png
# Renamed lc_2019bfb_cleaned.png to 2019bfb.png
# Renamed lc_2019bfd_cleaned.png to 2019bfd.png
# Renamed lc_2019bfz_cleaned.png to 2019bfz.png
# Renamed lc_2019bgo_cleaned.png to 2019bgo.png
# Renamed lc_2019bgp_cleaned.png to 2019bgp.png
# Renamed lc_2019bip_cleaned.png to 2019bip.png
# Renamed lc_2019biq_cleaned.png to 2019biq.png
# Renamed lc_2019biu_cleaned.png to 2019biu.png
# Renamed lc_2019bnk_cleaned.png to 2019bnk.png
# Renamed lc_2019boo_cleaned.png to 2019boo.png
# Renamed lc_2019bop_cleaned.png to 2019bop.png
# Renamed lc_2019boq_cleaned.png to 2019boq.png
# Renamed lc_2019box_cleaned.png to 2019box.png
# Renamed lc_2019bqk_cleaned.png to 2019bqk.png
# Renamed lc_2019bql_cleaned.png to 2019bql.png
# Renamed lc_2019bsw_cleaned.png to 2019bsw.png
# Renamed lc_2019bvp_cleaned.png to 2019bvp.png
# Renamed lc_2019bwb_cleaned.png to 2019bwb.png
# Renamed lc_2019bwo_cleaned.png to 2019bwo.png
# Renamed lc_2019bwu_cleaned.png to 2019bwu.png
# Renamed lc_2019bxg_cleaned.png to 2019bxg.png
# Renamed lc_2019bxi_cleaned.png to 2019bxi.png
# Renamed lc_2019bxl_cleaned.png to 2019bxl.png
# Renamed lc_2019caa_cleaned.png to 2019caa.png
# Renamed lc_2019cdy_cleaned.png to 2019cdy.png
# Renamed lc_2019cgy_cleaned.png to 2019cgy.png
# Renamed lc_2019cix_cleaned.png to 2019cix.png
# Renamed lc_2019cjp_cleaned.png to 2019cjp.png
# Renamed lc_2019cjz_cleaned.png to 2019cjz.png
# Renamed lc_2019cj_cleaned.png to 2019cj.png
# Renamed lc_2019clt_cleaned.png to 2019clt.png
# Renamed lc_2019clu_cleaned.png to 2019clu.png
# Renamed lc_2019cmb_cleaned.png to 2019cmb.png
# Renamed lc_2019cmf_cleaned.png to 2019cmf.png
# Renamed lc_2019cml_cleaned.png to 2019cml.png
# Renamed lc_2019coc_cleaned.png to 2019coc.png
# Renamed lc_2019con_cleaned.png to 2019con.png
# Renamed lc_2019cos_cleaned.png to 2019cos.png
# Renamed lc_2019cot_cleaned.png to 2019cot.png
# Renamed lc_2019cou_cleaned.png to 2019cou.png
# Renamed lc_2019cow_cleaned.png to 2019cow.png
# Renamed lc_2019coz_cleaned.png to 2019coz.png
# Renamed lc_2019cqf_cleaned.png to 2019cqf.png
# Renamed lc_2019cqi_cleaned.png to 2019cqi.png
# Renamed lc_2019cqk_cleaned.png to 2019cqk.png
# Renamed lc_2019cql_cleaned.png to 2019cql.png
# Renamed lc_2019crw_cleaned.png to 2019crw.png
# Renamed lc_2019crx_cleaned.png to 2019crx.png
# Renamed lc_2019crz_cleaned.png to 2019crz.png
# Renamed lc_2019cwr_cleaned.png to 2019cwr.png
# Renamed lc_2019cxt_cleaned.png to 2019cxt.png
# Renamed lc_2019czn_cleaned.png to 2019czn.png
# Renamed lc_2019dbm_cleaned.png to 2019dbm.png
# Renamed lc_2019dcj_cleaned.png to 2019dcj.png
# Renamed lc_2019ddc_cleaned.png to 2019ddc.png
# Renamed lc_2019deo_cleaned.png to 2019deo.png
# Renamed lc_2019dfr_cleaned.png to 2019dfr.png
# Renamed lc_2019dhm_cleaned.png to 2019dhm.png
# Renamed lc_2019dhz_cleaned.png to 2019dhz.png
# Renamed lc_2019din_cleaned.png to 2019din.png
# Renamed lc_2019dit_cleaned.png to 2019dit.png
# Renamed lc_2019djd_cleaned.png to 2019djd.png
# Renamed lc_2019dji_cleaned.png to 2019dji.png
# Renamed lc_2019dke_cleaned.png to 2019dke.png
# Renamed lc_2019dng_cleaned.png to 2019dng.png
# Renamed lc_2019dns_cleaned.png to 2019dns.png
# Renamed lc_2019dov_cleaned.png to 2019dov.png
# Renamed lc_2019dpd_cleaned.png to 2019dpd.png
# Renamed lc_2019dpz_cleaned.png to 2019dpz.png
# Renamed lc_2019dqg_cleaned.png to 2019dqg.png
# Renamed lc_2019dsn_cleaned.png to 2019dsn.png
# Renamed lc_2019dtv_cleaned.png to 2019dtv.png
# Renamed lc_2019dut_cleaned.png to 2019dut.png
# Renamed lc_2019dwl_cleaned.png to 2019dwl.png
# Renamed lc_2019dww_cleaned.png to 2019dww.png
# Renamed lc_2019dzc_cleaned.png to 2019dzc.png
# Renamed lc_2019dzs_cleaned.png to 2019dzs.png
# Renamed lc_2019ebe_cleaned.png to 2019ebe.png
# Renamed lc_2019ebh_cleaned.png to 2019ebh.png
# Renamed lc_2019ecn_cleaned.png to 2019ecn.png
# Renamed lc_2019edh_cleaned.png to 2019edh.png
# Renamed lc_2019egw_cleaned.png to 2019egw.png
# Renamed lc_2019ehv_cleaned.png to 2019ehv.png
# Renamed lc_2019ehx_cleaned.png to 2019ehx.png
# Renamed lc_2019ehy_cleaned.png to 2019ehy.png
# Renamed lc_2019ekk_cleaned.png to 2019ekk.png
# Renamed lc_2019ekn_cleaned.png to 2019ekn.png
# Renamed lc_2019ekp_cleaned.png to 2019ekp.png
# Renamed lc_2019erz_cleaned.png to 2019erz.png
# Renamed lc_2019esa_cleaned.png to 2019esa.png
# Renamed lc_2019esl_cleaned.png to 2019esl.png
# Renamed lc_2019esm_cleaned.png to 2019esm.png
# Renamed lc_2019exu_cleaned.png to 2019exu.png
# Renamed lc_2019fcc_cleaned.png to 2019fcc.png
# Renamed lc_2019fir_cleaned.png to 2019fir.png
# Renamed lc_2019fis_cleaned.png to 2019fis.png
# Renamed lc_2019fjs_cleaned.png to 2019fjs.png
# Renamed lc_2019fp_cleaned.png to 2019fp.png
# Renamed lc_2019gac_cleaned.png to 2019gac.png
# Renamed lc_2019gak_cleaned.png to 2019gak.png
# Renamed lc_2019gb_cleaned.png to 2019gb.png
# Renamed lc_2019gdc_cleaned.png to 2019gdc.png
# Renamed lc_2019gdg_cleaned.png to 2019gdg.png
# Renamed lc_2019gdy_cleaned.png to 2019gdy.png
# Renamed lc_2019gg_cleaned.png to 2019gg.png
# Renamed lc_2019gn_cleaned.png to 2019gn.png
# Renamed lc_2019gqv_cleaned.png to 2019gqv.png
# Renamed lc_2019guh_cleaned.png to 2019guh.png
# Renamed lc_2019gvc_cleaned.png to 2019gvc.png
# Renamed lc_2019gvi_cleaned.png to 2019gvi.png
# Renamed lc_2019gvp_cleaned.png to 2019gvp.png
# Renamed lc_2019gwq_cleaned.png to 2019gwq.png
# Renamed lc_2019gws_cleaned.png to 2019gws.png
# Renamed lc_2019gyb_cleaned.png to 2019gyb.png
# Renamed lc_2019gzu_cleaned.png to 2019gzu.png
# Renamed lc_2019hcn_cleaned.png to 2019hcn.png
# Renamed lc_2019hit_cleaned.png to 2019hit.png
# Renamed lc_2019hkx_cleaned.png to 2019hkx.png
# Renamed lc_2019hlb_cleaned.png to 2019hlb.png
# Renamed lc_2019hmh_cleaned.png to 2019hmh.png
# Renamed lc_2019hnp_cleaned.png to 2019hnp.png
# Renamed lc_2019hpg_cleaned.png to 2019hpg.png
# Renamed lc_2019hrs_cleaned.png to 2019hrs.png
# Renamed lc_2019hsc_cleaned.png to 2019hsc.png
# Renamed lc_2019hsl_cleaned.png to 2019hsl.png
# Renamed lc_2019hsq_cleaned.png to 2019hsq.png
# Renamed lc_2019htm_cleaned.png to 2019htm.png
# Renamed lc_2019htv_cleaned.png to 2019htv.png
# Renamed lc_2019htx_cleaned.png to 2019htx.png
# Renamed lc_2019hvx_cleaned.png to 2019hvx.png
# Renamed lc_2019hyu_cleaned.png to 2019hyu.png
# Renamed lc_2019hzo_cleaned.png to 2019hzo.png
# Renamed lc_2019hzq_cleaned.png to 2019hzq.png
# Renamed lc_2019iac_cleaned.png to 2019iac.png
# Renamed lc_2019iar_cleaned.png to 2019iar.png
# Renamed lc_2019ibg_cleaned.png to 2019ibg.png
# Renamed lc_2019ifd_cleaned.png to 2019ifd.png
# Renamed lc_2019ify_cleaned.png to 2019ify.png
# Renamed lc_2019ihi_cleaned.png to 2019ihi.png
# Renamed lc_2019iio_cleaned.png to 2019iio.png
# Renamed lc_2019iiv_cleaned.png to 2019iiv.png
# Renamed lc_2019iy_cleaned.png to 2019iy.png
# Renamed lc_2019jh_cleaned.png to 2019jh.png
# Renamed lc_2019jom_cleaned.png to 2019jom.png
# Renamed lc_2019jor_cleaned.png to 2019jor.png
# Renamed lc_2019jyj_cleaned.png to 2019jyj.png
# Renamed lc_2019kag_cleaned.png to 2019kag.png
# Renamed lc_2019khg_cleaned.png to 2019khg.png
# Renamed lc_2019kh_cleaned.png to 2019kh.png
# Renamed lc_2019kim_cleaned.png to 2019kim.png
# Renamed lc_2019kli_cleaned.png to 2019kli.png
# Renamed lc_2019kll_cleaned.png to 2019kll.png
# Renamed lc_2019kqd_cleaned.png to 2019kqd.png
# Renamed lc_2019kqq_cleaned.png to 2019kqq.png
# Renamed lc_2019krd_cleaned.png to 2019krd.png
# Renamed lc_2019krj_cleaned.png to 2019krj.png
# Renamed lc_2019kt_cleaned.png to 2019kt.png
# Renamed lc_2019kvh_cleaned.png to 2019kvh.png
# Renamed lc_2019kwc_cleaned.png to 2019kwc.png
# Renamed lc_2019lbm_cleaned.png to 2019lbm.png
# Renamed lc_2019llb_cleaned.png to 2019llb.png
# Renamed lc_2019lld_cleaned.png to 2019lld.png
# Renamed lc_2019llg_cleaned.png to 2019llg.png
# Renamed lc_2019lli_cleaned.png to 2019lli.png
# Renamed lc_2019lls_cleaned.png to 2019lls.png
# Renamed lc_2019lmf_cleaned.png to 2019lmf.png
# Renamed lc_2019lmi_cleaned.png to 2019lmi.png
# Renamed lc_2019lo_cleaned.png to 2019lo.png
# Renamed lc_2019lpf_cleaned.png to 2019lpf.png
# Renamed lc_2019lph_cleaned.png to 2019lph.png
# Renamed lc_2019lpk_cleaned.png to 2019lpk.png
# Renamed lc_2019lpr_cleaned.png to 2019lpr.png
# Renamed lc_2019lpw_cleaned.png to 2019lpw.png
# Renamed lc_2019lqc_cleaned.png to 2019lqc.png
# Renamed lc_2019lqg_cleaned.png to 2019lqg.png
# Renamed lc_2019lqo_cleaned.png to 2019lqo.png
# Renamed lc_2019lrq_cleaned.png to 2019lrq.png
# Renamed lc_2019lrs_cleaned.png to 2019lrs.png
# Renamed lc_2019lru_cleaned.png to 2019lru.png
# Renamed lc_2019lrx_cleaned.png to 2019lrx.png
# Renamed lc_2019lsf_cleaned.png to 2019lsf.png
# Renamed lc_2019lso_cleaned.png to 2019lso.png
# Renamed lc_2019lst_cleaned.png to 2019lst.png
# Renamed lc_2019luq_cleaned.png to 2019luq.png
# Renamed lc_2019lus_cleaned.png to 2019lus.png
# Renamed lc_2019lut_cleaned.png to 2019lut.png
# Renamed lc_2019lyd_cleaned.png to 2019lyd.png
# Renamed lc_2019lym_cleaned.png to 2019lym.png
# Renamed lc_2019mah_cleaned.png to 2019mah.png
# Renamed lc_2019maz_cleaned.png to 2019maz.png
# Renamed lc_2019mba_cleaned.png to 2019mba.png
# Renamed lc_2019mbi_cleaned.png to 2019mbi.png
# Renamed lc_2019mdc_cleaned.png to 2019mdc.png
# Renamed lc_2019mdp_cleaned.png to 2019mdp.png
# Renamed lc_2019mdq_cleaned.png to 2019mdq.png
# Renamed lc_2019mdr_cleaned.png to 2019mdr.png
# Renamed lc_2019mds_cleaned.png to 2019mds.png
# Renamed lc_2019mdw_cleaned.png to 2019mdw.png
# Renamed lc_2019meb_cleaned.png to 2019meb.png
# Renamed lc_2019mec_cleaned.png to 2019mec.png
# Renamed lc_2019med_cleaned.png to 2019med.png
# Renamed lc_2019mee_cleaned.png to 2019mee.png
# Renamed lc_2019mef_cleaned.png to 2019mef.png
# Renamed lc_2019meg_cleaned.png to 2019meg.png
# Renamed lc_2019men_cleaned.png to 2019men.png
# Renamed lc_2019mgr_cleaned.png to 2019mgr.png
# Renamed lc_2019mhv_cleaned.png to 2019mhv.png
# Renamed lc_2019mim_cleaned.png to 2019mim.png
# Renamed lc_2019mkg_cleaned.png to 2019mkg.png
# Renamed lc_2019mkl_cleaned.png to 2019mkl.png
# Renamed lc_2019mku_cleaned.png to 2019mku.png
# Renamed lc_2019mos_cleaned.png to 2019mos.png
# Renamed lc_2019mpq_cleaned.png to 2019mpq.png
# Renamed lc_2019mpt_cleaned.png to 2019mpt.png
# Renamed lc_2019mqc_cleaned.png to 2019mqc.png
# Renamed lc_2019mqg_cleaned.png to 2019mqg.png
# Renamed lc_2019mqz_cleaned.png to 2019mqz.png
# Renamed lc_2019mrd_cleaned.png to 2019mrd.png
# Renamed lc_2019mrf_cleaned.png to 2019mrf.png
# Renamed lc_2019mrg_cleaned.png to 2019mrg.png
# Renamed lc_2019msr_cleaned.png to 2019msr.png
# Renamed lc_2019mtm_cleaned.png to 2019mtm.png
# Renamed lc_2019mts_cleaned.png to 2019mts.png
# Renamed lc_2019mtt_cleaned.png to 2019mtt.png
# Renamed lc_2019mtz_cleaned.png to 2019mtz.png
# Renamed lc_2019mue_cleaned.png to 2019mue.png
# Renamed lc_2019mue_detrended_cleaned.png to 2019mue_detrended.png
# Renamed lc_2019muf_cleaned.png to 2019muf.png
# Renamed lc_2019muu_cleaned.png to 2019muu.png
# Renamed lc_2019muz_cleaned.png to 2019muz.png
# Renamed lc_2019mvj_cleaned.png to 2019mvj.png
# Renamed lc_2019mzo_cleaned.png to 2019mzo.png
# Renamed lc_2019mzy_cleaned.png to 2019mzy.png
# Renamed lc_2019ncd_cleaned.png to 2019ncd.png
# Renamed lc_2019ndl_cleaned.png to 2019ndl.png
# Renamed lc_2019nfq_cleaned.png to 2019nfq.png
# Renamed lc_2019nfv_cleaned.png to 2019nfv.png
# Renamed lc_2019nil_cleaned.png to 2019nil.png
# Renamed lc_2019njg_cleaned.png to 2019njg.png
# Renamed lc_2019njr_cleaned.png to 2019njr.png
# Renamed lc_2019njy_cleaned.png to 2019njy.png
# Renamed lc_2019nkq_cleaned.png to 2019nkq.png
# Renamed lc_2019nkr_cleaned.png to 2019nkr.png
# Renamed lc_2019nlc_cleaned.png to 2019ncleaned.png
# Renamed lc_2019nld_cleaned.png to 2019nld.png
# Renamed lc_2019nms_cleaned.png to 2019nms.png
# Renamed lc_2019nng_cleaned.png to 2019nng.png
# Renamed lc_2019nnr_cleaned.png to 2019nnr.png
# Renamed lc_2019noc_cleaned.png to 2019noc.png
# Renamed lc_2019nof_cleaned.png to 2019nof.png
# Renamed lc_2019nql_cleaned.png to 2019nql.png
# Renamed lc_2019nqn_cleaned.png to 2019nqn.png
# Renamed lc_2019nty_cleaned.png to 2019nty.png
# Renamed lc_2019ntz_cleaned.png to 2019ntz.png
# Renamed lc_2019nud_cleaned.png to 2019nud.png
# Renamed lc_2019nvj_cleaned.png to 2019nvj.png
# Renamed lc_2019nvk_cleaned.png to 2019nvk.png
# Renamed lc_2019nvl_cleaned.png to 2019nvl.png
# Renamed lc_2019nvm_cleaned.png to 2019nvm.png
# Renamed lc_2019nvw_cleaned.png to 2019nvw.png
# Renamed lc_2019nwu_cleaned.png to 2019nwu.png
# Renamed lc_2019nxp_cleaned.png to 2019nxp.png
# Renamed lc_2019nyf_cleaned.png to 2019nyf.png
# Renamed lc_2019nyo_cleaned.png to 2019nyo.png
# Renamed lc_2019nzp_cleaned.png to 2019nzp.png
# Renamed lc_2019nzq_cleaned.png to 2019nzq.png
# Renamed lc_2019oba_cleaned.png to 2019oba.png
# Renamed lc_2019obp_cleaned.png to 2019obp.png
# Renamed lc_2019oda_cleaned.png to 2019oda.png
# Renamed lc_2019ofn_cleaned.png to 2019ofn.png
# Renamed lc_2019oft_cleaned.png to 2019oft.png
# Renamed lc_2019ohj_cleaned.png to 2019ohj.png
# Renamed lc_2019omq_cleaned.png to 2019omq.png
# Renamed lc_2019onn_cleaned.png to 2019onn.png
# Renamed lc_2019ooj_cleaned.png to 2019ooj.png
# Renamed lc_2019ook_cleaned.png to 2019ook.png
# Renamed lc_2019opq_cleaned.png to 2019opq.png
# Renamed lc_2019opz_cleaned.png to 2019opz.png
# Renamed lc_2019oqb_cleaned.png to 2019oqb.png
# Renamed lc_2019oqc_cleaned.png to 2019oqc.png
# Renamed lc_2019ord_cleaned.png to 2019ord.png
# Renamed lc_2019osp_cleaned.png to 2019osp.png
# Renamed lc_2019osx_cleaned.png to 2019osx.png
# Renamed lc_2019osz_cleaned.png to 2019osz.png
# Renamed lc_2019oug_cleaned.png to 2019oug.png
# Renamed lc_2019ouk_cleaned.png to 2019ouk.png
# Renamed lc_2019ouw_cleaned.png to 2019ouw.png
# Renamed lc_2019ows_cleaned.png to 2019ows.png
# Renamed lc_2019owy_cleaned.png to 2019owy.png
# Renamed lc_2019oxg_cleaned.png to 2019oxg.png
# Renamed lc_2019oxo_cleaned.png to 2019oxo.png
# Renamed lc_2019oye_cleaned.png to 2019oye.png
# Renamed lc_2019oyk_cleaned.png to 2019oyk.png
# Renamed lc_2019ozf_cleaned.png to 2019ozf.png
# Renamed lc_2019ozg_cleaned.png to 2019ozg.png
# Renamed lc_2019pac_cleaned.png to 2019pac.png
# Renamed lc_2019pai_cleaned.png to 2019pai.png
# Renamed lc_2019pat_cleaned.png to 2019pat.png
# Renamed lc_2019pau_cleaned.png to 2019pau.png
# Renamed lc_2019pco_cleaned.png to 2019pco.png
# Renamed lc_2019pcy_cleaned.png to 2019pcy.png
# Renamed lc_2019pdx_cleaned.png to 2019pdx.png
# Renamed lc_2019pfb_cleaned.png to 2019pfb.png
# Renamed lc_2019pgi_cleaned.png to 2019pgi.png
# Renamed lc_2019pgp_cleaned.png to 2019pgp.png
# Renamed lc_2019pgu_cleaned.png to 2019pgu.png
# Renamed lc_2019pho_cleaned.png to 2019pho.png
# Renamed lc_2019php_cleaned.png to 2019php.png
# Renamed lc_2019pjk_cleaned.png to 2019pjk.png
# Renamed lc_2019pjm_cleaned.png to 2019pjm.png
# Renamed lc_2019pju_cleaned.png to 2019pju.png
# Renamed lc_2019pkz_cleaned.png to 2019pkz.png
# Renamed lc_2019pla_cleaned.png to 2019pla.png
# Renamed lc_2019pmr_cleaned.png to 2019pmr.png
# Renamed lc_2019pmt_cleaned.png to 2019pmt.png
# Renamed lc_2019pm_cleaned.png to 2019pm.png
# Renamed lc_2019pnp_cleaned.png to 2019pnp.png
# Renamed lc_2019pnw_cleaned.png to 2019pnw.png
# Renamed lc_2019pnw_detrended_cleaned.png to 2019pnw_detrended.png
# Renamed lc_2019pny_cleaned.png to 2019pny.png
# Renamed lc_2019poz_cleaned.png to 2019poz.png
# Renamed lc_2019pqm_cleaned.png to 2019pqm.png
# Renamed lc_2019pqv_cleaned.png to 2019pqv.png
# Renamed lc_2019prm_cleaned.png to 2019prm.png
# Renamed lc_2019prs_cleaned.png to 2019prs.png
# Renamed lc_2019prw_cleaned.png to 2019prw.png
# Renamed lc_2019prw_detrended_cleaned.png to 2019prw_detrended.png
# Renamed lc_2019prx_cleaned.png to 2019prx.png
# Renamed lc_2019ptf_cleaned.png to 2019ptf.png
# Renamed lc_2019ptg_cleaned.png to 2019ptg.png
# Renamed lc_2019ptv_cleaned.png to 2019ptv.png
# Renamed lc_2019ptv_detrended_cleaned.png to 2019ptv_detrended.png
# Renamed lc_2019pv_cleaned.png to 2019pv.png
# Renamed lc_2019pwa_cleaned.png to 2019pwa.png
# Renamed lc_2019pwd_cleaned.png to 2019pwd.png
# Renamed lc_2019pwq_cleaned.png to 2019pwq.png
# Renamed lc_2019pwr_cleaned.png to 2019pwr.png
# Renamed lc_2019pxv_cleaned.png to 2019pxv.png
# Renamed lc_2019pxx_cleaned.png to 2019pxx.png
# Renamed lc_2019pzj_cleaned.png to 2019pzj.png
# Renamed lc_2019pzn_cleaned.png to 2019pzn.png
# Renamed lc_2019pzq_cleaned.png to 2019pzq.png
# Renamed lc_2019pzt_cleaned.png to 2019pzt.png
# Renamed lc_2019qbs_cleaned.png to 2019qbs.png
# Renamed lc_2019qck_cleaned.png to 2019qck.png
# Renamed lc_2019qcu_cleaned.png to 2019qcu.png
# Renamed lc_2019qcw_cleaned.png to 2019qcw.png
# Renamed lc_2019qdh_cleaned.png to 2019qdh.png
# Renamed lc_2019qdi_cleaned.png to 2019qdi.png
# Renamed lc_2019qdm_cleaned.png to 2019qdm.png
# Renamed lc_2019qew_cleaned.png to 2019qew.png
# Renamed lc_2019qey_cleaned.png to 2019qey.png
# Renamed lc_2019qgh_cleaned.png to 2019qgh.png
# Renamed lc_2019qgj_cleaned.png to 2019qgj.png
# Renamed lc_2019qgx_cleaned.png to 2019qgx.png
# Renamed lc_2019qhg_cleaned.png to 2019qhg.png
# Renamed lc_2019qhh_cleaned.png to 2019qhh.png
# Renamed lc_2019qib_cleaned.png to 2019qib.png
# Renamed lc_2019qjh_cleaned.png to 2019qjh.png
# Renamed lc_2019qmm_cleaned.png to 2019qmm.png
# Renamed lc_2019qmm_detrended_cleaned.png to 2019qmm_detrended.png
# Renamed lc_2019qmt_cleaned.png to 2019qmt.png
# Renamed lc_2019qoj_cleaned.png to 2019qoj.png
# Renamed lc_2019qpc_cleaned.png to 2019qpc.png
# Renamed lc_2019qpx_cleaned.png to 2019qpx.png
# Renamed lc_2019qqk_cleaned.png to 2019qqk.png
# Renamed lc_2019qql_cleaned.png to 2019qql.png
# Renamed lc_2019qqr_cleaned.png to 2019qqr.png
# Renamed lc_2019qqs_cleaned.png to 2019qqs.png
# Renamed lc_2019qrh_cleaned.png to 2019qrh.png
# Renamed lc_2019qsc_cleaned.png to 2019qsc.png
# Renamed lc_2019qsc_detrended.png to 2019qsc_detrended.png
# Skipped renaming lc_2019qsc_detrended_cleaned.png. 2019qsc_detrended.png already exists.
# Renamed lc_2019qtw_cleaned.png to 2019qtw.png
# Renamed lc_2019qty_cleaned.png to 2019qty.png
# Renamed lc_2019qwf_cleaned.png to 2019qwf.png
# Renamed lc_2019qwj_cleaned.png to 2019qwj.png
# Renamed lc_2019qwl_cleaned.png to 2019qwl.png
# Renamed lc_2019qxo_cleaned.png to 2019qxo.png
# Renamed lc_2019qyb_cleaned.png to 2019qyb.png
# Renamed lc_2019qyc_cleaned.png to 2019qyc.png
# Renamed lc_2019rdl_cleaned.png to 2019rdl.png
# Renamed lc_2019rdp_cleaned.png to 2019rdp.png
# Renamed lc_2019rex_cleaned.png to 2019rex.png
# Renamed lc_2019rhl_cleaned.png to 2019rhl.png
# Renamed lc_2019rhy_cleaned.png to 2019rhy.png
# Renamed lc_2019rid_cleaned.png to 2019rid.png
# Renamed lc_2019ris_cleaned.png to 2019ris.png
# Renamed lc_2019rj_cleaned.png to 2019rj.png
# Renamed lc_2019rle_cleaned.png to 2019rle.png
# Renamed lc_2019rmp_cleaned.png to 2019rmp.png
# Renamed lc_2019rm_cleaned.png to 2019rm.png
# Renamed lc_2019rpz_cleaned.png to 2019rpz.png
# Renamed lc_2019rqd_cleaned.png to 2019rqd.png
# Renamed lc_2019rqf_cleaned.png to 2019rqf.png
# Renamed lc_2019rqg_cleaned.png to 2019rqg.png
# Renamed lc_2019rqu_cleaned.png to 2019rqu.png
# Renamed lc_2019rrc_cleaned.png to 2019rrc.png
# Renamed lc_2019rrd_cleaned.png to 2019rrd.png
# Renamed lc_2019rre_cleaned.png to 2019rre.png
# Renamed lc_2019ruc_cleaned.png to 2019ruc.png
# Renamed lc_2019ruf_cleaned.png to 2019ruf.png
# Renamed lc_2019rug_cleaned.png to 2019rug.png
# Renamed lc_2019rvh_cleaned.png to 2019rvh.png
# Renamed lc_2019rvx_cleaned.png to 2019rvx.png
# Renamed lc_2019rwg_cleaned.png to 2019rwg.png
# Renamed lc_2019rwh_cleaned.png to 2019rwh.png
# Renamed lc_2019ryj_cleaned.png to 2019ryj.png
# Renamed lc_2019sap_cleaned.png to 2019sap.png
# Renamed lc_2019saz_cleaned.png to 2019saz.png
# Renamed lc_2019sbi_cleaned.png to 2019sbi.png
# Renamed lc_2019sbu_cleaned.png to 2019sbu.png
# Renamed lc_2019sbx_cleaned.png to 2019sbx.png
# Renamed lc_2019sbz_cleaned.png to 2019sbz.png
# Renamed lc_2019sdl_cleaned.png to 2019sdl.png
# Renamed lc_2019sdp_cleaned.png to 2019sdp.png
# Renamed lc_2019sej_cleaned.png to 2019sej.png
# Renamed lc_2019sep_cleaned.png to 2019sep.png
# Renamed lc_2019sfx_cleaned.png to 2019sfx.png
# Renamed lc_2019sgb_cleaned.png to 2019sgb.png
# Renamed lc_2019sgq_cleaned.png to 2019sgq.png
# Renamed lc_2019sgu_cleaned.png to 2019sgu.png
# Renamed lc_2019sgv_cleaned.png to 2019sgv.png
# Renamed lc_2019sho_cleaned.png to 2019sho.png
# Renamed lc_2019sic_cleaned.png to 2019sic.png
# Renamed lc_2019sig_cleaned.png to 2019sig.png
# Renamed lc_2019sih_cleaned.png to 2019sih.png
# Renamed lc_2019sij_cleaned.png to 2019sij.png
# Renamed lc_2019skg_cleaned.png to 2019skg.png
# Renamed lc_2019skx_cleaned.png to 2019skx.png
# Renamed lc_2019sld_cleaned.png to 2019sld.png
# Renamed lc_2019slh_cleaned.png to 2019slh.png
# Renamed lc_2019slj_cleaned.png to 2019slj.png
# Renamed lc_2019slp_cleaned.png to 2019slp.png
# Renamed lc_2019slt_cleaned.png to 2019slt.png
# Renamed lc_2019sme_cleaned.png to 2019sme.png
# Renamed lc_2019smf_cleaned.png to 2019smf.png
# Renamed lc_2019snw_cleaned.png to 2019snw.png
# Renamed lc_2019soh_cleaned.png to 2019soh.png
# Renamed lc_2019soi_cleaned.png to 2019soi.png
# Renamed lc_2019soj_cleaned.png to 2019soj.png
# Renamed lc_2019sop_cleaned.png to 2019sop.png
# Renamed lc_2019sos_cleaned.png to 2019sos.png
# Renamed lc_2019spn_cleaned.png to 2019spn.png
# Renamed lc_2019sqf_cleaned.png to 2019sqf.png
# Renamed lc_2019sqj_cleaned.png to 2019sqj.png
# Renamed lc_2019sqk_cleaned.png to 2019sqk.png
# Renamed lc_2019sql_cleaned.png to 2019sql.png
# Renamed lc_2019sqm_cleaned.png to 2019sqm.png
# Renamed lc_2019sqn_cleaned.png to 2019sqn.png
# Renamed lc_2019sqo_cleaned.png to 2019sqo.png
# Renamed lc_2019src_cleaned.png to 2019src.png
# Renamed lc_2019sse_cleaned.png to 2019sse.png
# Renamed lc_2019ssx_cleaned.png to 2019ssx.png
# Renamed lc_2019sta_cleaned.png to 2019sta.png
# Renamed lc_2019stj_cleaned.png to 2019stj.png
# Renamed lc_2019stn_cleaned.png to 2019stn.png
# Renamed lc_2019str_cleaned.png to 2019str.png
# Renamed lc_2019sts_cleaned.png to 2019sts.png
# Renamed lc_2019svm_cleaned.png to 2019svm.png
# Renamed lc_2019swx_cleaned.png to 2019swx.png
# Renamed lc_2019swy_cleaned.png to 2019swy.png
# Renamed lc_2019sxa_cleaned.png to 2019sxa.png
# Renamed lc_2019sxb_cleaned.png to 2019sxb.png
# Renamed lc_2019sxc_cleaned.png to 2019sxc.png
# Renamed lc_2019sxe_cleaned.png to 2019sxe.png
# Renamed lc_2019sxq_cleaned.png to 2019sxq.png
# Renamed lc_2019syl_cleaned.png to 2019syl.png
# Renamed lc_2019tac_cleaned.png to 2019tac.png
# Renamed lc_2019tae_cleaned.png to 2019tae.png
# Renamed lc_2019tat_cleaned.png to 2019tat.png
# Renamed lc_2019tbg_cleaned.png to 2019tbg.png
# Renamed lc_2019tdi_cleaned.png to 2019tdi.png
# Renamed lc_2019tfa_cleaned.png to 2019tfa.png
# Renamed lc_2019tfd_cleaned.png to 2019tfd.png
# Renamed lc_2019tfu_cleaned.png to 2019tfu.png
# Renamed lc_2019tgj_cleaned.png to 2019tgj.png
# Renamed lc_2019thj_cleaned.png to 2019thj.png
# Renamed lc_2019thz_cleaned.png to 2019thz.png
# Renamed lc_2019til_cleaned.png to 2019til.png
# Renamed lc_2019tjl_cleaned.png to 2019tjl.png
# Renamed lc_2019tjs_cleaned.png to 2019tjs.png
# Renamed lc_2019tjt_cleaned.png to 2019tjt.png
# Renamed lc_2019tju_cleaned.png to 2019tju.png
# Renamed lc_2019tjw_cleaned.png to 2019tjw.png
# Renamed lc_2019tjx_cleaned.png to 2019tjx.png
# Renamed lc_2019tjz_cleaned.png to 2019tjz.png
# Renamed lc_2019tka_cleaned.png to 2019tka.png
# Renamed lc_2019tlo_cleaned.png to 2019tlo.png
# Renamed lc_2019tlp_cleaned.png to 2019tlp.png
# Renamed lc_2019tlu_cleaned.png to 2019tlu.png
# Renamed lc_2019tmw_cleaned.png to 2019tmw.png
# Renamed lc_2019tnf_cleaned.png to 2019tnf.png
# Renamed lc_2019tng_cleaned.png to 2019tng.png
# Renamed lc_2019tov_cleaned.png to 2019tov.png
# Renamed lc_2019tq_cleaned.png to 2019tq.png
# Renamed lc_2019trl_cleaned.png to 2019trl.png
# Renamed lc_2019tsc_cleaned.png to 2019tsc.png
# Renamed lc_2019tsm_cleaned.png to 2019tsm.png
# Renamed lc_2019tsq_cleaned.png to 2019tsq.png
# Renamed lc_2019tsu_cleaned.png to 2019tsu.png
# Renamed lc_2019tsv_cleaned.png to 2019tsv.png
# Renamed lc_2019tsw_cleaned.png to 2019tsw.png
# Renamed lc_2019tsx_cleaned.png to 2019tsx.png
# Renamed lc_2019tsy_cleaned.png to 2019tsy.png
# Renamed lc_2019tsz_cleaned.png to 2019tsz.png
# Renamed lc_2019tta_cleaned.png to 2019tta.png
# Renamed lc_2019tum_cleaned.png to 2019tum.png
# Renamed lc_2019tvu_cleaned.png to 2019tvu.png
# Renamed lc_2019tyu_cleaned.png to 2019tyu.png
# Renamed lc_2019uag_cleaned.png to 2019uag.png
# Renamed lc_2019uaj_cleaned.png to 2019uaj.png
# Renamed lc_2019ubd_cleaned.png to 2019ubd.png
# Renamed lc_2019ubf_cleaned.png to 2019ubf.png
# Renamed lc_2019ubi_cleaned.png to 2019ubi.png
# Renamed lc_2019uca_cleaned.png to 2019uca.png
# Renamed lc_2019udl_cleaned.png to 2019udl.png
# Renamed lc_2019udn_cleaned.png to 2019udn.png
# Renamed lc_2019uem_cleaned.png to 2019uem.png
# Renamed lc_2019uen_cleaned.png to 2019uen.png
# Renamed lc_2019ufu_cleaned.png to 2019ufu.png
# Renamed lc_2019ufy_cleaned.png to 2019ufy.png
# Renamed lc_2019ufz_cleaned.png to 2019ufz.png
# Renamed lc_2019ugb_cleaned.png to 2019ugb.png
# Renamed lc_2019uge_cleaned.png to 2019uge.png
# Renamed lc_2019ugr_cleaned.png to 2019ugr.png
# Renamed lc_2019ugy_cleaned.png to 2019ugy.png
# Renamed lc_2019ugz_cleaned.png to 2019ugz.png
# Renamed lc_2019uje_cleaned.png to 2019uje.png
# Renamed lc_2019ujq_cleaned.png to 2019ujq.png
# Renamed lc_2019ujt_cleaned.png to 2019ujt.png
# Renamed lc_2019ujw_cleaned.png to 2019ujw.png
# Renamed lc_2019ukb_cleaned.png to 2019ukb.png
# Renamed lc_2019ukd_cleaned.png to 2019ukd.png
# Renamed lc_2019ukv_cleaned.png to 2019ukv.png
# Renamed lc_2019ule_cleaned.png to 2019ule.png
# Renamed lc_2019ulr_cleaned.png to 2019ulr.png
# Renamed lc_2019ulr_detrended_cleaned.png to 2019ulr_detrended.png
# Renamed lc_2019ulv_cleaned.png to 2019ulv.png
# Renamed lc_2019ulw_cleaned.png to 2019ulw.png
# Renamed lc_2019umq_cleaned.png to 2019umq.png
# Renamed lc_2019unq_cleaned.png to 2019unq.png
# Renamed lc_2019uwj_cleaned.png to 2019uwj.png
# Renamed lc_2019uwk_cleaned.png to 2019uwk.png
# Renamed lc_2019uyn_cleaned.png to 2019uyn.png
# Renamed lc_2019uyr_cleaned.png to 2019uyr.png
# Renamed lc_2019val_cleaned.png to 2019val.png
# Renamed lc_2019vbi_cleaned.png to 2019vbi.png
# Renamed lc_2019vbj_cleaned.png to 2019vbj.png
# Renamed lc_2019vby_cleaned.png to 2019vby.png
# Renamed lc_2019vcz_cleaned.png to 2019vcz.png
# Renamed lc_2019vda_cleaned.png to 2019vda.png
# Renamed lc_2019vde_cleaned.png to 2019vde.png
# Renamed lc_2019vjv_cleaned.png to 2019vjv.png
# Renamed lc_2019vkn_cleaned.png to 2019vkn.png
# Renamed lc_2019vli_cleaned.png to 2019vli.png
# Renamed lc_2019vlt_cleaned.png to 2019vlt.png
# Renamed lc_2019vlu_cleaned.png to 2019vlu.png
# Renamed lc_2019vma_cleaned.png to 2019vma.png
# Renamed lc_2019vmb_cleaned.png to 2019vmb.png
# Renamed lc_2019vmc_cleaned.png to 2019vmc.png
# Renamed lc_2019vmm_cleaned.png to 2019vmm.png
# Renamed lc_2019vrh_cleaned.png to 2019vrh.png
# Renamed lc_2019vuj_cleaned.png to 2019vuj.png
# Renamed lc_2019vyb_cleaned.png to 2019vyb.png
# Renamed lc_2019vyf_cleaned.png to 2019vyf.png
# Renamed lc_2019vyj_cleaned.png to 2019vyj.png
# Renamed lc_2019vyk_cleaned.png to 2019vyk.png
# Renamed lc_2019vzi_cleaned.png to 2019vzi.png
# Renamed lc_2019vzv_cleaned.png to 2019vzv.png
# Renamed lc_2019vzx_cleaned.png to 2019vzx.png
# Renamed lc_2019vzy_cleaned.png to 2019vzy.png
# Renamed lc_2019wbk_cleaned.png to 2019wbk.png
# Renamed lc_2019wbl_cleaned.png to 2019wbl.png
# Renamed lc_2019wbo_cleaned.png to 2019wbo.png
# Renamed lc_2019wbr_cleaned.png to 2019wbr.png
# Renamed lc_2019wey_cleaned.png to 2019wey.png
# Renamed lc_2019whd_cleaned.png to 2019whd.png
# Renamed lc_2019wim_cleaned.png to 2019wim.png
# Renamed lc_2019wio_cleaned.png to 2019wio.png
# Renamed lc_2019wjj_cleaned.png to 2019wjj.png
# Renamed lc_2019wjl_cleaned.png to 2019wjl.png
# Renamed lc_2019wkz_cleaned.png to 2019wkz.png
# Renamed lc_2019wla_cleaned.png to 2019wla.png
# Renamed lc_2019wle_cleaned.png to 2019wle.png
# Renamed lc_2019wmw_cleaned.png to 2019wmw.png
# Renamed lc_2019wnu_cleaned.png to 2019wnu.png
# Renamed lc_2019wrr_cleaned.png to 2019wrr.png
# Renamed lc_2019wuu_cleaned.png to 2019wuu.png
# Renamed lc_2019wve_cleaned.png to 2019wve.png
# Renamed lc_2019wvo_cleaned.png to 2019wvo.png
# Renamed lc_2019wwo_cleaned.png to 2019wwo.png
# Renamed lc_2019wxp_cleaned.png to 2019wxp.png
# Renamed lc_2019wz_cleaned.png to 2019wz.png
# Renamed lc_2019xao_cleaned.png to 2019xao.png
# Renamed lc_2019xaq_cleaned.png to 2019xaq.png
# Renamed lc_2019xar_cleaned.png to 2019xar.png
# Renamed lc_2019xcn_cleaned.png to 2019xcn.png
# Renamed lc_2019xdl_cleaned.png to 2019xdl.png
# Renamed lc_2019xe_cleaned.png to 2019xe.png
# Renamed lc_2019xhk_cleaned.png to 2019xhk.png
# Renamed lc_2019xip_cleaned.png to 2019xip.png
# Renamed lc_2019xtf_cleaned.png to 2019xtf.png
# Renamed lc_2019xuk_cleaned.png to 2019xuk.png
# Renamed lc_2019xul_cleaned.png to 2019xul.png
# Renamed lc_2019xvs_cleaned.png to 2019xvs.png
# Renamed lc_2019yek_cleaned.png to 2019yek.png
# Renamed lc_2019yel_cleaned.png to 2019yel.png
# Renamed lc_2019yxj_cleaned.png to 2019yxj.png
# Renamed lc_2019yyw_cleaned.png to 2019yyw.png
# Renamed lc_2019zag_cleaned.png to 2019zag.png
# Renamed lc_2019zam_cleaned.png to 2019zam.png
# Renamed lc_2019zdo_cleaned.png to 2019zdo.png
# Renamed lc_2019zei_cleaned.png to 2019zei.png
# Renamed lc_2019zej_cleaned.png to 2019zej.png
# Renamed lc_2019zem_cleaned.png to 2019zem.png
# Renamed lc_2019zen_cleaned.png to 2019zen.png
# Renamed lc_2019zep_cleaned.png to 2019zep.png
# Renamed lc_2019zes_cleaned.png to 2019zes.png
# Renamed lc_2019zhj_cleaned.png to 2019zhj.png
# Renamed lc_2019zhm_cleaned.png to 2019zhm.png
# Renamed lc_2019zrd_cleaned.png to 2019zrd.png
# Renamed lc_2019zsi_cleaned.png to 2019zsi.png
# Renamed lc_2020aaab_cleaned.png to 2020aaab.png
# Renamed lc_2020aaaj_cleaned.png to 2020aaaj.png
# Renamed lc_2020aaap_cleaned.png to 2020aaap.png
# Renamed lc_2020aacy_cleaned.png to 2020aacy.png
# Renamed lc_2020aafo_cleaned.png to 2020aafo.png
# Renamed lc_2020aagz_cleaned.png to 2020aagz.png
# Renamed lc_2020aahq_cleaned.png to 2020aahq.png
# Renamed lc_2020aajf_cleaned.png to 2020aajf.png
# Renamed lc_2020aajq_cleaned.png to 2020aajq.png
# Renamed lc_2020aalz_cleaned.png to 2020aalz.png
# Renamed lc_2020aame_cleaned.png to 2020aame.png
# Renamed lc_2020aami_cleaned.png to 2020aami.png
# Renamed lc_2020aamu_cleaned.png to 2020aamu.png
# Renamed lc_2020aanf_cleaned.png to 2020aanf.png
# Renamed lc_2020aanv_cleaned.png to 2020aanv.png
# Renamed lc_2020aany_cleaned.png to 2020aany.png
# Renamed lc_2020aan_cleaned.png to 2020aan.png
# Renamed lc_2020aaog_cleaned.png to 2020aaog.png
# Renamed lc_2020aao_cleaned.png to 2020aao.png
# Renamed lc_2020aaqm_cleaned.png to 2020aaqm.png
# Renamed lc_2020aaqu_cleaned.png to 2020aaqu.png
# Renamed lc_2020aarw_cleaned.png to 2020aarw.png
# Renamed lc_2020aarz_cleaned.png to 2020aarz.png
# Renamed lc_2020aatb_cleaned.png to 2020aatb.png
# Renamed lc_2020aauh_cleaned.png to 2020aauh.png
# Renamed lc_2020aavd_cleaned.png to 2020aavd.png
# Renamed lc_2020aawh_cleaned.png to 2020aawh.png
# Renamed lc_2020aawi_cleaned.png to 2020aawi.png
# Renamed lc_2020aawj_cleaned.png to 2020aawj.png
# Renamed lc_2020aayb_cleaned.png to 2020aayb.png
# Renamed lc_2020aayc_cleaned.png to 2020aayc.png
# Renamed lc_2020aaye_cleaned.png to 2020aaye.png
# Renamed lc_2020aayk_cleaned.png to 2020aayk.png
# Renamed lc_2020aayr_cleaned.png to 2020aayr.png
# Renamed lc_2020aayt_cleaned.png to 2020aayt.png
# Renamed lc_2020aayv_cleaned.png to 2020aayv.png
# Renamed lc_2020aayy_cleaned.png to 2020aayy.png
# Renamed lc_2020abbx_cleaned.png to 2020abbx.png
# Renamed lc_2020abcd_cleaned.png to 2020abcd.png
# Renamed lc_2020abcr_cleaned.png to 2020abcr.png
# Renamed lc_2020abdk_cleaned.png to 2020abdk.png
# Renamed lc_2020abdk_detrended.png to 2020abdk_detrended.png
# Skipped renaming lc_2020abdk_detrended_cleaned.png. 2020abdk_detrended.png already exists.
# Renamed lc_2020abdu_cleaned.png to 2020abdu.png
# Renamed lc_2020abez_cleaned.png to 2020abez.png
# Renamed lc_2020abfn_cleaned.png to 2020abfn.png
# Renamed lc_2020abfo_cleaned.png to 2020abfo.png
# Renamed lc_2020abfw_cleaned.png to 2020abfw.png
# Renamed lc_2020abgz_cleaned.png to 2020abgz.png
# Renamed lc_2020abjj_cleaned.png to 2020abjj.png
# Renamed lc_2020abjl_cleaned.png to 2020abjl.png
# Renamed lc_2020abky_cleaned.png to 2020abky.png
# Renamed lc_2020ablu_cleaned.png to 2020ablu.png
# Renamed lc_2020abof_cleaned.png to 2020abof.png
# Renamed lc_2020abqs_cleaned.png to 2020abqs.png
# Renamed lc_2020abqu_cleaned.png to 2020abqu.png
# Renamed lc_2020abqy_cleaned.png to 2020abqy.png
# Renamed lc_2020abq_cleaned.png to 2020abq.png
# Renamed lc_2020abrp_cleaned.png to 2020abrp.png
# Renamed lc_2020absm_cleaned.png to 2020absm.png
# Renamed lc_2020abtd_cleaned.png to 2020abtd.png
# Renamed lc_2020abuo_cleaned.png to 2020abuo.png
# Renamed lc_2020abvc_cleaned.png to 2020abvc.png
# Renamed lc_2020abvn_cleaned.png to 2020abvn.png
# Renamed lc_2020abvz_cleaned.png to 2020abvz.png
# Renamed lc_2020abwb_cleaned.png to 2020abwb.png
# Renamed lc_2020abwn_cleaned.png to 2020abwn.png
# Renamed lc_2020abwr_cleaned.png to 2020abwr.png
# Renamed lc_2020abwu_cleaned.png to 2020abwu.png
# Renamed lc_2020abxa_cleaned.png to 2020abxa.png
# Renamed lc_2020abxj_cleaned.png to 2020abxj.png
# Renamed lc_2020abxl_cleaned.png to 2020abxl.png
# Renamed lc_2020abxn_cleaned.png to 2020abxn.png
# Renamed lc_2020abxo_cleaned.png to 2020abxo.png
# Renamed lc_2020acaa_cleaned.png to 2020acaa.png
# Renamed lc_2020acaj_cleaned.png to 2020acaj.png
# Renamed lc_2020acaw_cleaned.png to 2020acaw.png
# Renamed lc_2020acax_cleaned.png to 2020acax.png
# Renamed lc_2020acay_cleaned.png to 2020acay.png
# Renamed lc_2020acba_cleaned.png to 2020acba.png
# Renamed lc_2020acbc_cleaned.png to 2020acbc.png
# Renamed lc_2020acbf_cleaned.png to 2020acbf.png
# Renamed lc_2020acbp_cleaned.png to 2020acbp.png
# Renamed lc_2020accy_cleaned.png to 2020accy.png
# Renamed lc_2020accz_cleaned.png to 2020accz.png
# Renamed lc_2020acdk_cleaned.png to 2020acdk.png
# Renamed lc_2020acds_cleaned.png to 2020acds.png
# Renamed lc_2020acgb_cleaned.png to 2020acgb.png
# Renamed lc_2020acgc_cleaned.png to 2020acgc.png
# Renamed lc_2020acgd_cleaned.png to 2020acgd.png
# Renamed lc_2020acge_cleaned.png to 2020acge.png
# Renamed lc_2020acgf_cleaned.png to 2020acgf.png
# Renamed lc_2020acgi_cleaned.png to 2020acgi.png
# Renamed lc_2020achi_cleaned.png to 2020achi.png
# Renamed lc_2020achk_cleaned.png to 2020achk.png
# Renamed lc_2020aclq_cleaned.png to 2020aclq.png
# Renamed lc_2020acls_cleaned.png to 2020acls.png
# Renamed lc_2020aclz_cleaned.png to 2020aclz.png
# Renamed lc_2020acmr_cleaned.png to 2020acmr.png
# Renamed lc_2020acna_cleaned.png to 2020acna.png
# Renamed lc_2020acnj_cleaned.png to 2020acnj.png
# Renamed lc_2020acpo_cleaned.png to 2020acpo.png
# Renamed lc_2020acpu_cleaned.png to 2020acpu.png
# Renamed lc_2020acpv_cleaned.png to 2020acpv.png
# Renamed lc_2020acqf_cleaned.png to 2020acqf.png
# Renamed lc_2020acrs_cleaned.png to 2020acrs.png
# Renamed lc_2020acrz_cleaned.png to 2020acrz.png
# Renamed lc_2020acxg_cleaned.png to 2020acxg.png
# Renamed lc_2020acxt_cleaned.png to 2020acxt.png
# Renamed lc_2020acya_cleaned.png to 2020acya.png
# Renamed lc_2020aczd_cleaned.png to 2020aczd.png
# Renamed lc_2020adbn_cleaned.png to 2020adbn.png
# Renamed lc_2020adbq_cleaned.png to 2020adbq.png
# Renamed lc_2020adbx_cleaned.png to 2020adbx.png
# Renamed lc_2020adch_cleaned.png to 2020adch.png
# Renamed lc_2020adda_cleaned.png to 2020adda.png
# Renamed lc_2020addg_cleaned.png to 2020addg.png
# Renamed lc_2020adeh_cleaned.png to 2020adeh.png
# Renamed lc_2020adff_cleaned.png to 2020adff.png
# Renamed lc_2020adfz_cleaned.png to 2020adfz.png
# Renamed lc_2020adgf_cleaned.png to 2020adgf.png
# Renamed lc_2020adgj_cleaned.png to 2020adgj.png
# Renamed lc_2020adgm_cleaned.png to 2020adgm.png
# Renamed lc_2020adgq_cleaned.png to 2020adgq.png
# Renamed lc_2020adgv_cleaned.png to 2020adgv.png
# Renamed lc_2020adim_cleaned.png to 2020adim.png
# Renamed lc_2020adiw_cleaned.png to 2020adiw.png
# Renamed lc_2020adjd_cleaned.png to 2020adjd.png
# Renamed lc_2020adkj_cleaned.png to 2020adkj.png
# Renamed lc_2020adkk_cleaned.png to 2020adkk.png
# Renamed lc_2020adkr_cleaned.png to 2020adkr.png
# Renamed lc_2020adky_cleaned.png to 2020adky.png
# Renamed lc_2020adlb_cleaned.png to 2020adlb.png
# Renamed lc_2020adlc_cleaned.png to 2020adcleaned.png
# Renamed lc_2020adle_cleaned.png to 2020adle.png
# Renamed lc_2020adlw_cleaned.png to 2020adlw.png
# Renamed lc_2020adlx_cleaned.png to 2020adlx.png
# Renamed lc_2020adnk_cleaned.png to 2020adnk.png
# Renamed lc_2020adnv_cleaned.png to 2020adnv.png
# Renamed lc_2020adoj_cleaned.png to 2020adoj.png
# Renamed lc_2020adox_cleaned.png to 2020adox.png
# Renamed lc_2020adpr_cleaned.png to 2020adpr.png
# Renamed lc_2020adsj_cleaned.png to 2020adsj.png
# Renamed lc_2020adsx_cleaned.png to 2020adsx.png
# Renamed lc_2020adth_cleaned.png to 2020adth.png
# Renamed lc_2020adtr_cleaned.png to 2020adtr.png
# Renamed lc_2020advu_cleaned.png to 2020advu.png
# Renamed lc_2020adwr_cleaned.png to 2020adwr.png
# Renamed lc_2020adww_cleaned.png to 2020adww.png
# Renamed lc_2020adw_cleaned.png to 2020adw.png
# Renamed lc_2020adyh_cleaned.png to 2020adyh.png
# Renamed lc_2020adyt_cleaned.png to 2020adyt.png
# Renamed lc_2020adyz_cleaned.png to 2020adyz.png
# Renamed lc_2020aeat_cleaned.png to 2020aeat.png
# Renamed lc_2020aeax_cleaned.png to 2020aeax.png
# Renamed lc_2020aeay_cleaned.png to 2020aeay.png
# Renamed lc_2020aebg_cleaned.png to 2020aebg.png
# Renamed lc_2020aecm_cleaned.png to 2020aecm.png
# Renamed lc_2020aecz_cleaned.png to 2020aecz.png
# Renamed lc_2020aedd_cleaned.png to 2020aedd.png
# Renamed lc_2020aedr_cleaned.png to 2020aedr.png
# Renamed lc_2020aedv_cleaned.png to 2020aedv.png
# Renamed lc_2020aedx_cleaned.png to 2020aedx.png
# Renamed lc_2020aeed_cleaned.png to 2020aeed.png
# Renamed lc_2020aeee_cleaned.png to 2020aeee.png
# Renamed lc_2020aeel_cleaned.png to 2020aeel.png
# Renamed lc_2020aeeq_cleaned.png to 2020aeeq.png
# Renamed lc_2020aeey_cleaned.png to 2020aeey.png
# Renamed lc_2020aefd_cleaned.png to 2020aefd.png
# Renamed lc_2020aefg_cleaned.png to 2020aefg.png
# Renamed lc_2020aefr_cleaned.png to 2020aefr.png
# Renamed lc_2020aefv_cleaned.png to 2020aefv.png
# Renamed lc_2020aegb_cleaned.png to 2020aegb.png
# Renamed lc_2020aegs_cleaned.png to 2020aegs.png
# Renamed lc_2020aegx_cleaned.png to 2020aegx.png
# Renamed lc_2020aehe_cleaned.png to 2020aehe.png
# Renamed lc_2020aehp_cleaned.png to 2020aehp.png
# Renamed lc_2020aehr_cleaned.png to 2020aehr.png
# Renamed lc_2020aehv_cleaned.png to 2020aehv.png
# Renamed lc_2020aehy_cleaned.png to 2020aehy.png
# Renamed lc_2020aein_cleaned.png to 2020aein.png
# Renamed lc_2020aeio_cleaned.png to 2020aeio.png
# ...
# Renamed lc_2022zxn_cleaned.png to 2022zxn.png
# Renamed lc_2022zxo_cleaned.png to 2022zxo.png
# Renamed lc_2022zxw_cleaned.png to 2022zxw.png
# Renamed lc_2022zyd_cleaned.png to 2022zyd.png
# Renamed lc_2022zyh_cleaned.png to 2022zyh.png
# Renamed lc_2022zyo_cleaned.png to 2022zyo.png
# Renamed lc_2022zyu_cleaned.png to 2022zyu.png
# Renamed lc_2022zzx_cleaned.png to 2022zzx.png
# Renamed lc_2023aan_cleaned.png to 2023aan.png
# Renamed lc_2023aar_cleaned.png to 2023aar.png
# Renamed lc_2023adh_cleaned.png to 2023adh.png
# Renamed lc_2023aed_cleaned.png to 2023aed.png
# Renamed lc_2023aeh_cleaned.png to 2023aeh.png
# Renamed lc_2023aej_cleaned.png to 2023aej.png
# Renamed lc_2023ahn_cleaned.png to 2023ahn.png
# Renamed lc_2023aho_cleaned.png to 2023aho.png
# Renamed lc_2023aic_cleaned.png to 2023aic.png
# Renamed lc_2023aii_cleaned.png to 2023aii.png
# Renamed lc_2023aij_cleaned.png to 2023aij.png
# Renamed lc_2023ail_cleaned.png to 2023ail.png
# Renamed lc_2023air_cleaned.png to 2023air.png
# Renamed lc_2023akj_cleaned.png to 2023akj.png
# Renamed lc_2023alt_cleaned.png to 2023alt.png
# Renamed lc_2023alw_cleaned.png to 2023alw.png
# Renamed lc_2023ams_cleaned.png to 2023ams.png
# Renamed lc_2023amt_cleaned.png to 2023amt.png
# Renamed lc_2023amw_cleaned.png to 2023amw.png
# Renamed lc_2023anc_cleaned.png to 2023anc.png
# Renamed lc_2023anj_cleaned.png to 2023anj.png
# Renamed lc_2023anm_cleaned.png to 2023anm.png
# Renamed lc_2023ann_cleaned.png to 2023ann.png
# Renamed lc_2023anw_cleaned.png to 2023anw.png
# Renamed lc_2023aob_cleaned.png to 2023aob.png
# Renamed lc_2023aoi_cleaned.png to 2023aoi.png
# Renamed lc_2023aot_cleaned.png to 2023aot.png
# Renamed lc_2023aoz_cleaned.png to 2023aoz.png
# Renamed lc_2023apz_cleaned.png to 2023apz.png
# Renamed lc_2023arx_cleaned.png to 2023arx.png
# Renamed lc_2023ato_cleaned.png to 2023ato.png
# Renamed lc_2023atp_cleaned.png to 2023atp.png
# Renamed lc_2023aty_cleaned.png to 2023aty.png
# Renamed lc_2023atz_cleaned.png to 2023atz.png
# Renamed lc_2023auh_cleaned.png to 2023auh.png
# Renamed lc_2023auu_cleaned.png to 2023auu.png
# Renamed lc_2023ave_cleaned.png to 2023ave.png
# Renamed lc_2023avw_cleaned.png to 2023avw.png
# Renamed lc_2023axa_cleaned.png to 2023axa.png
# Renamed lc_2023axc_cleaned.png to 2023axc.png
# Renamed lc_2023baz_cleaned.png to 2023baz.png
# Renamed lc_2023bba_cleaned.png to 2023bba.png
# Renamed lc_2023bbi_cleaned.png to 2023bbi.png
# Renamed lc_2023bbt_cleaned.png to 2023bbt.png
# Renamed lc_2023bee_cleaned.png to 2023bee.png
# Renamed lc_2023bgq_cleaned.png to 2023bgq.png
# Renamed lc_2023bgt_cleaned.png to 2023bgt.png
# Renamed lc_2023bhp_cleaned.png to 2023bhp.png
# Renamed lc_2023bjr_cleaned.png to 2023bjr.png
# Renamed lc_2023bju_cleaned.png to 2023bju.png
# Renamed lc_2023bjv_cleaned.png to 2023bjv.png
# Renamed lc_2023blo_cleaned.png to 2023blo.png
# Renamed lc_2023blv_cleaned.png to 2023blv.png
# Renamed lc_2023bmf_cleaned.png to 2023bmf.png
# Renamed lc_2023bms_cleaned.png to 2023bms.png
# Renamed lc_2023bod_cleaned.png to 2023bod.png
# Renamed lc_2023boh_cleaned.png to 2023boh.png
# Renamed lc_2023bov_cleaned.png to 2023bov.png
# Renamed lc_2023bpc_cleaned.png to 2023bpc.png
# Renamed lc_2023bqj_cleaned.png to 2023bqj.png
# Renamed lc_2023bqn_cleaned.png to 2023bqn.png
# Renamed lc_2023bqp_cleaned.png to 2023bqp.png
# Renamed lc_2023bqr_cleaned.png to 2023bqr.png
# Renamed lc_2023bqv_cleaned.png to 2023bqv.png
# Renamed lc_2023bqz_cleaned.png to 2023bqz.png
# Renamed lc_2023bre_cleaned.png to 2023bre.png
# Renamed lc_2023bsd_cleaned.png to 2023bsd.png
# Renamed lc_2023bsr_cleaned.png to 2023bsr.png
# Renamed lc_2023bs_cleaned.png to 2023bs.png
# Renamed lc_2023btp_cleaned.png to 2023btp.png
# Renamed lc_2023btu_cleaned.png to 2023btu.png
# Renamed lc_2023bue_cleaned.png to 2023bue.png
# Renamed lc_2023buh_cleaned.png to 2023buh.png
# Renamed lc_2023bui_cleaned.png to 2023bui.png
# Renamed lc_2023buj_cleaned.png to 2023buj.png
# Renamed lc_2023bur_cleaned.png to 2023bur.png
# Renamed lc_2023bus_cleaned.png to 2023bus.png
# Renamed lc_2023bux_cleaned.png to 2023bux.png
# Renamed lc_2023bwv_cleaned.png to 2023bwv.png
# Renamed lc_2023bwx_cleaned.png to 2023bwx.png
# Renamed lc_2023bxf_cleaned.png to 2023bxf.png
# Renamed lc_2023bxq_cleaned.png to 2023bxq.png
# Renamed lc_2023bxt_cleaned.png to 2023bxt.png
# Renamed lc_2023bys_cleaned.png to 2023bys.png
# Renamed lc_2023bzw_cleaned.png to 2023bzw.png
# Renamed lc_2023caa_cleaned.png to 2023caa.png
# Renamed lc_2023cbn_cleaned.png to 2023cbn.png
# Renamed lc_2023cbr_cleaned.png to 2023cbr.png
# Renamed lc_2023ccg_cleaned.png to 2023ccg.png
# Renamed lc_2023ccu_cleaned.png to 2023ccu.png
# Renamed lc_2023cdd_cleaned.png to 2023cdd.png
# Renamed lc_2023cew_cleaned.png to 2023cew.png
# Renamed lc_2023cgi_cleaned.png to 2023cgi.png
# Renamed lc_2023cgk_cleaned.png to 2023cgk.png
# Renamed lc_2023chu_cleaned.png to 2023chu.png
# Renamed lc_2023chv_cleaned.png to 2023chv.png
# Renamed lc_2023cjf_cleaned.png to 2023cjf.png
# Renamed lc_2023cjj_cleaned.png to 2023cjj.png
# Renamed lc_2023cjm_cleaned.png to 2023cjm.png
# Renamed lc_2023cku_cleaned.png to 2023cku.png
# Renamed lc_2023cli_cleaned.png to 2023cli.png
# Renamed lc_2023cll_cleaned.png to 2023cll.png
# Renamed lc_2023clz_cleaned.png to 2023clz.png
# Renamed lc_2023cna_cleaned.png to 2023cna.png
# Renamed lc_2023cnm_cleaned.png to 2023cnm.png
# Renamed lc_2023coa_cleaned.png to 2023coa.png
# Renamed lc_2023cod_cleaned.png to 2023cod.png
# Renamed lc_2023cor_cleaned.png to 2023cor.png
# Renamed lc_2023cow_cleaned.png to 2023cow.png
# Renamed lc_2023crz_cleaned.png to 2023crz.png
# Renamed lc_2023csc_cleaned.png to 2023csc.png
# Renamed lc_2023cum_cleaned.png to 2023cum.png
# Renamed lc_2023cvk_cleaned.png to 2023cvk.png
# Renamed lc_2023cwy_cleaned.png to 2023cwy.png
# Renamed lc_2023cwz_cleaned.png to 2023cwz.png
# Renamed lc_2023cxc_cleaned.png to 2023cxc.png
# Renamed lc_2023cxd_cleaned.png to 2023cxd.png
# Renamed lc_2023cxg_cleaned.png to 2023cxg.png
# Renamed lc_2023cyf_cleaned.png to 2023cyf.png
# Renamed lc_2023cyi_cleaned.png to 2023cyi.png
# Renamed lc_2023dbj_cleaned.png to 2023dbj.png
# Renamed lc_2023ddy_cleaned.png to 2023ddy.png
# Renamed lc_2023dep_cleaned.png to 2023dep.png
# Renamed lc_2023deq_cleaned.png to 2023deq.png
# Renamed lc_2023dfb_cleaned.png to 2023dfb.png
# Renamed lc_2023dfr_cleaned.png to 2023dfr.png
# Renamed lc_2023dfx_cleaned.png to 2023dfx.png
# Renamed lc_2023dfz_cleaned.png to 2023dfz.png
# Renamed lc_2023dma_cleaned.png to 2023dma.png
# Renamed lc_2023dov_cleaned.png to 2023dov.png
# Renamed lc_2023dox_cleaned.png to 2023dox.png
# Renamed lc_2023dpq_cleaned.png to 2023dpq.png
# Renamed lc_2023dpu_cleaned.png to 2023dpu.png
# Renamed lc_2023dpz_cleaned.png to 2023dpz.png
# Renamed lc_2023dqd_cleaned.png to 2023dqd.png
# Renamed lc_2023dqh_cleaned.png to 2023dqh.png
# Renamed lc_2023dst_cleaned.png to 2023dst.png
# Renamed lc_2023duc_cleaned.png to 2023duc.png
# Renamed lc_2023dug_cleaned.png to 2023dug.png
# Renamed lc_2023dup_cleaned.png to 2023dup.png
# Renamed lc_2023dva_cleaned.png to 2023dva.png
# Renamed lc_2023dvj_cleaned.png to 2023dvj.png
# Renamed lc_2023dvq_cleaned.png to 2023dvq.png
# Renamed lc_2023dvz_cleaned.png to 2023dvz.png
# Renamed lc_2023dwl_cleaned.png to 2023dwl.png
# Renamed lc_2023dze_cleaned.png to 2023dze.png
# Renamed lc_2023ebl_cleaned.png to 2023ebl.png
# Renamed lc_2023ebq_cleaned.png to 2023ebq.png
# Renamed lc_2023ecd_cleaned.png to 2023ecd.png
# Renamed lc_2023edf_cleaned.png to 2023edf.png
# Renamed lc_2023edn_cleaned.png to 2023edn.png
# Renamed lc_2023edo_cleaned.png to 2023edo.png
# Renamed lc_2023edy_cleaned.png to 2023edy.png
# Renamed lc_2023eez_cleaned.png to 2023eez.png
# Renamed lc_2023egc_cleaned.png to 2023egc.png
# Renamed lc_2023egh_cleaned.png to 2023egh.png
# Renamed lc_2023egk_cleaned.png to 2023egk.png
# Renamed lc_2023egm_cleaned.png to 2023egm.png
# Renamed lc_2023egu_cleaned.png to 2023egu.png
# Renamed lc_2023ejj_cleaned.png to 2023ejj.png
# Renamed lc_2023ejl_cleaned.png to 2023ejl.png
# Renamed lc_2023ejp_cleaned.png to 2023ejp.png
# Renamed lc_2023ejy_cleaned.png to 2023ejy.png
# Renamed lc_2023ekc_cleaned.png to 2023ekc.png
# Renamed lc_2023eke_cleaned.png to 2023eke.png
# Renamed lc_2023elb_cleaned.png to 2023elb.png
# Renamed lc_2023elj_cleaned.png to 2023elj.png
# Renamed lc_2023elo_cleaned.png to 2023elo.png
# Renamed lc_2023eow_cleaned.png to 2023eow.png
# Renamed lc_2023epl_cleaned.png to 2023epl.png
# Renamed lc_2023epw_cleaned.png to 2023epw.png
# Renamed lc_2023eqh_cleaned.png to 2023eqh.png
# Renamed lc_2023eqj_cleaned.png to 2023eqj.png
# Renamed lc_2023eua_cleaned.png to 2023eua.png
# Renamed lc_2023eux_cleaned.png to 2023eux.png
# Renamed lc_2023evi_cleaned.png to 2023evi.png
# Renamed lc_2023evx_cleaned.png to 2023evx.png
# Renamed lc_2023exr_cleaned.png to 2023exr.png
# Renamed lc_2023exz_cleaned.png to 2023exz.png
# Renamed lc_2023ezg_cleaned.png to 2023ezg.png
# Renamed lc_2023ezt_cleaned.png to 2023ezt.png
# Renamed lc_2023fak_cleaned.png to 2023fak.png
# Renamed lc_2023far_cleaned.png to 2023far.png
# Renamed lc_2023fat_cleaned.png to 2023fat.png
# Renamed lc_2023fbr_cleaned.png to 2023fbr.png
# Renamed lc_2023fcv_cleaned.png to 2023fcv.png
# Renamed lc_2023fda_cleaned.png to 2023fda.png
# Renamed lc_2023fdj_cleaned.png to 2023fdj.png
# Renamed lc_2023fel_cleaned.png to 2023fel.png
# Renamed lc_2023fep_cleaned.png to 2023fep.png
# Renamed lc_2023ffq_cleaned.png to 2023ffq.png
# Renamed lc_2023fhl_cleaned.png to 2023fhl.png
# Renamed lc_2023fit_cleaned.png to 2023fit.png
# Renamed lc_2023flj_cleaned.png to 2023flj.png
# Renamed lc_2023fls_cleaned.png to 2023fls.png
# Renamed lc_2023fol_cleaned.png to 2023fol.png
# Renamed lc_2023fpc_cleaned.png to 2023fpc.png
# Renamed lc_2023fpe_cleaned.png to 2023fpe.png
# Renamed lc_2023fpo_cleaned.png to 2023fpo.png
# Renamed lc_2023fpq_cleaned.png to 2023fpq.png
# Renamed lc_2023fqu_cleaned.png to 2023fqu.png
# Renamed lc_2023fqz_cleaned.png to 2023fqz.png
# Renamed lc_2023ftx_cleaned.png to 2023ftx.png
# Renamed lc_2023fty_cleaned.png to 2023fty.png
# Renamed lc_2023fua_cleaned.png to 2023fua.png
# Renamed lc_2023fud_cleaned.png to 2023fud.png
# Renamed lc_2023fuo_cleaned.png to 2023fuo.png
# Renamed lc_2023fut_cleaned.png to 2023fut.png
# Renamed lc_2023fvg_cleaned.png to 2023fvg.png
# Renamed lc_2023fx_cleaned.png to 2023fx.png
# Renamed lc_2023fzf_cleaned.png to 2023fzf.png
# Renamed lc_2023gas_cleaned.png to 2023gas.png
# Renamed lc_2023gcj_cleaned.png to 2023gcj.png
# Renamed lc_2023gdn_cleaned.png to 2023gdn.png
# Renamed lc_2023gdu_cleaned.png to 2023gdu.png
# Renamed lc_2023ghs_cleaned.png to 2023ghs.png
# Renamed lc_2023gim_cleaned.png to 2023gim.png
# Renamed lc_2023gio_cleaned.png to 2023gio.png
# Renamed lc_2023gjx_cleaned.png to 2023gjx.png
# Renamed lc_2023gjz_cleaned.png to 2023gjz.png
# Renamed lc_2023gj_cleaned.png to 2023gj.png
# Renamed lc_2023gns_cleaned.png to 2023gns.png
# Renamed lc_2023gnx_cleaned.png to 2023gnx.png
# Renamed lc_2023gos_cleaned.png to 2023gos.png
# Renamed lc_2023gpu_cleaned.png to 2023gpu.png
# Renamed lc_2023gp_cleaned.png to 2023gp.png
# Renamed lc_2023gr_cleaned.png to 2023gr.png
# Renamed lc_2023gsf_cleaned.png to 2023gsf.png
# Renamed lc_2023gsh_cleaned.png to 2023gsh.png
# Renamed lc_2023gsp_cleaned.png to 2023gsp.png
# Renamed lc_2023gss_cleaned.png to 2023gss.png
# Renamed lc_2023gs_cleaned.png to 2023gs.png
# Renamed lc_2023gtp_cleaned.png to 2023gtp.png
# Renamed lc_2023gtx_cleaned.png to 2023gtx.png
# Renamed lc_2023guj_cleaned.png to 2023guj.png
# Renamed lc_2023gup_cleaned.png to 2023gup.png
# Renamed lc_2023gu_cleaned.png to 2023gu.png
# Renamed lc_2023gwh_cleaned.png to 2023gwh.png
# Renamed lc_2023gxh_cleaned.png to 2023gxh.png
# Renamed lc_2023gx_cleaned.png to 2023gx.png
# Renamed lc_2023gza_cleaned.png to 2023gza.png
# Renamed lc_2023gzq_cleaned.png to 2023gzq.png
# Renamed lc_2023gzz_cleaned.png to 2023gzz.png
# Renamed lc_2023hac_cleaned.png to 2023hac.png
# Renamed lc_2023had_cleaned.png to 2023had.png
# Renamed lc_2023hao_cleaned.png to 2023hao.png
# Renamed lc_2023hap_cleaned.png to 2023hap.png
# Renamed lc_2023hdl_cleaned.png to 2023hdl.png
# Renamed lc_2023hdy_cleaned.png to 2023hdy.png
# Renamed lc_2023hdz_cleaned.png to 2023hdz.png
# Renamed lc_2023hea_cleaned.png to 2023hea.png
# Renamed lc_2023heb_cleaned.png to 2023heb.png
# Renamed lc_2023hec_cleaned.png to 2023hec.png
# Renamed lc_2023hga_cleaned.png to 2023hga.png
# Renamed lc_2023hgb_cleaned.png to 2023hgb.png
# Renamed lc_2023hgd_cleaned.png to 2023hgd.png
# Renamed lc_2023hgg_cleaned.png to 2023hgg.png
# Renamed lc_2023hgm_cleaned.png to 2023hgm.png
# Renamed lc_2023hhg_cleaned.png to 2023hhg.png
# Renamed lc_2023hhi_cleaned.png to 2023hhi.png
# Renamed lc_2023hhl_cleaned.png to 2023hhl.png
# Renamed lc_2023hhs_cleaned.png to 2023hhs.png
# Renamed lc_2023hif_cleaned.png to 2023hif.png
# Renamed lc_2023hiu_cleaned.png to 2023hiu.png
# Renamed lc_2023hjr_cleaned.png to 2023hjr.png
# Renamed lc_2023hka_cleaned.png to 2023hka.png
# Renamed lc_2023hkj_cleaned.png to 2023hkj.png
# Renamed lc_2023hma_cleaned.png to 2023hma.png
# Renamed lc_2023hmp_cleaned.png to 2023hmp.png
# Renamed lc_2023hnb_cleaned.png to 2023hnb.png
# Renamed lc_2023hnd_cleaned.png to 2023hnd.png
# Renamed lc_2023hng_cleaned.png to 2023hng.png
# Renamed lc_2023ho_cleaned.png to 2023ho.png
# Renamed lc_2023hpf_cleaned.png to 2023hpf.png
# Renamed lc_2023hpn_cleaned.png to 2023hpn.png
# Renamed lc_2023hqg_cleaned.png to 2023hqg.png
# Renamed lc_2023hqh_cleaned.png to 2023hqh.png
# Renamed lc_2023hqz_cleaned.png to 2023hqz.png
# Renamed lc_2023hra_cleaned.png to 2023hra.png
# Renamed lc_2023hsk_cleaned.png to 2023hsk.png
# Renamed lc_2023hti_cleaned.png to 2023hti.png
# Renamed lc_2023htj_cleaned.png to 2023htj.png
# Renamed lc_2023htk_cleaned.png to 2023htk.png
# Renamed lc_2023hto_cleaned.png to 2023hto.png
# Renamed lc_2023htp_cleaned.png to 2023htp.png
# Renamed lc_2023hts_cleaned.png to 2023hts.png
# Renamed lc_2023hua_cleaned.png to 2023hua.png
# Renamed lc_2023hvz_cleaned.png to 2023hvz.png
# Renamed lc_2023hwc_cleaned.png to 2023hwc.png
# Renamed lc_2023hwj_cleaned.png to 2023hwj.png
# Renamed lc_2023hxz_cleaned.png to 2023hxz.png
# Renamed lc_2023hym_cleaned.png to 2023hym.png
# Renamed lc_2023hy_cleaned.png to 2023hy.png
# Renamed lc_2023ied_cleaned.png to 2023ied.png
# Renamed lc_2023ie_cleaned.png to 2023ie.png
# Renamed lc_2023iio_cleaned.png to 2023iio.png
# Renamed lc_2023ikp_cleaned.png to 2023ikp.png
# Renamed lc_2023inb_cleaned.png to 2023inb.png
# Renamed lc_2023iny_cleaned.png to 2023iny.png
# Renamed lc_2023iua_cleaned.png to 2023iua.png
# Renamed lc_2023iuk_cleaned.png to 2023iuk.png
# Renamed lc_2023iwl_cleaned.png to 2023iwl.png
# Renamed lc_2023ixg_cleaned.png to 2023ixg.png
# Renamed lc_2023iyb_cleaned.png to 2023iyb.png
# Renamed lc_2023iy_cleaned.png to 2023iy.png
# Renamed lc_2023jaw_cleaned.png to 2023jaw.png
# Renamed lc_2023jba_cleaned.png to 2023jba.png
# Renamed lc_2023jbj_cleaned.png to 2023jbj.png
# Renamed lc_2023jia_cleaned.png to 2023jia.png
# Renamed lc_2023jml_cleaned.png to 2023jml.png
# Renamed lc_2023jo_cleaned.png to 2023jo.png
# Renamed lc_2023jtz_cleaned.png to 2023jtz.png
# Renamed lc_2023jub_cleaned.png to 2023jub.png
# Renamed lc_2023ma_cleaned.png to 2023ma.png
# Renamed lc_2023mf_cleaned.png to 2023mf.png
# Renamed lc_2023mg_cleaned.png to 2023mg.png
# Renamed lc_2023ms_cleaned.png to 2023ms.png
# Renamed lc_2023nm_cleaned.png to 2023nm.png
# Renamed lc_2023np_cleaned.png to 2023np.png
# Renamed lc_2023qb_cleaned.png to 2023qb.png
# Renamed lc_2023rn_cleaned.png to 2023rn.png
# Renamed lc_2023rr_cleaned.png to 2023rr.png
# Renamed lc_2023rt_cleaned.png to 2023rt.png
# Renamed lc_2023su_cleaned.png to 2023su.png
# Renamed lc_2023tg_cleaned.png to 2023tg.png
# Renamed lc_2023ua_cleaned.png to 2023ua.png
# Renamed lc_2023ub_cleaned.png to 2023ub.png
# Renamed lc_2023ut_cleaned.png to 2023ut.png
# Renamed lc_2023wj_cleaned.png to 2023wj.png
# Renamed lc_2023wo_cleaned.png to 2023wo.png
# Renamed lc_2023wq_cleaned.png to 2023wq.png
# Renamed lc_2023xk_cleaned.png to 2023xk.png
# Renamed lc_2023xq_cleaned.png to 2023xq.png
# Renamed lc_2023xw_cleaned.png to 2023xw.png
# Renamed lc_2023xx_cleaned.png to 2023xx.png
# Renamed lc_2023xz_cleaned.png to 2023xz.png
# Renamed lc_2023yp_cleaned.png to 2023yp.png
# Renamed lc_2023yx_cleaned.png to 2023yx.png
# Renamed lc_2023yz_cleaned.png to 2023yz.png
# Renamed lc_2023zt_cleaned.png to 2023zt.png
# Renamed lc_GRB191016a.png to GRB191016a.png

# %%
import os
import tarfile
import shutil

def extract_and_keep_png(root_dir, output_dir):
    for sector_folder in os.listdir(root_dir):
        sector_path = os.path.join(root_dir, sector_folder)
        if os.path.isdir(sector_path) and sector_folder.startswith("sector"):
            for root, dirs, files in os.walk(sector_path):
                for file in files:
                    if file.endswith(".tar.gz"):
                        tar_filepath = os.path.join(root, file)
                        with tarfile.open(tar_filepath, 'r:gz') as tar:
                            tar.extractall(path=root)
                        
                        os.remove(tar_filepath)

                        for root, dirs, files in os.walk(root):
                            for file in files:
                                if file.endswith(".png"):
                                    png_file_path = os.path.join(root, file)
                                    shutil.move(png_file_path, output_dir)

# Specify the root directory containing "sectorx" folders
root_directory = r"C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs"
# Specify the output directory for PNG files
output_directory = os.path.join(root_directory, "PNG_FILES")

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Call the function to extract tarballs and move PNG files
extract_and_keep_png(root_directory, output_directory)

# %%
import os
import tarfile
import re
import shutil

def extract_tarballs(tarball_directory, extraction_directory):
    for file_name in os.listdir(tarball_directory):
        if file_name.endswith(".tgz"):
            tarball_path = os.path.join(tarball_directory, file_name)
            with tarfile.open(tarball_path, 'r:gz') as tar:
                tar.extractall(extraction_directory)

def delete_png_files(directory):
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".png"):
                os.remove(os.path.join(root, file))

def collect_and_rename_txt_files(directory, output_directory):
    txt_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".txt"):
                txt_files.append(os.path.join(root, file))
    for txt_file in txt_files:
        # Extracting title from the file name
        title = re.findall(r'(?:20\d{2}[a-zA-Z]+)', txt_file)
        if title:
            new_name = os.path.join(output_directory, title[0] + ".txt")
            shutil.copy(txt_file, new_name)

def main():
    # Directory containing the tarballs
    tarball_directory = r"C:\Users\nic51\Code_Repos\Tess\Data\Extracted_Tarballs"
    # Directory to extract tarballs
    extraction_directory = r"C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs"
    # Directory to collect TXT files
    txt_output_directory = r"C:\Users\nic51\Code_Repos\Tess\TXT_Files"

    # Extract tarballs
    extract_tarballs(tarball_directory, extraction_directory)


    # Collect TXT files and rename them
    print("Collecting and renaming TXT files...")
    collect_and_rename_txt_files(extraction_directory, txt_output_directory)
    print("TXT files collected and renamed successfully")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 50
#      47     print("TXT files collected and renamed successfully")
#      49 if __name__ == "__main__":
# ---> 50     main()
#
# Cell In[1], line 41, in main()
#      38 txt_output_directory = r"C:\Users\nic51\Code_Repos\Tess\TXT_Files"
#      40 # Extract tarballs
# ---> 41 extract_tarballs(tarball_directory, extraction_directory)
#      44 # Collect TXT files and rename them
#      45 print("Collecting and renaming TXT files...")
#
# Cell In[1], line 7, in extract_tarballs(tarball_directory, extraction_directory)
#       6 def extract_tarballs(tarball_directory, extraction_directory):
# ----> 7     for file_name in os.listdir(tarball_directory):
#       8         if file_name.endswith(".tgz"):
#       9             tarball_path = os.path.join(tarball_directory, file_name)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\nic51\\Code_Repos\\Tess\\Extracted_Tarballs'

# %%
import os
import shutil

def collect_and_move_txt_files(extraction_directory, txt_output_directory):
    # Create the output directory if it doesn't exist
    os.makedirs(txt_output_directory, exist_ok=True)

    # Traverse each sector folder within the extraction directory
    for sector_folder in os.listdir(extraction_directory):
        sector_path = os.path.join(extraction_directory, sector_folder)
        if os.path.isdir(sector_path):
            # Traverse each file within the sector folder
            for root, _, files in os.walk(sector_path):
                for file in files:
                    if file.endswith(".txt"):
                        # Move the TXT file to the output directory
                        source_path = os.path.join(root, file)
                        destination_path = os.path.join(txt_output_directory, file)
                        shutil.move(source_path, destination_path)

def main():
    # Directory containing the extracted files from tarballs
    extraction_directory = r"C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs"
    # Directory to collect TXT files
    txt_output_directory = r"C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs\TXT_Files"

    # Collect and move TXT files
    print("Collecting and moving TXT files...")
    collect_and_move_txt_files(extraction_directory, txt_output_directory)
    print("TXT files collected and moved successfully")

if __name__ == "__main__":
    main()
# Out:
# Collecting and moving TXT files...
# TXT files collected and moved successfully

# %%
import os
import tarfile

def extract_tarball(tgz_file, extraction_dir, delete_png=False, add_txt_extension=False):
    try:
        with tarfile.open(tgz_file, 'r:gz') as tar:
            tar.extractall(path=extraction_dir)
            if delete_png:
                # Delete .png files
                for member in tar.getmembers():
                    if member.name.endswith('.png'):
                        os.remove(os.path.join(extraction_dir, member.name))
            if add_txt_extension:
                # Rename files and add .txt extension
                for member in tar.getmembers():
                    if not member.name.endswith('.png'):
                        new_name = os.path.splitext(member.name)[0] + '.txt'
                        os.rename(os.path.join(extraction_dir, member.name), os.path.join(extraction_dir, new_name))
        print(f"Extracted {os.path.basename(tgz_file)} to {extraction_dir}")
    except tarfile.ReadError as e:
        print(f"Error extracting {os.path.basename(tgz_file)}:", e)

def main():
    # Local directory where the .tgz files are located
    local_directory = r"C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs"
    
    # Directory where you want to extract the .tgz files
    extraction_dir = r"C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs"
    
    # Create the extraction directory if it does not exist
    if not os.path.exists(extraction_dir):
        os.makedirs(extraction_dir)
    
    # Get a list of .tgz files in the local directory
    tgz_files = [f for f in os.listdir(local_directory) if f.endswith('.tgz')]
    
    # Extract each .tgz file
    for tgz_file in tgz_files:
        # Construct the full path of the .tgz file
        tgz_file_path = os.path.join(local_directory, tgz_file)
        # Extract the .tgz file and optionally delete .png files and add .txt extension
        extract_tarball(tgz_file_path, extraction_dir, delete_png=True, add_txt_extension=True)

if __name__ == "__main__":
    main()
# Out:
# Extracted s01.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s02.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s03.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s04.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s05.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s06.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s07.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s08.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s09.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s10.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s11.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s12.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s13.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s14.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s15.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s16.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s17.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s18.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s19.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s20.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s21.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s22.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s23.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s24.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s25.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s26.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s27.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s28.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s29.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s30.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s31.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s32.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s33.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s34.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s35.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s36.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s37.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s38.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s39.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s40.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s41.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s42.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s43.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s44.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s45.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s46.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s47.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s48.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s49.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s50.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s51.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s52.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s53.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s54.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s55.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s56.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s57.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s58.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s59.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s60.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s61.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s62.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s63.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s64.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s65.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs
# Extracted s66.tgz to C:\Users\nic51\Code_Repos\Tess\Extracted_Tarballs

# %%
#This code takes all figures generated in each sector notebook and saves them as jpeg files
import os
import nbformat
from nbconvert.preprocessors import ExecutePreprocessor
from PIL import Image
import base64
import io

# Function to execute a notebook
def execute_notebook(notebook_path):
    with open(notebook_path) as f:
        nb = nbformat.read(f, as_version=4)

    # Execute the notebook
    ep = ExecutePreprocessor(timeout=600, kernel_name='python3')
    ep.preprocess(nb)

# Function to extract and save plots
def save_plots(notebook_path, output_dir):
    with open(notebook_path) as f:
        nb = nbformat.read(f, as_version=4)

    # Execute the notebook
    execute_notebook(notebook_path)

    # Extract plots from the executed notebook
    for cell in nb.cells:
        if 'outputs' in cell and cell.cell_type == 'code':
            for output in cell.outputs:
                if output.output_type == 'display_data' and 'image/png' in output.data:
                    image_data = output.data['image/png']
                    # Decode base64 encoded image data
                    image_bytes = base64.b64decode(image_data)
                    # Save the plot as a JPEG image file
                    plot_name = f"plot_{cell.execution_count}.jpeg"  # Change the file extension
                    plot_path = os.path.join(output_dir, plot_name)
                    with Image.open(io.BytesIO(image_bytes)) as img:
                        img.convert('RGB').save(plot_path, format='JPEG')  # Save as JPEG

# Function to process notebooks for sectors
def process_sectors():
    for sector in range(1, 67):
        sector_notebook_path = rf'C:\Users\nic51\TESS RESEARCH\Interesting_curves\sector_{sector}.ipynb'
        sector_output_dir = rf'C:\Users\nic51\TESS RESEARCH\Interesting_curves\sector{sector}_interestingcurves'
        os.makedirs(sector_output_dir, exist_ok=True)  # Create directory if it doesn't exist
        save_plots(sector_notebook_path, sector_output_dir)

process_sectors()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 48
#      45         os.makedirs(sector_output_dir, exist_ok=True)  # Create directory if it doesn't exist
#      46         save_plots(sector_notebook_path, sector_output_dir)
# ---> 48 process_sectors()
#
# Cell In[12], line 46, in process_sectors()
#      44 sector_output_dir = rf'C:\Users\nic51\TESS RESEARCH\Interesting_curves\sector{sector}_interestingcurves'
#      45 os.makedirs(sector_output_dir, exist_ok=True)  # Create directory if it doesn't exist
# ---> 46 save_plots(sector_notebook_path, sector_output_dir)
#
# Cell In[12], line 20, in save_plots(notebook_path, output_dir)
#      19 def save_plots(notebook_path, output_dir):
# ---> 20     with open(notebook_path) as f:
#      21         nb = nbformat.read(f, as_version=4)
#      23     # Execute the notebook
#
# File c:\Users\nic51\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\nic51\\TESS RESEARCH\\Interesting_curves\\sector_1.ipynb'

# %%
import os
from pptx import Presentation
from pptx.util import Inches
from PIL import Image
import tempfile

def resize_image(image_path, max_width, max_height):
    image = Image.open(image_path)
    width, height = image.size
    aspect_ratio = width / height

    if width > max_width or height > max_height:
        if aspect_ratio > 1:
            new_width = max_width
            new_height = max_width / aspect_ratio
        else:
            new_width = max_height * aspect_ratio
            new_height = max_height

        image = image.resize((int(new_width), int(new_height)), Image.ANTIALIAS)

    return image

def create_ppt_from_images(root_folder, output_pptx):
    prs = Presentation()
    max_width = Inches(8)
    max_height = Inches(6)

    for folder in os.listdir(root_folder):
        folder_path = os.path.join(root_folder, folder)
        if os.path.isdir(folder_path):
            # Add title slide for each folder
            title_slide_layout = prs.slide_layouts[0]  # Index 0 corresponds to the title slide layout
            title_slide = prs.slides.add_slide(title_slide_layout)
            title = title_slide.shapes.title
            title.text = folder

            for file_name in os.listdir(folder_path):
                if file_name.endswith(".jpg") or file_name.endswith(".jpeg"):
                    file_path = os.path.join(folder_path, file_name)
                    resized_image = resize_image(file_path, max_width, max_height)
                    with tempfile.NamedTemporaryFile(delete=False, suffix=".jpg") as temp_file:
                        temp_file_path = temp_file.name
                        resized_image.save(temp_file_path, format="JPEG")
                        slide_layout = prs.slide_layouts[6]
                        slide = prs.slides.add_slide(slide_layout)
                        left = top = Inches(1)
                        slide.shapes.add_picture(temp_file_path, left, top, width=max_width, height=max_height)

    prs.save(output_pptx)
    print("PowerPoint presentation created successfully!")

root_folder = r"C:\Users\nic51\TESS RESEARCH\Interesting_curves"
output_pptx = "output2.pptx"

create_ppt_from_images(root_folder, output_pptx)
# Out:
# PowerPoint presentation created successfully!
